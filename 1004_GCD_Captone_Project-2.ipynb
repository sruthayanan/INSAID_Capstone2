# %% [markdown]
# # Capstone Project : HR Analytics
#
# <font color='maroon'> Data Analytics and Machine Learning #
#
# <font color='green'>
# ## Group : 1004 ##
# </font>
#
# ![hr.png](attachment:hr.png)

# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Introduction" data-toc-modified-id="Introduction-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Introduction</a></span></li><li><span><a href="#Problem-Statement" data-toc-modified-id="Problem-Statement-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Problem Statement</a></span></li><li><span><a href="#Data-Description" data-toc-modified-id="Data-Description-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Data Description</a></span><ul class="toc-item"><li><ul class="toc-item"><li><span><a href="#department_data" data-toc-modified-id="department_data-3.0.1"><span class="toc-item-num">3.0.1&nbsp;&nbsp;</span>department_data</a></span></li><li><span><a href="#.employee_details_data" data-toc-modified-id=".employee_details_data-3.0.2"><span class="toc-item-num">3.0.2&nbsp;&nbsp;</span>.employee_details_data</a></span></li><li><span><a href="#employee_data" data-toc-modified-id="employee_data-3.0.3"><span class="toc-item-num">3.0.3&nbsp;&nbsp;</span>employee_data</a></span><ul class="toc-item"><li><span><a href="#Target-variable" data-toc-modified-id="Target-variable-3.0.3.1"><span class="toc-item-num">3.0.3.1&nbsp;&nbsp;</span>Target variable</a></span></li><li><span><a href="#Administrative-information" data-toc-modified-id="Administrative-information-3.0.3.2"><span class="toc-item-num">3.0.3.2&nbsp;&nbsp;</span>Administrative information</a></span></li><li><span><a href="#Workload-information" data-toc-modified-id="Workload-information-3.0.3.3"><span class="toc-item-num">3.0.3.3&nbsp;&nbsp;</span>Workload information</a></span></li><li><span><a href="#Mutual-evaluation-information" data-toc-modified-id="Mutual-evaluation-information-3.0.3.4"><span class="toc-item-num">3.0.3.4&nbsp;&nbsp;</span>Mutual evaluation information</a></span></li></ul></li></ul></li><li><span><a href="#Retrieving-Datasets-from-SQL-Server" data-toc-modified-id="Retrieving-Datasets-from-SQL-Server-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Retrieving Datasets from SQL Server</a></span></li><li><span><a href="#Saving-the-datasets-into-CSV-Files" data-toc-modified-id="Saving-the-datasets-into-CSV-Files-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>Saving the datasets into CSV Files</a></span></li><li><span><a href="#Importing-the-datasets" data-toc-modified-id="Importing-the-datasets-3.3"><span class="toc-item-num">3.3&nbsp;&nbsp;</span>Importing the datasets</a></span></li></ul></li><li><span><a href="#Data-Examination" data-toc-modified-id="Data-Examination-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Data Examination</a></span><ul class="toc-item"><li><span><a href="#Observations-of-Department-Data" data-toc-modified-id="Observations-of-Department-Data-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>Observations of Department Data</a></span></li><li><span><a href="#Observations-of-Employee-Details" data-toc-modified-id="Observations-of-Employee-Details-4.2"><span class="toc-item-num">4.2&nbsp;&nbsp;</span>Observations of Employee Details</a></span></li><li><span><a href="#Observations-of-Employee-Data" data-toc-modified-id="Observations-of-Employee-Data-4.3"><span class="toc-item-num">4.3&nbsp;&nbsp;</span>Observations of Employee Data</a></span></li></ul></li><li><span><a href="#Pre-processing-of-Data" data-toc-modified-id="Pre-processing-of-Data-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Pre-processing of Data</a></span><ul class="toc-item"><li><span><a href="#Challenge-1:-Removing-Duplicates" data-toc-modified-id="Challenge-1:-Removing-Duplicates-5.1"><span class="toc-item-num">5.1&nbsp;&nbsp;</span>Challenge-1: Removing Duplicates</a></span></li><li><span><a href="#Challenge-2:-Correction-in-Department-ID" data-toc-modified-id="Challenge-2:-Correction-in-Department-ID-5.2"><span class="toc-item-num">5.2&nbsp;&nbsp;</span>Challenge-2: Correction in Department ID</a></span></li><li><span><a href="#Challenge-3:-Merging-the-Datasets" data-toc-modified-id="Challenge-3:-Merging-the-Datasets-5.3"><span class="toc-item-num">5.3&nbsp;&nbsp;</span>Challenge-3: Merging the Datasets</a></span></li><li><span><a href="#Challenge-4:-Missing-Value-Treatment" data-toc-modified-id="Challenge-4:-Missing-Value-Treatment-5.4"><span class="toc-item-num">5.4&nbsp;&nbsp;</span>Challenge-4: Missing Value Treatment</a></span><ul class="toc-item"><li><span><a href="#For-null-values-in-'Department':" data-toc-modified-id="For-null-values-in-'Department':-5.4.1"><span class="toc-item-num">5.4.1&nbsp;&nbsp;</span>For null values in 'Department':</a></span></li><li><span><a href="#For-null-values-in-Filed-Complaint:" data-toc-modified-id="For-null-values-in-Filed-Complaint:-5.4.2"><span class="toc-item-num">5.4.2&nbsp;&nbsp;</span>For null values in Filed Complaint:</a></span></li><li><span><a href="#For-null-values-in-Recently-Promoted:" data-toc-modified-id="For-null-values-in-Recently-Promoted:-5.4.3"><span class="toc-item-num">5.4.3&nbsp;&nbsp;</span>For null values in Recently Promoted:</a></span></li><li><span><a href="#For-null-values-in-Tenure:" data-toc-modified-id="For-null-values-in-Tenure:-5.4.4"><span class="toc-item-num">5.4.4&nbsp;&nbsp;</span>For null values in Tenure:</a></span></li><li><span><a href="#For-null-values-in-Satisfaction" data-toc-modified-id="For-null-values-in-Satisfaction-5.4.5"><span class="toc-item-num">5.4.5&nbsp;&nbsp;</span>For null values in Satisfaction</a></span></li><li><span><a href="#For-null-values-in-Last-Evaluation" data-toc-modified-id="For-null-values-in-Last-Evaluation-5.4.6"><span class="toc-item-num">5.4.6&nbsp;&nbsp;</span>For null values in Last Evaluation</a></span></li></ul></li></ul></li><li><span><a href="#Exploratory-Data-Analysis" data-toc-modified-id="Exploratory-Data-Analysis-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Exploratory Data Analysis</a></span><ul class="toc-item"><li><span><a href="#Employee-Status-Analysis" data-toc-modified-id="Employee-Status-Analysis-6.1"><span class="toc-item-num">6.1&nbsp;&nbsp;</span>Employee Status Analysis</a></span></li><li><span><a href="#Gender-wise-data-analysis" data-toc-modified-id="Gender-wise-data-analysis-6.2"><span class="toc-item-num">6.2&nbsp;&nbsp;</span>Gender wise data analysis</a></span></li><li><span><a href="#Age-wise-data-analysis" data-toc-modified-id="Age-wise-data-analysis-6.3"><span class="toc-item-num">6.3&nbsp;&nbsp;</span>Age wise data analysis</a></span></li><li><span><a href="#Department-wise-Analysis" data-toc-modified-id="Department-wise-Analysis-6.4"><span class="toc-item-num">6.4&nbsp;&nbsp;</span>Department wise Analysis</a></span></li><li><span><a href="#Marital-Status-Analysis" data-toc-modified-id="Marital-Status-Analysis-6.5"><span class="toc-item-num">6.5&nbsp;&nbsp;</span>Marital Status Analysis</a></span></li><li><span><a href="#Tenure-wise-Analysis" data-toc-modified-id="Tenure-wise-Analysis-6.6"><span class="toc-item-num">6.6&nbsp;&nbsp;</span>Tenure-wise Analysis</a></span></li><li><span><a href="#Recently-Promoted-wise-Analysis" data-toc-modified-id="Recently-Promoted-wise-Analysis-6.7"><span class="toc-item-num">6.7&nbsp;&nbsp;</span>Recently Promoted wise Analysis</a></span></li><li><span><a href="#n_projects-wise-Analysis" data-toc-modified-id="n_projects-wise-Analysis-6.8"><span class="toc-item-num">6.8&nbsp;&nbsp;</span>n_projects wise Analysis</a></span></li><li><span><a href="#Filed-Complaint-wise-Analysis" data-toc-modified-id="Filed-Complaint-wise-Analysis-6.9"><span class="toc-item-num">6.9&nbsp;&nbsp;</span>Filed Complaint wise Analysis</a></span></li><li><span><a href="#Monthly-hours-worked-by-the-employee" data-toc-modified-id="Monthly-hours-worked-by-the-employee-6.10"><span class="toc-item-num">6.10&nbsp;&nbsp;</span>Monthly hours worked by the employee</a></span></li><li><span><a href="#Salary-wise-Analysis" data-toc-modified-id="Salary-wise-Analysis-6.11"><span class="toc-item-num">6.11&nbsp;&nbsp;</span>Salary wise Analysis</a></span></li><li><span><a href="#Satisfaction-and-Last-Evaluation-wise-Analysis" data-toc-modified-id="Satisfaction-and-Last-Evaluation-wise-Analysis-6.12"><span class="toc-item-num">6.12&nbsp;&nbsp;</span>Satisfaction and Last Evaluation wise Analysis</a></span></li><li><span><a href="#Correlation-b/w-Features" data-toc-modified-id="Correlation-b/w-Features-6.13"><span class="toc-item-num">6.13&nbsp;&nbsp;</span>Correlation b/w Features</a></span></li><li><span><a href="#Pair-Plot" data-toc-modified-id="Pair-Plot-6.14"><span class="toc-item-num">6.14&nbsp;&nbsp;</span>Pair Plot</a></span></li></ul></li><li><span><a href="#Final-Dataset-for-Modelling" data-toc-modified-id="Final-Dataset-for-Modelling-7"><span class="toc-item-num">7&nbsp;&nbsp;</span>Final Dataset for Modelling</a></span></li><li><span><a href="#Feature-Engineering" data-toc-modified-id="Feature-Engineering-8"><span class="toc-item-num">8&nbsp;&nbsp;</span>Feature Engineering</a></span><ul class="toc-item"><li><span><a href="#Encoding" data-toc-modified-id="Encoding-8.1"><span class="toc-item-num">8.1&nbsp;&nbsp;</span>Encoding</a></span><ul class="toc-item"><li><span><a href="#Label-Encoding" data-toc-modified-id="Label-Encoding-8.1.1"><span class="toc-item-num">8.1.1&nbsp;&nbsp;</span>Label Encoding</a></span></li><li><span><a href="#One-Hot-encoding" data-toc-modified-id="One-Hot-encoding-8.1.2"><span class="toc-item-num">8.1.2&nbsp;&nbsp;</span>One-Hot encoding</a></span></li></ul></li><li><span><a href="#Splitting-X-and-y-into-training-datasets" data-toc-modified-id="Splitting-X-and-y-into-training-datasets-8.2"><span class="toc-item-num">8.2&nbsp;&nbsp;</span>Splitting X and y into training datasets</a></span></li><li><span><a href="#Scaling" data-toc-modified-id="Scaling-8.3"><span class="toc-item-num">8.3&nbsp;&nbsp;</span>Scaling</a></span></li></ul></li><li><span><a href="#Modeling" data-toc-modified-id="Modeling-9"><span class="toc-item-num">9&nbsp;&nbsp;</span>Modeling</a></span><ul class="toc-item"><li><span><a href="#Logistic-Regression" data-toc-modified-id="Logistic-Regression-9.1"><span class="toc-item-num">9.1&nbsp;&nbsp;</span>Logistic Regression</a></span></li><li><span><a href="#Decision-Tree-Classifier" data-toc-modified-id="Decision-Tree-Classifier-9.2"><span class="toc-item-num">9.2&nbsp;&nbsp;</span>Decision Tree Classifier</a></span></li><li><span><a href="#Random-Forest-Classifier" data-toc-modified-id="Random-Forest-Classifier-9.3"><span class="toc-item-num">9.3&nbsp;&nbsp;</span>Random Forest Classifier</a></span></li><li><span><a href="#Naive-Bayes" data-toc-modified-id="Naive-Bayes-9.4"><span class="toc-item-num">9.4&nbsp;&nbsp;</span>Naive Bayes</a></span></li><li><span><a href="#K-Nearest-Neighbor" data-toc-modified-id="K-Nearest-Neighbor-9.5"><span class="toc-item-num">9.5&nbsp;&nbsp;</span>K Nearest Neighbor</a></span></li><li><span><a href="#Support-Vector-Machines" data-toc-modified-id="Support-Vector-Machines-9.6"><span class="toc-item-num">9.6&nbsp;&nbsp;</span>Support Vector Machines</a></span></li><li><span><a href="#Bagging-Classifier" data-toc-modified-id="Bagging-Classifier-9.7"><span class="toc-item-num">9.7&nbsp;&nbsp;</span>Bagging Classifier</a></span></li><li><span><a href="#Voting-Based-Ensemble-Technique" data-toc-modified-id="Voting-Based-Ensemble-Technique-9.8"><span class="toc-item-num">9.8&nbsp;&nbsp;</span>Voting Based Ensemble Technique</a></span></li><li><span><a href="#AdaBoost-Classifier" data-toc-modified-id="AdaBoost-Classifier-9.9"><span class="toc-item-num">9.9&nbsp;&nbsp;</span>AdaBoost Classifier</a></span></li><li><span><a href="#Gradient-Boost-Classifier" data-toc-modified-id="Gradient-Boost-Classifier-9.10"><span class="toc-item-num">9.10&nbsp;&nbsp;</span>Gradient Boost Classifier</a></span></li><li><span><a href="#XG-Boost-Classifier" data-toc-modified-id="XG-Boost-Classifier-9.11"><span class="toc-item-num">9.11&nbsp;&nbsp;</span>XG Boost Classifier</a></span></li></ul></li><li><span><a href="#Hyper-Parameter-Tuning" data-toc-modified-id="Hyper-Parameter-Tuning-10"><span class="toc-item-num">10&nbsp;&nbsp;</span>Hyper Parameter Tuning</a></span><ul class="toc-item"><li><span><a href="#Gridsearch-with-Decision-Tree" data-toc-modified-id="Gridsearch-with-Decision-Tree-10.1"><span class="toc-item-num">10.1&nbsp;&nbsp;</span>Gridsearch with Decision Tree</a></span></li><li><span><a href="#Gridsearch-with-Bagging-Classifier" data-toc-modified-id="Gridsearch-with-Bagging-Classifier-10.2"><span class="toc-item-num">10.2&nbsp;&nbsp;</span>Gridsearch with Bagging Classifier</a></span></li><li><span><a href="#RandomizedsearchCV-with-Random-Forest" data-toc-modified-id="RandomizedsearchCV-with-Random-Forest-10.3"><span class="toc-item-num">10.3&nbsp;&nbsp;</span>RandomizedsearchCV with Random Forest</a></span></li><li><span><a href="#Support-Vector-Classifier" data-toc-modified-id="Support-Vector-Classifier-10.4"><span class="toc-item-num">10.4&nbsp;&nbsp;</span>Support Vector Classifier</a></span></li></ul></li><li><span><a href="#Fit-&amp;-Tune-Models-with-Cross-validation" data-toc-modified-id="Fit-&amp;-Tune-Models-with-Cross-validation-11"><span class="toc-item-num">11&nbsp;&nbsp;</span>Fit &amp; Tune Models with Cross validation</a></span><ul class="toc-item"><li><span><a href="#Logistic-Regression" data-toc-modified-id="Logistic-Regression-11.1"><span class="toc-item-num">11.1&nbsp;&nbsp;</span>Logistic Regression</a></span></li><li><span><a href="#Support-Vector-Classifier" data-toc-modified-id="Support-Vector-Classifier-11.2"><span class="toc-item-num">11.2&nbsp;&nbsp;</span>Support Vector Classifier</a></span></li><li><span><a href="#Bagging-Classifier" data-toc-modified-id="Bagging-Classifier-11.3"><span class="toc-item-num">11.3&nbsp;&nbsp;</span>Bagging Classifier</a></span></li><li><span><a href="#Adaboost-Classifier" data-toc-modified-id="Adaboost-Classifier-11.4"><span class="toc-item-num">11.4&nbsp;&nbsp;</span>Adaboost Classifier</a></span></li><li><span><a href="#XGB-Classifier" data-toc-modified-id="XGB-Classifier-11.5"><span class="toc-item-num">11.5&nbsp;&nbsp;</span>XGB Classifier</a></span></li></ul></li><li><span><a href="#Evaluate-and-Finalise-the-Model" data-toc-modified-id="Evaluate-and-Finalise-the-Model-12"><span class="toc-item-num">12&nbsp;&nbsp;</span>Evaluate and Finalise the Model</a></span><ul class="toc-item"><li><span><a href="#Model-Comparison" data-toc-modified-id="Model-Comparison-12.1"><span class="toc-item-num">12.1&nbsp;&nbsp;</span>Model Comparison</a></span></li><li><span><a href="#Finalizing-the-Model" data-toc-modified-id="Finalizing-the-Model-12.2"><span class="toc-item-num">12.2&nbsp;&nbsp;</span>Finalizing the Model</a></span></li></ul></li><li><span><a href="#Predicting-the-Unseen-Data" data-toc-modified-id="Predicting-the-Unseen-Data-13"><span class="toc-item-num">13&nbsp;&nbsp;</span>Predicting the Unseen Data</a></span><ul class="toc-item"><li><span><a href="#Importing-&amp;-Preprocessing-of-Unseen-data" data-toc-modified-id="Importing-&amp;-Preprocessing-of-Unseen-data-13.1"><span class="toc-item-num">13.1&nbsp;&nbsp;</span>Importing &amp; Preprocessing of Unseen data</a></span></li><li><span><a href="#Missing-Value-Treatment:" data-toc-modified-id="Missing-Value-Treatment:-13.2"><span class="toc-item-num">13.2&nbsp;&nbsp;</span>Missing Value Treatment:</a></span></li><li><span><a href="#Feature-Engineering-of-Unseen-data" data-toc-modified-id="Feature-Engineering-of-Unseen-data-13.3"><span class="toc-item-num">13.3&nbsp;&nbsp;</span>Feature Engineering of Unseen data</a></span><ul class="toc-item"><li><span><a href="#Encoding" data-toc-modified-id="Encoding-13.3.1"><span class="toc-item-num">13.3.1&nbsp;&nbsp;</span>Encoding</a></span></li></ul></li><li><span><a href="#Model-to-Predict-Unseen-Data" data-toc-modified-id="Model-to-Predict-Unseen-Data-13.4"><span class="toc-item-num">13.4&nbsp;&nbsp;</span>Model to Predict Unseen Data</a></span></li></ul></li><li><span><a href="#Actionable-Insights" data-toc-modified-id="Actionable-Insights-14"><span class="toc-item-num">14&nbsp;&nbsp;</span>Actionable Insights</a></span><ul class="toc-item"><li><ul class="toc-item"><li><span><a href="#Actionable-Insight:" data-toc-modified-id="Actionable-Insight:-14.0.1"><span class="toc-item-num">14.0.1&nbsp;&nbsp;</span>Actionable Insight:</a></span></li></ul></li></ul></li></ul></div>

# %% [markdown]
# ##  Introduction

# %% [markdown]
# Employee attrition is one of the great concerns that companies are struggling to address today and this situation shall continue to be there for one simple reason: the companies don’t really understand why their employees are leaving in the first place. Rather than companies jumping to well-intentioned quick fixes, they may take time to investigate the true causes of attrition. If companies make a concerted effort to better understand why employees are leaving and take meaningful action to retain the emplyees, they can gain an edge in the race to attract, develop, and retain the talent.
#
# **Current Practice**
#
# Once an employee leaves, he or she is taken an interview with the name "exit interview" and shares reasons for leaving. The HR Department then tries and learns insights from the interview and makes changes accordingly.
#
# **This suffers from the following problems:**
#
# The above approach is that it's too haphazard. The quality of insight gained from an interview depends heavily on the skill of the interviewer.
# The second problem is these insights can't be aggregated and interlaced across all employees who have left.
# The third is that it is too late by the time the proposed policy changes take effect.

# %% [markdown]
# ##  Problem Statement

# %% [markdown]
# Our client for this project is the HR Department at a software company.
#
# The problem statement is described in the following points:-
# - The HR Department wants to try a **new initiative** to retain employees.
# - The idea is to use **data to predict** whether an employee is **likely to leave**.
# - Once these employees are identified, HR can be **more proactive** in reaching out to them before it's too late.
# - They only want to deal with the data that is related to permanent employees.
# - HR Department has given datasets of past employees and their status (still employed or already left).
# - Our task is **to build a classification model to predict whether an employee will stay or leave**.
# - We need to build the best possible model as there is no comparable candidate for this problem.

# %% [markdown]
# ##  Data Description

# %% [markdown]
# The Business Intelligence Analysts of the Company provided us three datasets that contain information about past employees and their status (still employed or already left).
#
# #### department_data
#     This dataset contains information about each department. The schema of the dataset is as follows:
#
#     - **dept_id**  -Unique Department Code
#     - **dept_name** -Name of the Department
#     - **dept_head**  -Name of the Head of the Department
#
# #### .employee_details_data
#     This dataset consists of Employee ID, their Age, Gender and Marital Status. The schema of this dataset is as follows:
#
#     - **employee_id** – Unique ID Number for each employee
#     - **age** – Age of the employee
#     - **gender** – Gender of the employee
#     - **marital_status** – Marital Status of the employee
#
# ####  employee_data
#     This dataset consists of each employee’s Administrative Information, Workload Information, Mutual Evaluation Information and Status.
#
#    ##### Target variable
#     - status – Current employment status (Employed / Left)
#
#    ##### Administrative information
#     - department – Department to which the employees belong(ed) to
#     - salary – Salary level with respect to rest of their department
#     - tenure – Number of years at the company
#     - recently_promoted – Was the employee promoted in the last 3 years?
#     - employee_id – Unique ID Number for each employee
#
#    ##### Workload information
#     - n_projects – Number of projects employee has worked on
#     - avg_monthly_hrs – Average number of hours worked per month
#
#    ##### Mutual evaluation information
#     - satisfaction – Score for employee’s satisfaction with the company (higher is better)
#     - last_evaluation – Score for most recent evaluation of employee (higher is better)
#     - filed_complaint – Has the employee filed a formal complaint in the last 3 years?

# %% [markdown]
# ###  Retrieving Datasets from SQL Server

# %%
#!pip install mysql

# %%
#!pip install mysql.connector

# %%
import numpy as np                     
import pandas as pd

pd.set_option('mode.chained_assignment', None)      
pd.set_option('display.max_colwidth', -1)           
pd.options.display.max_columns = 50  
pd.set_option('display.max_rows', None)
pd.set_option('float_format', '{:5f}'.format)

import warnings
warnings.filterwarnings('ignore')                  

import matplotlib.pyplot as plt
# %matplotlib inline

import seaborn as sns
sns.set(style='whitegrid', font_scale=1.3, color_codes=True)
# Out:
# <ipython-input-1-3463aee4df3d>:5: FutureWarning: Passing a negative integer is deprecated in version 1.0 and will not be supported in future version. Instead, use None to not limit the column width.
#   pd.set_option('display.max_colwidth', -1)

# %%
'''import mysql.connector
from mysql.connector import Error
import pandas as pd

try:
    connection = mysql.connector.connect(host='cpanel.insaid.co',
                                         database='Capstone2',
                                         user='student',
                                         password='student')
    
    if connection.is_connected():
        db_Info = connection.get_server_info()
        print("Connected to MySQL Server version ", db_Info)
        cursor = connection.cursor()
        cursor.execute("select database();")
        record = cursor.fetchone()
        print("You're connected to database: ", record)
        print("\n")
        
        cursor.execute("USE Capstone2")
        cursor.execute("SHOW TABLES")
        for (table_name,) in cursor:
            print(table_name)
        print("\n")
        
except Error as e:
    print("Error while connecting to MySQL", e)
finally:
    if (connection.is_connected()):
        cursor.close()
        connection.close()
        print("MySQL connection is closed")'''
# Out:
# 'import mysql.connector\nfrom mysql.connector import Error\nimport pandas as pd\n\ntry:\n    connection = mysql.connector.connect(host=\'cpanel.insaid.co\',\n                                         database=\'Capstone2\',\n                                         user=\'student\',\n                                         password=\'student\')\n    \n    if connection.is_connected():\n        db_Info = connection.get_server_info()\n        print("Connected to MySQL Server version ", db_Info)\n        cursor = connection.cursor()\n        cursor.execute("select database();")\n        record = cursor.fetchone()\n        print("You\'re connected to database: ", record)\n        print("\n")\n        \n        cursor.execute("USE Capstone2")\n        cursor.execute("SHOW TABLES")\n        for (table_name,) in cursor:\n            print(table_name)\n        print("\n")\n        \nexcept Error as e:\n    print("Error while connecting to MySQL", e)\nfinally:\n    if (connection.is_connected()):\n        cursor.close()\n        connection.close()\n        print("MySQL connection is closed")'

# %% [markdown]
# ### Saving the datasets into CSV Files

# %%
'''try:
    connection = mysql.connector.connect(host='cpanel.insaid.co',
                                         database='Capstone2',
                                         user='student',
                                         password='student')
    
    if connection.is_connected():
        db_Info = connection.get_server_info()
        print("Connected to MySQL Server version ", db_Info)
        cursor = connection.cursor()
        cursor.execute("select database();")
        record = cursor.fetchone()
        print("You're connected to database: ", record)
        print("\n")
        
        cursor.execute("USE Capstone2")
        cursor.execute("SHOW TABLES")
        for (table_name,) in cursor:
            print(table_name)
        print("\n")
        
# export  department_data table in csv format
        sql_select_Query = "select * from department_data"
        results = pd.read_sql_query(sql_select_Query, connection)
        results.to_csv("department_data.csv", index=False)
        print("Sucessfully exported table department_data")
        
# export  employee_data table in csv format
        sql_select_Query = "select * from employee_data"
        results = pd.read_sql_query(sql_select_Query, connection)
        results.to_csv("employee_data.csv", index=False)
        print("Sucessfully exported table employee_data")
        
# export  employee_details_data table in csv format
        sql_select_Query = "select * from employee_details_data"
        results = pd.read_sql_query(sql_select_Query, connection)
        results.to_csv("employee_details_data.csv", index=False)
        print("Sucessfully exported table employee_details_data")

# export  model_evaluation_results table in csv format
        sql_select_Query = "select * from model_evaluation_results"
        results = pd.read_sql_query(sql_select_Query, connection)
        results.to_csv("model_evaluation_results.csv", index=False)
        print("Sucessfully exported table model_evaluation_results")
        
# export  model_evaluation_table in csv format
        sql_select_Query = "select * from model_evaluation_table"
        results = pd.read_sql_query(sql_select_Query, connection)
        results.to_csv("model_evaluation_table.csv", index=False)
        print("Sucessfully exported table model_evaluation_table")
        
        
except Error as e:
    print("Error while connecting to MySQL", e)
finally:
    if (connection.is_connected()):
        cursor.close()
        connection.close()
        print("MySQL connection is closed")'''
# Out:
# 'try:\n    connection = mysql.connector.connect(host=\'cpanel.insaid.co\',\n                                         database=\'Capstone2\',\n                                         user=\'student\',\n                                         password=\'student\')\n    \n    if connection.is_connected():\n        db_Info = connection.get_server_info()\n        print("Connected to MySQL Server version ", db_Info)\n        cursor = connection.cursor()\n        cursor.execute("select database();")\n        record = cursor.fetchone()\n        print("You\'re connected to database: ", record)\n        print("\n")\n        \n        cursor.execute("USE Capstone2")\n        cursor.execute("SHOW TABLES")\n        for (table_name,) in cursor:\n            print(table_name)\n        print("\n")\n        \n# export  department_data table in csv format\n        sql_select_Query = "select * from department_data"\n        results = pd.read_sql_query(sql_select_Query, connection)\n        results.to_csv("department_data.csv", index=False)\n        print("Sucessfully exported table department_data")\n        \n# export  employee_data table in csv format\n        sql_select_Query = "select * from employee_data"\n        results = pd.read_sql_query(sql_select_Query, connection)\n        results.to_csv("employee_data.csv", index=False)\n        print("Sucessfully exported table employee_data")\n        \n# export  employee_details_data table in csv format\n        sql_select_Query = "select * from employee_details_data"\n        results = pd.read_sql_query(sql_select_Query, connection)\n        results.to_csv("employee_details_data.csv", index=False)\n        print("Sucessfully exported table employee_details_data")\n\n# export  model_evaluation_results table in csv format\n        sql_select_Query = "select * from model_evaluation_results"\n        results = pd.read_sql_query(sql_select_Query, connection)\n        results.to_csv("model_evaluation_results.csv", index=False)\n        print("Sucessfully exported table model_evaluation_results")\n        \n# export  model_evaluation_table in csv format\n        sql_select_Query = "select * from model_evaluation_table"\n        results = pd.read_sql_query(sql_select_Query, connection)\n        results.to_csv("model_evaluation_table.csv", index=False)\n        print("Sucessfully exported table model_evaluation_table")\n        \n        \nexcept Error as e:\n    print("Error while connecting to MySQL", e)\nfinally:\n    if (connection.is_connected()):\n        cursor.close()\n        connection.close()\n        print("MySQL connection is closed")'

# %% [markdown]
# ### Importing the datasets

# %%
dept_data = pd.read_csv("https://raw.githubusercontent.com/sruthayanan/INSAID_Capstone2/main/department_data.csv")
emp_details = pd.read_csv("https://raw.githubusercontent.com/sruthayanan/INSAID_Capstone2/main/employee_details_data.csv")
emp_data = pd.read_csv("https://raw.githubusercontent.com/sruthayanan/INSAID_Capstone2/main/employee_data.csv")

# %% [markdown]
# ##  Data Examination

# %% [markdown]
# ###  Observations of Department Data

# %%
dept_data.head()
# Out:
#    dept_id    dept_name              dept_head
# 0  D00-IT   IT           Henry Adey
# 1  D00-SS   Sales        Edward J Bayley
# 2  D00-TP   Temp         Micheal Zachrey
# 3  D00-ENG  Engineering  Sushant Raghunathan K
# 4  D00-SP   Support      Amelia Westray

# %%
dept_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11 entries, 0 to 10
# Data columns (total 3 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   dept_id    11 non-null     object
#  1   dept_name  11 non-null     object
#  2   dept_head  11 non-null     object
# dtypes: object(3)
# memory usage: 392.0+ bytes

# %% [markdown]
# - There are **11** unique departments present in the dataset

# %% [markdown]
# ###  Observations of Employee Details

# %%
emp_details.head()
# Out:
#    employee_id  age  gender marital_status
# 0  113558       43   Male    Married
# 1  112256       24   Female  Unmarried
# 2  112586       22   Female  Unmarried
# 3  108071       36   Male    Married
# 4  116915       38   Male    Married

# %%
emp_details.shape
# Out:
# (14245, 4)

# %%
emp_details.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14245 entries, 0 to 14244
# Data columns (total 4 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   employee_id     14245 non-null  int64
#  1   age             14245 non-null  int64
#  2   gender          14245 non-null  object
#  3   marital_status  14245 non-null  object
# dtypes: int64(2), object(2)
# memory usage: 445.3+ KB

# %%
emp_details.describe(include='all')
# Out:
#          employee_id          age gender marital_status
# count  14245.000000  14245.000000  14245  14245
# unique   nan           nan         2      2
# top      nan           nan         Male   Unmarried
# freq     nan           nan         9382   7283
# mean   112123.050544 32.889926     NaN    NaN
# std    8500.457343   9.970834      NaN    NaN
# min    100101.000000 22.000000     NaN    NaN
# 25%    105775.000000 24.000000     NaN    NaN
# 50%    111298.000000 29.000000     NaN    NaN
# 75%    116658.000000 41.000000     NaN    NaN
# max    148988.000000 57.000000     NaN    NaN

# %% [markdown]
# - The minimum and maximum ages of the employees working in the company are 22 and 57 respectively

# %%
emp_details.nunique()
# Out:
# employee_id       14245
# age               36
# gender            2
# marital_status    2
# dtype: int64

# %%
emp_details.isnull().sum().sort_values(ascending = False)
# Out:
# marital_status    0
# gender            0
# age               0
# employee_id       0
# dtype: int64

# %%
emp_details = emp_details.drop_duplicates()

# %%
emp_details.shape
# Out:
# (14245, 4)

# %% [markdown]
# - Total observations are 14245 and 4 Variables
# - No Missing Values
# - No duplicated rows in the emp_details dataset

# %% [markdown]
# ###  Observations of Employee Data

# %%
emp_data.head()
# Out:
#    avg_monthly_hrs department  filed_complaint  last_evaluation  n_projects  \
# 0 246.000000        NaN         nan            0.866838          6
# 1 134.000000        NaN         nan            0.555718          2
# 2 156.000000        D00-SS    1.000000         0.474082          2
# 3 256.000000        D00-SP      nan            0.961360          6
# 4 146.000000        D00-SS      nan            0.507349          2
#
#    recently_promoted  salary  satisfaction status   tenure  employee_id
# 0   nan               medium 0.134415       Left  4.000000  124467
# 1   nan               low    0.511041       Left  3.000000  112210
# 2   nan               medium 0.405101       Left  3.000000  126150
# 3   nan               low    0.152974       Left  4.000000  125346
# 4   nan               medium 0.434845       Left  3.000000  113707

# %%
emp_data.shape
# Out:
# (14150, 11)

# %%
emp_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14150 entries, 0 to 14149
# Data columns (total 11 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   avg_monthly_hrs    14150 non-null  float64
#  1   department         13443 non-null  object
#  2   filed_complaint    2046 non-null   float64
#  3   last_evaluation    12663 non-null  float64
#  4   n_projects         14150 non-null  int64
#  5   recently_promoted  297 non-null    float64
#  6   salary             14150 non-null  object
#  7   satisfaction       14000 non-null  float64
#  8   status             14150 non-null  object
#  9   tenure             14000 non-null  float64
#  10  employee_id        14150 non-null  int64
# dtypes: float64(6), int64(2), object(3)
# memory usage: 1.2+ MB

# %% [markdown]
# - The "emp_data" contains null values in some of the variables.

# %%
emp_data.describe()
# Out:
#        avg_monthly_hrs  filed_complaint  last_evaluation   n_projects  \
# count 14150.000000     2046.000000      12663.000000     14150.000000
# mean  199.994346       1.000000         0.718399         3.778304
# std   50.833697        0.000000         0.173108         1.250162
# min   49.000000        1.000000         0.316175         1.000000
# 25%   155.000000       1.000000         0.563711         3.000000
# 50%   199.000000       1.000000         0.724731         4.000000
# 75%   245.000000       1.000000         0.871409         5.000000
# max   310.000000       1.000000         1.000000         7.000000
#
#        recently_promoted  satisfaction       tenure   employee_id
# count 297.000000         14000.000000  14000.000000 14150.000000
# mean  1.000000           0.621212      3.499357     112080.750247
# std   0.000000           0.250482      1.462584     8748.202856
# min   1.000000           0.040058      2.000000     0.000000
# 25%   1.000000           0.450356      3.000000     105772.500000
# 50%   1.000000           0.652394      3.000000     111291.500000
# 75%   1.000000           0.824926      4.000000     116650.750000
# max   1.000000           1.000000      10.000000    148988.000000

# %% [markdown]
# - There are some **employee_id**s whose entries are Zeros.

# %%
emp_data.isnull().sum().sort_values(ascending = False)
# Out:
# recently_promoted    13853
# filed_complaint      12104
# last_evaluation      1487
# department           707
# tenure               150
# satisfaction         150
# employee_id          0
# status               0
# salary               0
# n_projects           0
# avg_monthly_hrs      0
# dtype: int64

# %% [markdown]
# - Total observations are **14150**.
# - **13853** records having null values in **Recently promoted** variable.
# - **12104** records having null values in  **filed_complaint** variable.
# - **1487** records having null values in **last evaluation** variable.
# - **707** records having null values in **Department** variable.
# - For **Tenure** and **satisfaction** variables, **150** records having null values.

# %%
emp_data.nunique()
# Out:
# avg_monthly_hrs      249
# department           12
# filed_complaint      1
# last_evaluation      12188
# n_projects           7
# recently_promoted    1
# salary               3
# satisfaction         13497
# status               2
# tenure               8
# employee_id          14117
# dtype: int64

# %%
emp_data.employee_id.value_counts()[:5]
# Out:
# 0         5
# 119780    2
# 104360    2
# 116850    2
# 109425    2
# Name: employee_id, dtype: int64

# %%
df_id = emp_data[(emp_data.employee_id == 0)]
df_id
# Out:
#        avg_monthly_hrs department  filed_complaint  last_evaluation  \
# 34    284.000000        D00-SS      nan            0.852702
# 304   264.000000        D00-ENG     nan            0.774554
# 1234  129.000000        D00-SP      nan            0.402660
# 11304 167.000000        NaN         nan            0.880053
# 12304 259.000000        D00-ENG     nan            0.505883
#
#        n_projects  recently_promoted  salary  satisfaction    status   tenure  \
# 34     6            nan               low    0.069168       Left     4.000000
# 304    6            nan               low    0.110974       Left     4.000000
# 1234   2            nan               medium 0.437359       Left     3.000000
# 11304  5            nan               low    0.682140       Employed 3.000000
# 12304  5            nan               low    0.631046       Employed 4.000000
#
#        employee_id
# 34     0
# 304    0
# 1234   0
# 11304  0
# 12304  0

# %% [markdown]
# - 5 Observations has the Employee id as Zero and there is no common variable between the datasets to extract from other datasets, hence these 5 observations needs to be dropped

# %% [markdown]
# ##  Pre-processing of Data

# %% [markdown]
# ### Challenge-1: Removing Duplicates

# %%
emp_data = emp_data.drop_duplicates()

# %%
emp_data.shape
# Out:
# (14121, 11)

# %% [markdown]
# - emp_data has a size of 14121 after dropping duplicates

# %%
emp_data.nunique()
# Out:
# avg_monthly_hrs      249
# department           12
# filed_complaint      1
# last_evaluation      12188
# n_projects           7
# recently_promoted    1
# salary               3
# satisfaction         13497
# status               2
# tenure               8
# employee_id          14117
# dtype: int64

# %% [markdown]
# ###  Challenge-2: Correction in Department ID

# %%
emp_data.department.value_counts()
# Out:
# D00-SS     3896
# D00-ENG    2575
# D00-SP     2109
# D00-IT     1152
# D00-PD     853
# D00-MT     812
# D00-FN     722
# D00-MN     590
# -IT        207
# D00-AD     175
# D00-PR     173
# D00-TP     150
# Name: department, dtype: int64

# %% [markdown]
# - Replace 207 rows of'-IT' with 'D00-IT' in emp_data

# %%
emp_data.replace({'-IT'},{'D00-IT'},inplace =True)

# %%
emp_data.department.value_counts()
# Out:
# D00-SS     3896
# D00-ENG    2575
# D00-SP     2109
# D00-IT     1359
# D00-PD     853
# D00-MT     812
# D00-FN     722
# D00-MN     590
# D00-AD     175
# D00-PR     173
# D00-TP     150
# Name: department, dtype: int64

# %% [markdown]
# ### Challenge-3: Merging the Datasets

# %% [markdown]
# - 'emp_data' and 'emp_details' datasets are being merged to get a common dataset 'final_data'

# %%
common = np.intersect1d(emp_data.employee_id,emp_details.employee_id)
common.shape
# Out:
# (14116,)

# %%
final_data = pd.merge(left=emp_data,right=emp_details, how='inner',on='employee_id')
final_data.head()
# Out:
#    avg_monthly_hrs department  filed_complaint  last_evaluation  n_projects  \
# 0 246.000000        NaN         nan            0.866838          6
# 1 134.000000        NaN         nan            0.555718          2
# 2 156.000000        D00-SS    1.000000         0.474082          2
# 3 256.000000        D00-SP      nan            0.961360          6
# 4 146.000000        D00-SS      nan            0.507349          2
#
#    recently_promoted  salary  satisfaction status   tenure  employee_id  age  \
# 0   nan               medium 0.134415       Left  4.000000  124467       42
# 1   nan               low    0.511041       Left  3.000000  112210       23
# 2   nan               medium 0.405101       Left  3.000000  126150       24
# 3   nan               low    0.152974       Left  4.000000  125346       51
# 4   nan               medium 0.434845       Left  3.000000  113707       23
#
#    gender marital_status
# 0  Female  Married
# 1  Female  Unmarried
# 2  Female  Unmarried
# 3  Female  Married
# 4  Female  Unmarried

# %%
final_data.shape
# Out:
# (14116, 14)

# %%
final_data.nunique()
# Out:
# avg_monthly_hrs      249
# department           11
# filed_complaint      1
# last_evaluation      12184
# n_projects           7
# recently_promoted    1
# salary               3
# satisfaction         13492
# status               2
# tenure               8
# employee_id          14116
# age                  36
# gender               2
# marital_status       2
# dtype: int64

# %%
final_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 14116 entries, 0 to 14115
# Data columns (total 14 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   avg_monthly_hrs    14116 non-null  float64
#  1   department         13410 non-null  object
#  2   filed_complaint    2041 non-null   float64
#  3   last_evaluation    12629 non-null  float64
#  4   n_projects         14116 non-null  int64
#  5   recently_promoted  297 non-null    float64
#  6   salary             14116 non-null  object
#  7   satisfaction       13966 non-null  float64
#  8   status             14116 non-null  object
#  9   tenure             13966 non-null  float64
#  10  employee_id        14116 non-null  int64
#  11  age                14116 non-null  int64
#  12  gender             14116 non-null  object
#  13  marital_status     14116 non-null  object
# dtypes: float64(6), int64(3), object(5)
# memory usage: 1.6+ MB

# %% [markdown]
# - The missing values in some of the variables in merged dataset needs to be filled for further analysis.

# %% [markdown]
# ###  Challenge-4: Missing Value Treatment

# %%
null_data = pd.DataFrame(final_data.isnull().sum(), columns = ['Frequency'])
null_data.transpose()
# Out:
#            avg_monthly_hrs  department  filed_complaint  last_evaluation  \
# Frequency  0                706         12075            1487
#
#            n_projects  recently_promoted  salary  satisfaction  status  \
# Frequency  0           13819              0       150           0
#
#            tenure  employee_id  age  gender  marital_status
# Frequency  150     0            0    0       0

# %% [markdown]
# #### For null values in 'Department':
#
#  We can consider null value present in Department as Unknown Department and will replace the null value with **D00-UN**.

# %%
final_data['department'] = final_data['department'].replace(np.NaN,'D00-UN')

# %%
final_data.department.value_counts()
# Out:
# D00-SS     3895
# D00-ENG    2573
# D00-SP     2108
# D00-IT     1359
# D00-PD     853
# D00-MT     812
# D00-FN     722
# D00-UN     706
# D00-MN     590
# D00-AD     175
# D00-PR     173
# D00-TP     150
# Name: department, dtype: int64

# %% [markdown]
# #### For null values in Filed Complaint:

# %%
final_data.filed_complaint.value_counts()
# Out:
# 1.000000    2041
# Name: filed_complaint, dtype: int64

# %% [markdown]
# - 1 indicates that the employee has given complaint.
# - So the remaining data which means employees have not given complaint. Hence we will replace the NAN values with zero.

# %% [markdown]
# #### For null values in Recently Promoted:

# %%
final_data.recently_promoted.value_counts()
# Out:
# 1.000000    297
# Name: recently_promoted, dtype: int64

# %% [markdown]
# - 1 indicates that the employee was promoted.
# - So the remaining data which indicates employees are not promoted.We will replace the NAN values with zero.

# %%
final_data[['filed_complaint','recently_promoted']] = final_data[['filed_complaint','recently_promoted']].replace(np.NaN,0)

# %% [markdown]
# #### For null values in Tenure:

# %%
final_data.tenure.value_counts()
# Out:
# 3.000000     6006
# 2.000000     3019
# 4.000000     2386
# 5.000000     1363
# 6.000000     659
# 10.000000    198
# 7.000000     180
# 8.000000     155
# Name: tenure, dtype: int64

# %%
# Replacing the NaN values in tenure with '1' to extraxt the information for the missing value
final_data['tenure'] = final_data['tenure'].replace(np.NaN,1)

# %%
df_tenure = final_data[(final_data.tenure == 1)]
df_tenure
# Out:
#        avg_monthly_hrs department  filed_complaint  last_evaluation  \
# 43    125.000000        D00-TP    0.000000           nan
# 244   124.000000        D00-TP    0.000000           nan
# 250   119.000000        D00-TP    0.000000           nan
# 412   126.000000        D00-TP    0.000000           nan
# 466   65.000000         D00-TP    0.000000           nan
# 727   139.000000        D00-TP    0.000000           nan
# 777   63.000000         D00-TP    0.000000           nan
# 911   72.000000         D00-TP    0.000000           nan
# 928   87.000000         D00-TP    0.000000           nan
# 991   68.000000         D00-TP    1.000000           nan
# 1329  74.000000         D00-TP    0.000000           nan
# 1342  67.000000         D00-TP    0.000000           nan
# 1642  129.000000        D00-TP    0.000000           nan
# 1837  124.000000        D00-TP    1.000000           nan
# 1847  69.000000         D00-TP    0.000000           nan
# 2029  82.000000         D00-TP    0.000000           nan
# 2049  49.000000         D00-TP    0.000000           nan
# 2124  98.000000         D00-TP    0.000000           nan
# 2146  76.000000         D00-TP    0.000000           nan
# 2387  120.000000        D00-TP    0.000000           nan
# 2587  84.000000         D00-TP    1.000000           nan
# 2682  138.000000        D00-TP    0.000000           nan
# 2992  130.000000        D00-TP    0.000000           nan
# 2998  90.000000         D00-TP    0.000000           nan
# 3010  81.000000         D00-TP    1.000000           nan
# 3042  127.000000        D00-TP    1.000000           nan
# 3055  117.000000        D00-TP    0.000000           nan
# 3061  70.000000         D00-TP    0.000000           nan
# 3119  120.000000        D00-TP    1.000000           nan
# 3221  101.000000        D00-TP    0.000000           nan
# 3247  131.000000        D00-TP    0.000000           nan
# 3396  110.000000        D00-TP    0.000000           nan
# 3624  135.000000        D00-TP    1.000000           nan
# 3836  100.000000        D00-TP    0.000000           nan
# 3837  103.000000        D00-TP    0.000000           nan
# 3873  118.000000        D00-TP    1.000000           nan
# 3887  125.000000        D00-TP    0.000000           nan
# 3996  60.000000         D00-TP    0.000000           nan
# 4006  73.000000         D00-TP    0.000000           nan
# 4021  135.000000        D00-TP    0.000000           nan
# 4228  81.000000         D00-TP    0.000000           nan
# 4330  123.000000        D00-TP    0.000000           nan
# 4380  136.000000        D00-TP    1.000000           nan
# 4528  83.000000         D00-TP    0.000000           nan
# 4716  136.000000        D00-TP    0.000000           nan
# 4844  99.000000         D00-TP    0.000000           nan
# 4868  115.000000        D00-TP    0.000000           nan
# 4876  54.000000         D00-TP    0.000000           nan
# 4935  120.000000        D00-TP    0.000000           nan
# 5008  100.000000        D00-TP    0.000000           nan
# 5041  81.000000         D00-TP    0.000000           nan
# 5069  56.000000         D00-TP    0.000000           nan
# 5187  125.000000        D00-TP    0.000000           nan
# 5348  128.000000        D00-TP    0.000000           nan
# 5573  84.000000         D00-TP    0.000000           nan
# 5605  112.000000        D00-TP    0.000000           nan
# 5661  84.000000         D00-TP    0.000000           nan
# 5899  71.000000         D00-TP    0.000000           nan
# 5906  127.000000        D00-TP    1.000000           nan
# 6089  133.000000        D00-TP    0.000000           nan
# 6232  69.000000         D00-TP    0.000000           nan
# 6392  75.000000         D00-TP    0.000000           nan
# 6409  70.000000         D00-TP    1.000000           nan
# 6413  82.000000         D00-TP    1.000000           nan
# 6567  138.000000        D00-TP    0.000000           nan
# 6581  87.000000         D00-TP    0.000000           nan
# 6666  49.000000         D00-TP    0.000000           nan
# 6820  67.000000         D00-TP    0.000000           nan
# 6899  100.000000        D00-TP    1.000000           nan
# 6967  111.000000        D00-TP    0.000000           nan
# 7010  116.000000        D00-TP    0.000000           nan
# 7109  125.000000        D00-TP    0.000000           nan
# 7213  52.000000         D00-TP    0.000000           nan
# 7234  124.000000        D00-TP    0.000000           nan
# 7269  127.000000        D00-TP    0.000000           nan
# 7420  72.000000         D00-TP    0.000000           nan
# 7482  89.000000         D00-TP    0.000000           nan
# 7491  124.000000        D00-TP    0.000000           nan
# 7538  117.000000        D00-TP    0.000000           nan
# 7539  133.000000        D00-TP    0.000000           nan
# 7618  126.000000        D00-TP    0.000000           nan
# 7674  66.000000         D00-TP    1.000000           nan
# 7997  85.000000         D00-TP    0.000000           nan
# 8003  114.000000        D00-TP    0.000000           nan
# 8062  78.000000         D00-TP    0.000000           nan
# 8227  127.000000        D00-TP    1.000000           nan
# 8639  126.000000        D00-TP    0.000000           nan
# 8669  67.000000         D00-TP    0.000000           nan
# 8699  114.000000        D00-TP    0.000000           nan
# 8947  129.000000        D00-TP    0.000000           nan
# 8982  69.000000         D00-TP    0.000000           nan
# 9090  78.000000         D00-TP    0.000000           nan
# 9125  95.000000         D00-TP    0.000000           nan
# 9133  123.000000        D00-TP    0.000000           nan
# 9141  99.000000         D00-TP    0.000000           nan
# 9215  82.000000         D00-TP    0.000000           nan
# 9279  101.000000        D00-TP    0.000000           nan
# 9341  92.000000         D00-TP    0.000000           nan
# 9408  96.000000         D00-TP    0.000000           nan
# 9569  112.000000        D00-TP    0.000000           nan
# 9690  80.000000         D00-TP    0.000000           nan
# 9735  104.000000        D00-TP    0.000000           nan
# 9987  91.000000         D00-TP    0.000000           nan
# 10084 97.000000         D00-TP    1.000000           nan
# 10095 87.000000         D00-TP    1.000000           nan
# 10115 134.000000        D00-TP    0.000000           nan
# 10186 91.000000         D00-TP    0.000000           nan
# 10224 93.000000         D00-TP    0.000000           nan
# 10334 121.000000        D00-TP    0.000000           nan
# 10382 100.000000        D00-TP    0.000000           nan
# 10418 67.000000         D00-TP    0.000000           nan
# 10525 131.000000        D00-TP    0.000000           nan
# 10602 66.000000         D00-TP    0.000000           nan
# 10616 54.000000         D00-TP    0.000000           nan
# 10736 80.000000         D00-TP    0.000000           nan
# 10783 136.000000        D00-TP    1.000000           nan
# 10791 130.000000        D00-TP    1.000000           nan
# 10910 121.000000        D00-TP    0.000000           nan
# 10944 84.000000         D00-TP    0.000000           nan
# 10962 90.000000         D00-TP    1.000000           nan
# 10970 84.000000         D00-TP    1.000000           nan
# 11085 87.000000         D00-TP    0.000000           nan
# 11142 68.000000         D00-TP    0.000000           nan
# 11398 93.000000         D00-TP    1.000000           nan
# 11413 92.000000         D00-TP    0.000000           nan
# 11629 72.000000         D00-TP    1.000000           nan
# 11642 108.000000        D00-TP    0.000000           nan
# 11683 102.000000        D00-TP    0.000000           nan
# 11778 128.000000        D00-TP    1.000000           nan
# 12032 95.000000         D00-TP    1.000000           nan
# 12159 81.000000         D00-TP    0.000000           nan
# 12299 115.000000        D00-TP    0.000000           nan
# 12320 111.000000        D00-TP    0.000000           nan
# 12393 111.000000        D00-TP    0.000000           nan
# 12399 96.000000         D00-TP    1.000000           nan
# 12576 110.000000        D00-TP    0.000000           nan
# 12655 143.000000        D00-TP    0.000000           nan
# 12965 76.000000         D00-TP    0.000000           nan
# 12988 123.000000        D00-TP    1.000000           nan
# 13094 95.000000         D00-TP    0.000000           nan
# 13149 100.000000        D00-TP    0.000000           nan
# 13155 124.000000        D00-TP    0.000000           nan
# 13183 55.000000         D00-TP    0.000000           nan
# 13211 122.000000        D00-TP    1.000000           nan
# 13315 88.000000         D00-TP    0.000000           nan
# 13736 122.000000        D00-TP    0.000000           nan
# 13769 49.000000         D00-TP    0.000000           nan
# 13836 97.000000         D00-TP    1.000000           nan
# 13900 132.000000        D00-TP    0.000000           nan
# 13955 116.000000        D00-TP    0.000000           nan
#
#        n_projects  recently_promoted  salary  satisfaction    status   tenure  \
# 43     3          0.000000            medium   nan          Left     1.000000
# 244    3          0.000000            low      nan          Left     1.000000
# 250    2          0.000000            medium   nan          Left     1.000000
# 412    2          0.000000            low      nan          Left     1.000000
# 466    1          0.000000            high     nan          Left     1.000000
# 727    1          0.000000            medium   nan          Left     1.000000
# 777    1          0.000000            medium   nan          Left     1.000000
# 911    1          0.000000            medium   nan          Left     1.000000
# 928    2          0.000000            medium   nan          Left     1.000000
# 991    1          0.000000            low      nan          Left     1.000000
# 1329   1          0.000000            low      nan          Left     1.000000
# 1342   1          0.000000            medium   nan          Left     1.000000
# 1642   2          0.000000            low      nan          Left     1.000000
# 1837   2          0.000000            medium   nan          Employed 1.000000
# 1847   1          0.000000            low      nan          Employed 1.000000
# 2029   1          0.000000            medium   nan          Employed 1.000000
# 2049   2          0.000000            medium   nan          Employed 1.000000
# 2124   2          0.000000            medium   nan          Employed 1.000000
# 2146   2          0.000000            medium   nan          Employed 1.000000
# 2387   2          0.000000            medium   nan          Employed 1.000000
# 2587   2          0.000000            medium   nan          Employed 1.000000
# 2682   2          0.000000            medium   nan          Employed 1.000000
# 2992   1          0.000000            medium   nan          Employed 1.000000
# 2998   1          0.000000            medium   nan          Employed 1.000000
# 3010   1          0.000000            medium   nan          Employed 1.000000
# 3042   1          0.000000            high     nan          Employed 1.000000
# 3055   1          0.000000            low      nan          Employed 1.000000
# 3061   3          0.000000            low      nan          Employed 1.000000
# 3119   2          0.000000            medium   nan          Employed 1.000000
# 3221   1          0.000000            medium   nan          Employed 1.000000
# 3247   2          0.000000            medium   nan          Employed 1.000000
# 3396   2          0.000000            medium   nan          Employed 1.000000
# 3624   2          0.000000            medium   nan          Employed 1.000000
# 3836   2          0.000000            high     nan          Employed 1.000000
# 3837   1          0.000000            low      nan          Employed 1.000000
# 3873   1          0.000000            low      nan          Employed 1.000000
# 3887   3          0.000000            low      nan          Left     1.000000
# 3996   1          0.000000            medium   nan          Employed 1.000000
# 4006   1          0.000000            low      nan          Employed 1.000000
# 4021   2          0.000000            low      nan          Employed 1.000000
# 4228   2          0.000000            medium   nan          Employed 1.000000
# 4330   1          0.000000            medium   nan          Employed 1.000000
# 4380   2          0.000000            medium   nan          Employed 1.000000
# 4528   2          0.000000            low      nan          Employed 1.000000
# 4716   2          0.000000            low      nan          Employed 1.000000
# 4844   1          0.000000            medium   nan          Employed 1.000000
# 4868   2          0.000000            medium   nan          Employed 1.000000
# 4876   1          0.000000            medium   nan          Employed 1.000000
# 4935   2          0.000000            low      nan          Employed 1.000000
# 5008   1          0.000000            medium   nan          Employed 1.000000
# 5041   1          0.000000            high     nan          Employed 1.000000
# 5069   1          0.000000            medium   nan          Employed 1.000000
# 5187   2          0.000000            medium   nan          Employed 1.000000
# 5348   2          0.000000            medium   nan          Employed 1.000000
# 5573   1          0.000000            medium   nan          Employed 1.000000
# 5605   2          0.000000            low      nan          Left     1.000000
# 5661   1          0.000000            low      nan          Employed 1.000000
# 5899   2          0.000000            low      nan          Employed 1.000000
# 5906   2          0.000000            medium   nan          Employed 1.000000
# 6089   2          0.000000            medium   nan          Employed 1.000000
# 6232   1          0.000000            medium   nan          Employed 1.000000
# 6392   1          0.000000            low      nan          Employed 1.000000
# 6409   1          0.000000            low      nan          Employed 1.000000
# 6413   3          0.000000            low      nan          Employed 1.000000
# 6567   3          0.000000            medium   nan          Employed 1.000000
# 6581   2          0.000000            low      nan          Employed 1.000000
# 6666   1          0.000000            medium   nan          Employed 1.000000
# 6820   3          0.000000            high     nan          Employed 1.000000
# 6899   1          0.000000            medium   nan          Employed 1.000000
# 6967   1          0.000000            medium   nan          Employed 1.000000
# 7010   3          0.000000            medium   nan          Employed 1.000000
# 7109   2          0.000000            low      nan          Employed 1.000000
# 7213   2          0.000000            low      nan          Employed 1.000000
# 7234   1          0.000000            medium   nan          Employed 1.000000
# 7269   2          0.000000            medium   nan          Left     1.000000
# 7420   2          0.000000            low      nan          Employed 1.000000
# 7482   2          0.000000            high     nan          Employed 1.000000
# 7491   2          0.000000            medium   nan          Employed 1.000000
# 7538   2          0.000000            medium   nan          Employed 1.000000
# 7539   2          0.000000            low      nan          Employed 1.000000
# 7618   2          0.000000            medium   nan          Employed 1.000000
# 7674   2          0.000000            low      nan          Employed 1.000000
# 7997   2          0.000000            low      nan          Employed 1.000000
# 8003   2          0.000000            low      nan          Employed 1.000000
# 8062   2          0.000000            medium   nan          Employed 1.000000
# 8227   3          0.000000            medium   nan          Left     1.000000
# 8639   2          0.000000            low      nan          Employed 1.000000
# 8669   2          0.000000            low      nan          Left     1.000000
# 8699   1          0.000000            medium   nan          Employed 1.000000
# 8947   2          0.000000            low      nan          Employed 1.000000
# 8982   2          0.000000            low      nan          Employed 1.000000
# 9090   1          0.000000            medium   nan          Employed 1.000000
# 9125   2          0.000000            low      nan          Employed 1.000000
# 9133   2          0.000000            low      nan          Employed 1.000000
# 9141   1          0.000000            low      nan          Employed 1.000000
# 9215   1          0.000000            low      nan          Employed 1.000000
# 9279   1          0.000000            low      nan          Employed 1.000000
# 9341   1          0.000000            low      nan          Employed 1.000000
# 9408   2          0.000000            medium   nan          Employed 1.000000
# 9569   2          0.000000            medium   nan          Employed 1.000000
# 9690   2          0.000000            low      nan          Employed 1.000000
# 9735   2          0.000000            medium   nan          Employed 1.000000
# 9987   2          0.000000            medium   nan          Employed 1.000000
# 10084  2          0.000000            low      nan          Employed 1.000000
# 10095  2          0.000000            medium   nan          Employed 1.000000
# 10115  2          0.000000            medium   nan          Employed 1.000000
# 10186  1          0.000000            medium   nan          Employed 1.000000
# 10224  1          0.000000            medium   nan          Employed 1.000000
# 10334  1          0.000000            medium   nan          Employed 1.000000
# 10382  2          0.000000            medium   nan          Employed 1.000000
# 10418  1          0.000000            low      nan          Employed 1.000000
# 10525  2          0.000000            low      nan          Employed 1.000000
# 10602  1          0.000000            medium   nan          Employed 1.000000
# 10616  1          0.000000            high     nan          Employed 1.000000
# 10736  1          0.000000            low      nan          Employed 1.000000
# 10783  2          0.000000            low      nan          Employed 1.000000
# 10791  2          0.000000            low      nan          Employed 1.000000
# 10910  2          0.000000            medium   nan          Employed 1.000000
# 10944  2          0.000000            low      nan          Employed 1.000000
# 10962  2          0.000000            medium   nan          Employed 1.000000
# 10970  1          0.000000            medium   nan          Employed 1.000000
# 11085  1          0.000000            medium   nan          Employed 1.000000
# 11142  1          0.000000            low      nan          Employed 1.000000
# 11398  2          0.000000            low      nan          Employed 1.000000
# 11413  1          0.000000            medium   nan          Employed 1.000000
# 11629  2          0.000000            medium   nan          Employed 1.000000
# 11642  2          0.000000            low      nan          Employed 1.000000
# 11683  2          0.000000            low      nan          Employed 1.000000
# 11778  1          0.000000            low      nan          Employed 1.000000
# 12032  1          0.000000            high     nan          Employed 1.000000
# 12159  1          0.000000            low      nan          Employed 1.000000
# 12299  2          0.000000            high     nan          Employed 1.000000
# 12320  2          0.000000            low      nan          Employed 1.000000
# 12393  2          0.000000            medium   nan          Left     1.000000
# 12399  1          0.000000            medium   nan          Employed 1.000000
# 12576  1          0.000000            low      nan          Employed 1.000000
# 12655  2          0.000000            low      nan          Employed 1.000000
# 12965  2          0.000000            low      nan          Employed 1.000000
# 12988  2          0.000000            low      nan          Employed 1.000000
# 13094  3          0.000000            medium   nan          Employed 1.000000
# 13149  2          0.000000            low      nan          Employed 1.000000
# 13155  1          0.000000            low      nan          Employed 1.000000
# 13183  1          0.000000            medium   nan          Employed 1.000000
# 13211  1          0.000000            low      nan          Employed 1.000000
# 13315  1          0.000000            medium   nan          Employed 1.000000
# 13736  2          0.000000            medium   nan          Employed 1.000000
# 13769  2          0.000000            low      nan          Employed 1.000000
# 13836  1          0.000000            medium   nan          Employed 1.000000
# 13900  2          0.000000            medium   nan          Left     1.000000
# 13955  2          0.000000            low      nan          Employed 1.000000
#
#        employee_id  age  gender marital_status
# 43     120360       24   Female  Unmarried
# 244    116012       25   Female  Unmarried
# 250    116287       22   Female  Unmarried
# 412    115235       24   Female  Unmarried
# 466    122769       24   Female  Unmarried
# 727    123723       24   Female  Unmarried
# 777    120313       23   Female  Unmarried
# 911    111561       22   Female  Unmarried
# 928    115104       23   Female  Unmarried
# 991    129361       25   Female  Unmarried
# 1329   116522       22   Female  Unmarried
# 1342   116237       49   Male    Married
# 1642   128152       23   Female  Unmarried
# 1837   118850       28   Male    Unmarried
# 1847   113076       25   Male    Unmarried
# 2029   103832       26   Male    Unmarried
# 2049   118113       25   Female  Unmarried
# 2124   105562       22   Female  Unmarried
# 2146   113260       28   Male    Unmarried
# 2387   101232       25   Female  Unmarried
# 2587   109239       22   Male    Unmarried
# 2682   109306       22   Male    Unmarried
# 2992   113583       23   Male    Unmarried
# 2998   113569       24   Male    Unmarried
# 3010   110057       25   Female  Unmarried
# 3042   145421       23   Male    Unmarried
# 3055   110325       28   Male    Unmarried
# 3061   108875       26   Male    Unmarried
# 3119   109219       24   Female  Unmarried
# 3221   107352       29   Male    Unmarried
# 3247   100663       25   Male    Unmarried
# 3396   113843       25   Male    Unmarried
# 3624   113190       22   Female  Unmarried
# 3836   107688       26   Male    Unmarried
# 3837   100657       27   Male    Unmarried
# 3873   113354       25   Female  Unmarried
# 3887   116526       29   Male    Unmarried
# 3996   119708       23   Male    Unmarried
# 4006   109936       23   Male    Unmarried
# 4021   102532       27   Male    Unmarried
# 4228   135029       22   Male    Unmarried
# 4330   110052       22   Female  Unmarried
# 4380   100530       22   Male    Unmarried
# 4528   110887       29   Male    Unmarried
# 4716   108761       25   Male    Unmarried
# 4844   115241       24   Male    Unmarried
# 4868   110532       25   Female  Unmarried
# 4876   110179       25   Male    Unmarried
# 4935   103586       29   Male    Unmarried
# 5008   114407       28   Male    Unmarried
# 5041   106779       23   Female  Unmarried
# 5069   119516       25   Male    Unmarried
# 5187   100669       24   Male    Unmarried
# 5348   117472       24   Male    Unmarried
# 5573   115629       26   Male    Unmarried
# 5605   147737       23   Female  Unmarried
# 5661   104071       27   Male    Unmarried
# 5899   114815       27   Male    Unmarried
# 5906   113427       25   Male    Unmarried
# 6089   104183       23   Male    Unmarried
# 6232   100505       29   Male    Unmarried
# 6392   104686       23   Female  Unmarried
# 6409   114927       25   Male    Unmarried
# 6413   103726       24   Male    Unmarried
# 6567   100496       22   Male    Unmarried
# 6581   133310       24   Female  Unmarried
# 6666   115448       29   Male    Unmarried
# 6820   119518       25   Female  Unmarried
# 6899   110623       25   Male    Unmarried
# 6967   117606       22   Female  Unmarried
# 7010   106769       26   Male    Unmarried
# 7109   114484       23   Male    Unmarried
# 7213   107672       26   Male    Unmarried
# 7234   146260       22   Female  Unmarried
# 7269   119737       28   Male    Unmarried
# 7420   119726       23   Male    Unmarried
# 7482   118148       22   Male    Unmarried
# 7491   116521       22   Male    Unmarried
# 7538   106586       24   Male    Unmarried
# 7539   107111       26   Male    Unmarried
# 7618   107164       24   Female  Unmarried
# 7674   104687       24   Male    Unmarried
# 7997   109227       26   Male    Unmarried
# 8003   105667       26   Male    Unmarried
# 8062   109298       24   Male    Unmarried
# 8227   107852       23   Male    Unmarried
# 8639   101419       25   Male    Unmarried
# 8669   115051       24   Male    Unmarried
# 8699   105784       25   Female  Unmarried
# 8947   105586       23   Male    Unmarried
# 8982   118241       27   Male    Unmarried
# 9090   114529       27   Male    Unmarried
# 9125   106103       25   Female  Unmarried
# 9133   105176       29   Male    Unmarried
# 9141   100446       23   Female  Unmarried
# 9215   119484       27   Male    Unmarried
# 9279   106215       26   Male    Unmarried
# 9341   104021       23   Female  Unmarried
# 9408   113803       27   Male    Unmarried
# 9569   119165       23   Male    Unmarried
# 9690   118081       27   Male    Unmarried
# 9735   132628       23   Male    Unmarried
# 9987   119185       29   Male    Unmarried
# 10084  130345       23   Female  Unmarried
# 10095  113869       23   Male    Unmarried
# 10115  100987       28   Male    Unmarried
# 10186  119290       23   Female  Unmarried
# 10224  108370       24   Male    Unmarried
# 10334  108944       24   Male    Unmarried
# 10382  103063       24   Female  Unmarried
# 10418  110970       25   Male    Unmarried
# 10525  109047       25   Female  Unmarried
# 10602  116041       29   Male    Unmarried
# 10616  118489       23   Male    Unmarried
# 10736  109922       27   Male    Unmarried
# 10783  141656       22   Male    Unmarried
# 10791  114506       28   Male    Unmarried
# 10910  119956       26   Male    Unmarried
# 10944  114612       24   Male    Unmarried
# 10962  100849       27   Male    Unmarried
# 10970  117235       26   Male    Unmarried
# 11085  111504       24   Female  Unmarried
# 11142  100247       25   Male    Unmarried
# 11398  110797       24   Male    Unmarried
# 11413  102456       25   Female  Unmarried
# 11629  115750       23   Female  Unmarried
# 11642  108823       29   Male    Unmarried
# 11683  108020       22   Male    Unmarried
# 11778  114063       29   Male    Unmarried
# 12032  102702       24   Male    Unmarried
# 12159  112925       26   Male    Unmarried
# 12299  113310       24   Male    Unmarried
# 12320  104255       26   Male    Unmarried
# 12393  117523       29   Male    Unmarried
# 12399  105801       26   Male    Unmarried
# 12576  117798       22   Female  Unmarried
# 12655  116311       27   Male    Unmarried
# 12965  110042       29   Male    Unmarried
# 12988  105253       25   Female  Unmarried
# 13094  102453       25   Female  Unmarried
# 13149  108924       24   Male    Unmarried
# 13155  108546       25   Female  Unmarried
# 13183  109096       27   Male    Unmarried
# 13211  108289       22   Male    Unmarried
# 13315  100881       26   Male    Unmarried
# 13736  111990       23   Male    Unmarried
# 13769  148021       23   Male    Unmarried
# 13836  116171       29   Male    Unmarried
# 13900  106482       27   Male    Unmarried
# 13955  105231       23   Male    Unmarried

# %%
df_tenure.filed_complaint.value_counts()
# Out:
# 0.000000    121
# 1.000000    29
# Name: filed_complaint, dtype: int64

# %%
df_tenure.age.value_counts()
# Out:
# 25    27
# 23    27
# 24    25
# 22    19
# 26    16
# 29    14
# 27    14
# 28    7
# 49    1
# Name: age, dtype: int64

# %%
df_tenure.marital_status.value_counts()
# Out:
# Unmarried    149
# Married      1
# Name: marital_status, dtype: int64

# %%
df_tenure.department.value_counts()
# Out:
# D00-TP    150
# Name: department, dtype: int64

# %% [markdown]
# From the above information, we can infer that 150 observations of null value in Tenure column are,
#
# - All belong to same department ie.Temporary
# - 149 are Unmarried
# - All are Young age group, hence considered as experience of less than a year and therefore imputing with value '1' is justified.

# %% [markdown]
# #### For null values in Satisfaction

# %% [markdown]
# - All 150 Missing vaues belong to tenure=1 category
# - We can replace the missing values with '0' value because this belongs to the newly recruited emplyees.

# %%
final_data['satisfaction'] = final_data['satisfaction'].replace(np.NaN,0)

# %% [markdown]
# #### For null values in Last Evaluation

# %% [markdown]
# - We can replace the missing values with mean values of the respective departments.

# %%
# Calculating the mean of last_evaluation for each department, 
means = final_data.groupby('department')['last_evaluation'].mean()
# Convert pandas series to dictionary
dd=means.to_dict()

# %%
means
# Out:
# department
# D00-AD    0.726187
# D00-ENG   0.722725
# D00-FN    0.724704
# D00-IT    0.719525
# D00-MN    0.729070
# D00-MT    0.714934
# D00-PD    0.719523
# D00-PR    0.699205
# D00-SP    0.723170
# D00-SS    0.710672
# D00-TP      nan
# D00-UN    0.717679
# Name: last_evaluation, dtype: float64

# %%
# replacing the null values of last_evaluation with mean of that department.
final_data.last_evaluation = final_data.last_evaluation.fillna(final_data.department.map(dd))

# %%
final_data.last_evaluation.value_counts().count()
# Out:
# 12195

# %%
# Replacing the NaN value present in 'last_evaluation' column of department ID: D00-TP with Zeros(0)
final_data['last_evaluation'] = final_data['last_evaluation'].fillna(0)

# %%
final_data.last_evaluation.value_counts().count()
# Out:
# 12196

# %%
# Cross-checking that there are no null values in each column
null_data1 = pd.DataFrame(final_data.isnull().sum(), columns = ['Frequency'])
null_data1.transpose()
# Out:
#            avg_monthly_hrs  department  filed_complaint  last_evaluation  \
# Frequency  0                0           0                0
#
#            n_projects  recently_promoted  salary  satisfaction  status  \
# Frequency  0           0                  0       0             0
#
#            tenure  employee_id  age  gender  marital_status
# Frequency  0       0            0    0       0

# %%
# Type casting the relevant columns of float to integer
final_data = final_data.astype({'filed_complaint':'int64','recently_promoted':'int64','tenure':'int64','age':'int64' })

# %%
final_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 14116 entries, 0 to 14115
# Data columns (total 14 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   avg_monthly_hrs    14116 non-null  float64
#  1   department         14116 non-null  object
#  2   filed_complaint    14116 non-null  int64
#  3   last_evaluation    14116 non-null  float64
#  4   n_projects         14116 non-null  int64
#  5   recently_promoted  14116 non-null  int64
#  6   salary             14116 non-null  object
#  7   satisfaction       14116 non-null  float64
#  8   status             14116 non-null  object
#  9   tenure             14116 non-null  int64
#  10  employee_id        14116 non-null  int64
#  11  age                14116 non-null  int64
#  12  gender             14116 non-null  object
#  13  marital_status     14116 non-null  object
# dtypes: float64(3), int64(6), object(5)
# memory usage: 1.6+ MB

# %%
final_data.head()
# Out:
#    avg_monthly_hrs department  filed_complaint  last_evaluation  n_projects  \
# 0 246.000000        D00-UN     0               0.866838          6
# 1 134.000000        D00-UN     0               0.555718          2
# 2 156.000000        D00-SS     1               0.474082          2
# 3 256.000000        D00-SP     0               0.961360          6
# 4 146.000000        D00-SS     0               0.507349          2
#
#    recently_promoted  salary  satisfaction status  tenure  employee_id  age  \
# 0  0                  medium 0.134415       Left   4       124467       42
# 1  0                  low    0.511041       Left   3       112210       23
# 2  0                  medium 0.405101       Left   3       126150       24
# 3  0                  low    0.152974       Left   4       125346       51
# 4  0                  medium 0.434845       Left   3       113707       23
#
#    gender marital_status
# 0  Female  Married
# 1  Female  Unmarried
# 2  Female  Unmarried
# 3  Female  Married
# 4  Female  Unmarried

# %%
final_data.shape
# Out:
# (14116, 14)

# %% [markdown]
# ##  Exploratory Data Analysis

# %% [markdown]
# ###  Employee Status Analysis

# %%
print(final_data[['employee_id','status']].groupby('status').nunique())

figure = plt.figure(figsize = [12, 6])
colors_list = ['#FFA15A','#666699']

# Bar Plot
plt.subplot(1, 2, 1)
ax = sns.barplot(final_data['status'].value_counts().index, final_data['status'].value_counts(), palette  = colors_list)
plt.xlabel('Employee Status', size = 14)
plt.ylabel('Frequency', size = 14)
plt.title('Frequency Occurence', y=1.02, size = 14)

# Pie Plot

plt.subplot(1, 2, 2)
final_data['status'].value_counts().plot(kind = 'pie', figsize = [12, 6], autopct = '%1.1f%%', startangle = 90, 
                                     shadow = True, labels = None, pctdistance = 1.2, colors = colors_list)
plt.title('Proportion', y = 1.02, size = 14)
plt.ylabel('')
plt.axis('equal')
plt.legend(labels = final_data['status'].value_counts().index, bbox_to_anchor=(1.25,1.025),loc = 'center right')
plt.suptitle(t = 'Frequency & Proportion of Employee Status', y = 1.05, size = 14)
plt.tight_layout(pad = 1.0)
plt.show()
# Out:
#           employee_id
# status
# Employed  10761
# Left      3355

# %% [markdown]
# - We can see out of 14116 employees 3355 had left the organization and 10761 are currently employed. The no. of employee left is 24% of the total employment.

# %%
emp_status = final_data.groupby('status')
emp_left = emp_status.get_group('Left')
emp_employed = emp_status.get_group('Employed')

# %%
emp_left.mean()
# Out:
# avg_monthly_hrs     206.688227
# filed_complaint     0.045306
# last_evaluation     0.725455
# n_projects          3.837258
# recently_promoted   0.005365
# satisfaction        0.445077
# tenure              3.851863
# employee_id         115522.503428
# age                 31.973770
# dtype: float64

# %%
emp_employed.mean()
# Out:
# avg_monthly_hrs     197.905120
# filed_complaint     0.175541
# last_evaluation     0.706106
# n_projects          3.759223
# recently_promoted   0.025927
# satisfaction        0.667609
# tenure              3.352477
# employee_id         111060.050739
# age                 33.183533
# dtype: float64

# %% [markdown]
# Observations from the above stats:
#
# - Employees who left had higher number of average working hours per month
# - Average age of employees who left is younger in comparison to those still employed
# - Average value of satisfaction of those who left is lower that of those still employed
# - Average of employees last promoted among those left is less compared to those still employed
# - Average number of projects worked upon by both who left and still employed remains almost the same
# - Employees who left had worked for more number of years than those still employed

# %%
final_data.pivot_table('employee_id', index='age', columns='status',aggfunc='count')
# Out:
# status   Employed       Left
# age
# 22     800.000000 366.000000
# 23     814.000000 382.000000
# 24     935.000000 373.000000
# 25     874.000000 372.000000
# 26     504.000000 122.000000
# 27     522.000000 140.000000
# 28     523.000000 124.000000
# 29     536.000000 124.000000
# 30     224.000000 51.000000
# 31     177.000000 48.000000
# 32     223.000000 54.000000
# 33     220.000000 59.000000
# 34     201.000000 42.000000
# 35     220.000000 41.000000
# 36     218.000000 51.000000
# 37     225.000000 59.000000
# 38     224.000000 45.000000
# 39     223.000000 47.000000
# 40     228.000000 43.000000
# 41     219.000000 50.000000
# 42     253.000000 50.000000
# 43     220.000000 45.000000
# 44     188.000000 62.000000
# 45     212.000000 52.000000
# 46     214.000000 57.000000
# 47     224.000000 54.000000
# 48     221.000000 51.000000
# 49     195.000000 48.000000
# 50     181.000000 52.000000
# 51     175.000000 52.000000
# 52     211.000000 41.000000
# 53     186.000000 49.000000
# 54     171.000000 55.000000
# 55       nan      38.000000
# 56       nan      22.000000
# 57       nan      34.000000

# %%
plt.figure(figsize=(15,5))
sns.countplot(x='age', hue='status', data = final_data)
# Out:
# <AxesSubplot:xlabel='age', ylabel='count'>

# %% [markdown]
# - The details indicate : unmarried, young employees leaving the organisation is higher among the total employees Left the Organization.

# %% [markdown]
# ### Gender wise data analysis

# %%
print(final_data.gender.value_counts())
sns.countplot(x='gender',data=final_data)
# Out:
# Male      9287
# Female    4829
# Name: gender, dtype: int64
# <AxesSubplot:xlabel='gender', ylabel='count'>

# %%
pd.crosstab(final_data['status'],final_data['gender'],margins=True).sort_values('All')
# Out:
# gender    Female  Male    All
# status
# Left      1495    1860  3355
# Employed  3334    7427  10761
# All       4829    9287  14116

# %%
sns.countplot(x='gender',data=final_data,hue='status')
# Out:
# <AxesSubplot:xlabel='gender', ylabel='count'>

# %%
pd.crosstab(final_data['age'],final_data['gender'],margins=True).sort_values('All')
# Out:
# gender  Female  Male    All
# age
# 56      0       22    22
# 57      0       34    34
# 55      0       38    38
# 31      70      155   225
# 54      73      153   226
# 51      59      168   227
# 50      53      180   233
# 53      74      161   235
# 49      68      175   243
# 34      77      166   243
# 44      77      173   250
# 52      70      182   252
# 35      74      187   261
# 45      73      191   264
# 43      78      187   265
# 36      80      189   269
# 38      77      192   269
# 41      84      185   269
# 39      65      205   270
# 46      80      191   271
# 40      90      181   271
# 48      80      192   272
# 30      77      198   275
# 32      84      193   277
# 47      89      189   278
# 33      90      189   279
# 37      70      214   284
# 42      95      208   303
# 26      77      549   626
# 28      87      560   647
# 29      80      580   660
# 27      77      585   662
# 22      635     531   1166
# 23      613     583   1196
# 25      651     595   1246
# 24      702     606   1308
# All     4829    9287  14116

# %%
plt.figure(figsize = [12, 6])
sns.countplot(x='age',data=final_data,hue='gender',palette='Set2')
# sns.countplot(x='age',data=final_data,hue=['gender','marital_status'],palette='Set2')
# Out:
# <AxesSubplot:xlabel='age', ylabel='count'>

# %%
as_fig = sns.FacetGrid(final_data,hue='gender',aspect=5)
as_fig.map(sns.kdeplot,'age')
oldest = final_data['age'].max()
as_fig.set(xlim=(0,oldest))
as_fig.add_legend()
plt.title("Gender Vs Age Distribution")
# Out:
# Text(0.5, 1.0, 'Gender Vs Age Distribution')

# %% [markdown]
# - Female Employees are more than Male in the age group of 22 to 25 years.

# %%
pd.crosstab(final_data['marital_status'],final_data['gender'],margins=True).sort_values('All')
# Out:
# gender          Female  Male    All
# marital_status
# Married         2197    4708  6905
# Unmarried       2632    4579  7211
# All             4829    9287  14116

# %%
plt.figure(figsize = [10, 5])
sns.countplot(x='marital_status',data=final_data,hue='gender')
# Out:
# <AxesSubplot:xlabel='marital_status', ylabel='count'>

# %%
plt.figure(figsize = [15, 8])
sns.catplot(x="age", y='avg_monthly_hrs', hue="marital_status",
            col="status", aspect=1.5,
            kind="swarm", data=final_data[(final_data.gender == 'Male')])

# %%
plt.figure(figsize = [15, 8])
sns.catplot(x="age", y='avg_monthly_hrs', hue="marital_status",
            col="status", aspect=1.5,
            kind="swarm", data=final_data[(final_data.gender == 'Female')])

# %% [markdown]
# - For unmarried male left employees, one cluster is seen at around 150hours of avg_monthly_hrs
# - For unmarried female left employees, two clusters are seen with respect to avg_monthly_hrs, one higher (around 250hours) and another lower (around 150hours)

# %%
plt.figure(figsize = [15, 8])
sns.catplot(x="gender", y='age', hue="marital_status",
            col="status", aspect=1.2,
            kind="swarm", data=final_data)

# %% [markdown]
# - In company, the maximum age of unmarried female is 25 and for male is 29.

# %%
pd.crosstab(final_data['department'],final_data['gender'],margins=True).sort_values('All')
# Out:
# gender      Female  Male    All
# department
# D00-TP      44      106   150
# D00-PR      55      118   173
# D00-AD      55      120   175
# D00-MN      196     394   590
# D00-UN      253     453   706
# D00-FN      236     486   722
# D00-MT      271     541   812
# D00-PD      285     568   853
# D00-IT      493     866   1359
# D00-SP      700     1408  2108
# D00-ENG     880     1693  2573
# D00-SS      1361    2534  3895
# All         4829    9287  14116

# %%
plt.figure(figsize = [15, 6])
sns.countplot(x='department',data=final_data,hue='gender',palette='Set1')
# Out:
# <AxesSubplot:xlabel='department', ylabel='count'>

# %% [markdown]
# - It appears that ratio of male to female is almost same accross all departments.

# %%
pd.crosstab(final_data['salary'],final_data['gender'],margins=True).sort_values('All')
# Out:
# gender  Female  Male    All
# salary
# high    360     781   1141
# medium  2059    4027  6086
# low     2410    4479  6889
# All     4829    9287  14116

# %%
plt.figure(figsize = [12, 5])
sns.countplot(x='salary',data=final_data,hue='gender',palette='Set2_r')
# Out:
# <AxesSubplot:xlabel='salary', ylabel='count'>

# %% [markdown]
# - In the company, the ratio of male to female is almost same accross the three salary categories.

# %%
print(final_data.pivot_table('employee_id', index='recently_promoted', columns='gender',aggfunc='count'))
# Out:
# gender             Female  Male
# recently_promoted
# 0                  4739    9080
# 1                  90      207

# %%
plt.figure(figsize = [12, 5])
sns.countplot(x='recently_promoted',data=final_data,hue='gender',palette='Set3_r')
# Out:
# <AxesSubplot:xlabel='recently_promoted', ylabel='count'>

# %% [markdown]
# - As the recently promoted employees are very less, any insight could not be infered.

# %%
print(final_data.pivot_table('employee_id', index='tenure', columns='gender',aggfunc='count'))
# Out:
# gender  Female  Male
# tenure
# 1       44      106
# 2       941     2078
# 3       2105    3901
# 4       845     1541
# 5       520     843
# 6       233     426
# 7       49      131
# 8       43      112
# 10      49      149

# %%
plt.figure(figsize = [12, 5])
sns.countplot(x='tenure',data=final_data,hue='gender',palette='Set1_r')
# Out:
# <AxesSubplot:xlabel='tenure', ylabel='count'>

# %% [markdown]
# - In the company, the ratio of male to female is almost same accross the category 'tenure' and most of the emplyees are of tenure= 2 to 4 years.

# %%
a= final_data.query("gender == 'Male'")
a.groupby('age')['department'].value_counts().unstack().plot(kind='bar',cmap='Set1',
                                                               figsize=(12,8),stacked=True)
# Out:
# <AxesSubplot:xlabel='age'>

# %%
a= final_data.query("gender == 'Female'")
a.groupby('age')['department'].value_counts().unstack().plot(kind='bar',cmap='Set2',
                                                               figsize=(12,8),stacked=True)
# Out:
# <AxesSubplot:xlabel='age'>

# %% [markdown]
# - Most of the male employees are in the age group 22 to 29.
# - In females, most of the employees are in the age group 22-25.

# %% [markdown]
# ###  Age wise data analysis

# %%
plt.figure(figsize=(15,5))
final_data.groupby('age').employee_id.nunique().sort_values(ascending=False).plot(kind='bar')
plt.title('Distribution of Employees across Age')
plt.xticks(size = 12)
plt.ylabel('# Employees')
plt.legend()

# %%
as_fig = sns.FacetGrid(final_data,hue='department',aspect=5)
as_fig.map(sns.kdeplot,'age')
oldest = final_data['age'].max()
as_fig.set(xlim=(0,oldest))
as_fig.add_legend()
plt.title('Age distribution Across Departments')
# Out:
# Text(0.5, 1.0, 'Age distribution Across Departments')

# %% [markdown]
# - In Department-**Temporary**, most of the Employees belongs to the age group of 20 to 30 Years.

# %% [markdown]
# ###  Department wise Analysis

# %%
#pd.crosstab(final_data['department'],final_data['status'])
pd.crosstab(final_data['department'],final_data['status'],margins=True).sort_values('All')
# Out:
# status      Employed  Left    All
# department
# D00-TP      130       20    150
# D00-PR      157       16    173
# D00-AD      140       35    175
# D00-MN      505       85    590
# D00-UN      501       205   706
# D00-FN      529       193   722
# D00-MT      617       195   812
# D00-PD      666       187   853
# D00-IT      1062      297   1359
# D00-SP      1589      519   2108
# D00-ENG     1919      654   2573
# D00-SS      2946      949   3895
# All         10761     3355  14116

# %%
pd.crosstab(final_data.department,final_data.status).plot(kind='bar',figsize=(10,6))
# Out:
# <AxesSubplot:xlabel='department'>

# %% [markdown]
# - The above chart indicates that the highest employee attrition belonged to Sales department followed by Engineering, Support and IT departments

# %%
pd.crosstab(final_data['department'],final_data['n_projects'])
# Out:
# n_projects   1    2     3     4    5    6   7
# department
# D00-AD      0   20   50    56    32   12   5
# D00-ENG     0   384  678   742   481  233  55
# D00-FN      0   119  190   206   131  61   15
# D00-IT      0   207  380   376   276  98   22
# D00-MN      0   73   163   192   114  36   12
# D00-MT      0   146  232   237   134  50   13
# D00-PD      0   137  223   249   160  69   15
# D00-PR      0   17   61    42    34   16   3
# D00-SP      0   327  569   613   412  162  25
# D00-SS      0   680  1031  1116  701  303  64
# D00-TP      61  79   10    0     0    0    0
# D00-UN      0   133  201   215   91   53   13

# %%
pd.crosstab(final_data.department,final_data.n_projects).plot(kind='bar',figsize=(15,7))
# Out:
# <AxesSubplot:xlabel='department'>

# %% [markdown]
# - The above chart indicates that the highest number of Projects handled by the Sales department followed by Engineering and Support departments same as seen in employee attrition also.

# %% [markdown]
# ### Marital Status Analysis

# %%
emp_left['marital_status'].value_counts()
# Out:
# Unmarried    1947
# Married      1408
# Name: marital_status, dtype: int64

# %%
emp_left['gender'].value_counts()
# Out:
# Male      1860
# Female    1495
# Name: gender, dtype: int64

# %%
emp_employed['marital_status'].value_counts()
# Out:
# Married      5497
# Unmarried    5264
# Name: marital_status, dtype: int64

# %%
plt.figure(figsize=(12,6))
sns.countplot(x='marital_status', hue='status', data = final_data,palette="summer")
# Out:
# <AxesSubplot:xlabel='marital_status', ylabel='count'>

# %% [markdown]
# - The proportion of left employees are more in Unmarried category.

# %% [markdown]
# ### Tenure-wise Analysis

# %%
print(final_data[['employee_id','tenure']].groupby('tenure').nunique())
# Out:
#         employee_id
# tenure
# 1       150
# 2       3019
# 3       6006
# 4       2386
# 5       1363
# 6       659
# 7       180
# 8       155
# 10      198

# %%
plt.figure(figsize=(15,5))
sns.countplot(x='tenure',  data = final_data)
# Out:
# <AxesSubplot:xlabel='tenure', ylabel='count'>

# %%
final_data['tenure'].value_counts().plot(kind='pie',fontsize=14, autopct='%3.1f%%',figsize=(7,7), startangle=135, 
                                         cmap='Accent')
plt.legend(labels = final_data['tenure'].value_counts().index, bbox_to_anchor=(1.25,0.5),loc = 'center right')
plt.title('Pie chart showing the Tenure of Employees')
# Out:
# Text(0.5, 1.0, 'Pie chart showing the Tenure of Employees')

# %% [markdown]
# - Majority of the employees working are in the range of tenure= 2 to 4 years.

# %%
plt.figure(figsize=(15,5))
sns.countplot(x='status', hue='tenure', data = final_data)
# Out:
# <AxesSubplot:xlabel='status', ylabel='count'>

# %% [markdown]
# - Around 80% of employees have experience between 2-4 years.
# - After 3 to 5 years of working in the company, employees are leaving.

# %% [markdown]
# ### Recently Promoted wise Analysis

# %%
final_data[['employee_id','recently_promoted']].groupby('recently_promoted').nunique()
# Out:
#                    employee_id
# recently_promoted
# 0                  13819
# 1                  297

# %%
sns.countplot(x='recently_promoted',  data = final_data)
# Out:
# <AxesSubplot:xlabel='recently_promoted', ylabel='count'>

# %% [markdown]
# - Only 297 employees out of 14116 got promoted recently.

# %%
emp_left[['employee_id','recently_promoted']].groupby('recently_promoted').nunique()
# Out:
#                    employee_id
# recently_promoted
# 0                  3337
# 1                  18

# %% [markdown]
# - The above table indicates that the number of employees promoted among those who left the organisation is so small.

# %%
final_data['recently_promoted'].value_counts().plot(kind='pie',fontsize=14, autopct='%3.1f%%',figsize=(7,7), startangle=135)
plt.legend(labels = final_data['recently_promoted'].value_counts().index, bbox_to_anchor=(1.25,0.5),loc = 'center right')
plt.title('Pie chart showing the Promotion of Employees Left')
# Out:
# Text(0.5, 1.0, 'Pie chart showing the Promotion of Employees Left')

# %% [markdown]
# ### n_projects wise Analysis

# %%
sns.countplot(x='n_projects',data=final_data)
# Out:
# <AxesSubplot:xlabel='n_projects', ylabel='count'>

# %% [markdown]
# - Majority of the emplyees are working in the range of 2 to 6 projects.

# %%
sns.countplot(x="n_projects", data=emp_left)
# Out:
# <AxesSubplot:xlabel='n_projects', ylabel='count'>

# %% [markdown]
# - Majority of the emplyees who left have worked for only 2 projects.

# %% [markdown]
# ### Filed Complaint wise Analysis

# %%
final_data[['employee_id','filed_complaint']].groupby('filed_complaint').nunique()
# Out:
#                  employee_id
# filed_complaint
# 0                12075
# 1                2041

# %%
plt.figure(figsize=(12,5))
sns.countplot(x='status', hue='filed_complaint', data = final_data)
# Out:
# <AxesSubplot:xlabel='status', ylabel='count'>

# %%
emp_left[['employee_id','filed_complaint']].groupby('filed_complaint').nunique()
# Out:
#                  employee_id
# filed_complaint
# 0                3203
# 1                152

# %% [markdown]
# - Majority of the employees who had left not much complained in the last 3 years

# %%
plt.figure(figsize=(12,6))
sns.countplot(x='filed_complaint', hue='department', data = final_data)
# Out:
# <AxesSubplot:xlabel='filed_complaint', ylabel='count'>

# %% [markdown]
# - More complaints are filed in Sales department followed by Engineering department

# %% [markdown]
# ### Monthly hours worked by the employee

# %%
sns.distplot(final_data.avg_monthly_hrs)
# Out:
# <AxesSubplot:xlabel='avg_monthly_hrs'>

# %%
final_data.avg_monthly_hrs.mean()
# Out:
# 199.9926324737886

# %%
emp_left.avg_monthly_hrs.mean()
# Out:
# 206.68822652757078

# %%
emp_employed.avg_monthly_hrs.mean()
# Out:
# 197.90512034197565

# %% [markdown]
# - The employees who left have worked more hours compared to employed

# %% [markdown]
# ###  Salary wise Analysis

# %%
final_data[['employee_id','salary']].groupby('salary').nunique()
# Out:
#         employee_id
# salary
# high    1141
# low     6889
# medium  6086

# %%
ax = final_data['salary'].value_counts().plot(kind='bar', figsize=(10,7),fontsize=13);
ax.set_alpha(0.8)
ax.set_title("Distribution Of The Employee Salary", fontsize=12)
ax.set_ylabel("Frequency", fontsize=12);

totals = []

for i in ax.patches:
    totals.append(i.get_height())

total = sum(totals)

for i in ax.patches:
    ax.text(i.get_x()-.03, i.get_height()+.5, \
            str(round((i.get_height()/total)*100, 2))+'%', fontsize=15,
                color='dimgrey')

# %% [markdown]
# - Low salary category emplyees are higher in the company around 50%

# %%
emp_left[['employee_id','salary']].groupby('salary').nunique()
# Out:
#         employee_id
# salary
# high    77
# low     2038
# medium  1240

# %% [markdown]
# - Employees who left the company are mostly in the low salary category

# %% [markdown]
# ### Satisfaction and Last Evaluation wise Analysis

# %%
from sklearn.cluster import KMeans
# Filter data
left_emp =  emp_left[['satisfaction', 'last_evaluation']]
# Create groups using K-means clustering.
kmeans = KMeans(n_clusters = 3, random_state = 1).fit(left_emp)

# %%
# Add new column "label" annd assign cluster labels.
left_emp['label'] = kmeans.labels_
# Create scatter plot
plt.scatter(left_emp['satisfaction'], left_emp['last_evaluation'], c=left_emp['label'],cmap='Paired')
plt.xlabel('Satisfaction Level')
plt.ylabel('Last Evaluation Rating')
plt.title('Clusters of employees who left')
plt.show()

# %% [markdown]
# From the above clusters we can find that Employee who left the company can be grouped into 3 clusters of employees:
#
# - High Evaluation rating, but low satisfaction
# - Medium to low Evaluation rating and medium and low satisfaction
# - High Evaluation rating and high satisfaction

# %% [markdown]
# ###  Correlation b/w Features

# %%
plt.figure(figsize=(12, 8))
sns.heatmap(final_data.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ###  Pair Plot

# %%
sns.pairplot(data=final_data)

# %% [markdown]
# ## Final Dataset for Modelling

# %%
final_data.head()
# Out:
#    avg_monthly_hrs department  filed_complaint  last_evaluation  n_projects  \
# 0 246.000000        D00-UN     0               0.866838          6
# 1 134.000000        D00-UN     0               0.555718          2
# 2 156.000000        D00-SS     1               0.474082          2
# 3 256.000000        D00-SP     0               0.961360          6
# 4 146.000000        D00-SS     0               0.507349          2
#
#    recently_promoted  salary  satisfaction status  tenure  employee_id  age  \
# 0  0                  medium 0.134415       Left   4       124467       42
# 1  0                  low    0.511041       Left   3       112210       23
# 2  0                  medium 0.405101       Left   3       126150       24
# 3  0                  low    0.152974       Left   4       125346       51
# 4  0                  medium 0.434845       Left   3       113707       23
#
#    gender marital_status
# 0  Female  Married
# 1  Female  Unmarried
# 2  Female  Unmarried
# 3  Female  Married
# 4  Female  Unmarried

# %%
final_data.nunique()
# Out:
# avg_monthly_hrs      249
# department           12
# filed_complaint      2
# last_evaluation      12196
# n_projects           7
# recently_promoted    2
# salary               3
# satisfaction         13493
# status               2
# tenure               9
# employee_id          14116
# age                  36
# gender               2
# marital_status       2
# dtype: int64

# %%
final_data.shape
# Out:
# (14116, 14)

# %% [markdown]
# - "employee_id" is not needed for modelling

# %%
df_employee = final_data.drop('employee_id',1)

# %%
df_employee.shape
# Out:
# (14116, 13)

# %% [markdown]
# ## Feature Engineering

# %%
df_employee['status']= np.where(df_employee.status=='Left', 1, 0)

# %% [markdown]
# ### Encoding

# %% [markdown]
# #### Label Encoding

# %%
from sklearn.preprocessing import LabelEncoder
Label_Encoder = LabelEncoder()
Label_Encoder.fit(df_employee['department'])
df_employee['department'] = Label_Encoder.transform(df_employee['department'])

# %%
df_employee.head()
# Out:
#    avg_monthly_hrs  department  filed_complaint  last_evaluation  n_projects  \
# 0 246.000000        11          0               0.866838          6
# 1 134.000000        11          0               0.555718          2
# 2 156.000000        9           1               0.474082          2
# 3 256.000000        8           0               0.961360          6
# 4 146.000000        9           0               0.507349          2
#
#    recently_promoted  salary  satisfaction  status  tenure  age  gender  \
# 0  0                  medium 0.134415       1       4       42   Female
# 1  0                  low    0.511041       1       3       23   Female
# 2  0                  medium 0.405101       1       3       24   Female
# 3  0                  low    0.152974       1       4       51   Female
# 4  0                  medium 0.434845       1       3       23   Female
#
#   marital_status
# 0  Married
# 1  Unmarried
# 2  Unmarried
# 3  Married
# 4  Unmarried

# %% [markdown]
# #### One-Hot encoding

# %%
categorical_feature_oh=['salary','gender','marital_status']
df_employee=pd.get_dummies(df_employee,columns = categorical_feature_oh)

df_employee.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 14116 entries, 0 to 14115
# Data columns (total 17 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   avg_monthly_hrs           14116 non-null  float64
#  1   department                14116 non-null  int32
#  2   filed_complaint           14116 non-null  int64
#  3   last_evaluation           14116 non-null  float64
#  4   n_projects                14116 non-null  int64
#  5   recently_promoted         14116 non-null  int64
#  6   satisfaction              14116 non-null  float64
#  7   status                    14116 non-null  int32
#  8   tenure                    14116 non-null  int64
#  9   age                       14116 non-null  int64
#  10  salary_high               14116 non-null  uint8
#  11  salary_low                14116 non-null  uint8
#  12  salary_medium             14116 non-null  uint8
#  13  gender_Female             14116 non-null  uint8
#  14  gender_Male               14116 non-null  uint8
#  15  marital_status_Married    14116 non-null  uint8
#  16  marital_status_Unmarried  14116 non-null  uint8
# dtypes: float64(3), int32(2), int64(5), uint8(7)
# memory usage: 1.8 MB

# %% [markdown]
# ### Splitting X and y into training datasets

# %%
Y = df_employee['status']

X = df_employee.drop(['status'],axis=1)

# %%
print(X.shape)
print(Y.shape)
# Out:
# (14116, 16)
# (14116,)

# %%
from sklearn.model_selection import train_test_split

X_train,X_test,Y_train,Y_test = train_test_split(X,Y,test_size=0.2,random_state=1,stratify=Y)

# %%
print(X_train.shape)
print(Y_train.shape)
# Out:
# (11292, 16)
# (11292,)

# %%
print(X_test.shape)
print(Y_test.shape)
# Out:
# (2824, 16)
# (2824,)

# %% [markdown]
# ### Scaling

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()

X_train_sc = scaler.fit_transform(X_train)
X_test_sc = scaler.transform(X_test)

# %%
X_s = scaler.fit_transform(X)

# %% [markdown]
# ## Modeling

# %% [markdown]
# ### Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression

# %%
lr = LogisticRegression()
lr.fit(X_train_sc,Y_train)
y_test_pred_lr = lr.predict(X_test_sc)

# %%
from sklearn.metrics import accuracy_score,precision_score, recall_score, f1_score
print('Accuracy score for test data is:', accuracy_score(Y_test,y_test_pred_lr))
print('Recall: %.3f' % recall_score(Y_test,y_test_pred_lr))
print('Precision: %.3f' % precision_score(Y_test,y_test_pred_lr))
print('F1 Score: %.3f' % f1_score(Y_test,y_test_pred_lr))
# Out:
# Accuracy score for test data is: 0.7963881019830028
# Recall: 0.347
# Precision: 0.630
# F1 Score: 0.448

# %%
from sklearn.metrics import confusion_matrix
confusion_matrix = pd.DataFrame(confusion_matrix(Y_test, y_test_pred_lr))
print(confusion_matrix)
# Out:
#       0    1
# 0  2016  137
# 1  438   233

# %%
from sklearn import metrics

probs = lr.predict_proba(X_test_sc)
preds = probs[:,1]
fpr, tpr, threshold = metrics.roc_curve(Y_test, preds)
roc_auc = metrics.auc(fpr, tpr)

plt.title('Receiver Operating Characteristic')
plt.plot(fpr, tpr, 'b', label = 'AUC = %0.2f' % roc_auc)
plt.legend(loc = 'lower right')
plt.plot([0, 1], [0, 1],'r--')
plt.xlim([0, 1])
plt.ylim([0, 1])
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
plt.show()

# %% [markdown]
# ### Decision Tree Classifier

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
dtc = DecisionTreeClassifier()
dtc.fit(X_train_sc, Y_train)
y_test_pred_dtc = dtc.predict(X_test_sc)

# %%
from sklearn.metrics import accuracy_score,precision_score, recall_score, f1_score
print('Accuracy score for test data is:', accuracy_score(Y_test,y_test_pred_dtc))
print('Recall: %.3f' % recall_score(Y_test, y_test_pred_dtc))
print('Precision: %.3f' % precision_score(Y_test, y_test_pred_dtc))
print('F1 Score: %.3f' % f1_score(Y_test, y_test_pred_dtc))
# Out:
# Accuracy score for test data is: 0.9610481586402266
# Recall: 0.927
# Precision: 0.911
# F1 Score: 0.919

# %%
from sklearn.metrics import confusion_matrix
confusion_matrix = pd.DataFrame(confusion_matrix(Y_test, y_test_pred_dtc))
print(confusion_matrix)
# Out:
#       0    1
# 0  2092  61
# 1  49    622

# %% [markdown]
# ### Random Forest Classifier

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rfc=RandomForestClassifier(n_estimators=100,max_depth=7,n_jobs=-1)
rfc.fit(X_train_sc,Y_train)
y_test_pred_rfc = rfc.predict(X_test_sc)

# %%
from sklearn.metrics import accuracy_score,precision_score, recall_score, f1_score
print('Accuracy score for test data is:', accuracy_score(Y_test,y_test_pred_rfc))
print('Recall: %.3f' % recall_score(Y_test, y_test_pred_rfc))
print('Precision: %.3f' % precision_score(Y_test, y_test_pred_rfc))
print('F1 Score: %.3f' % f1_score(Y_test, y_test_pred_rfc))
# Out:
# Accuracy score for test data is: 0.9702549575070821
# Recall: 0.903
# Precision: 0.970
# F1 Score: 0.935

# %%
from sklearn.metrics import confusion_matrix
confusion_matrix = pd.DataFrame(confusion_matrix(Y_test, y_test_pred_rfc))
print(confusion_matrix)
# Out:
#       0    1
# 0  2134  19
# 1  65    606

# %% [markdown]
# ### Naive Bayes

# %%
from sklearn.naive_bayes import GaussianNB

# %%
nbc = GaussianNB()
nbc.fit(X_train_sc,Y_train)
y_test_pred_nbc = nbc.predict(X_test_sc)

# %%
from sklearn.metrics import accuracy_score,precision_score, recall_score, f1_score
print('Accuracy score for test data is:', accuracy_score(Y_test,y_test_pred_nbc))
print('Recall: %.3f' % recall_score(Y_test, y_test_pred_nbc))
print('Precision: %.3f' % precision_score(Y_test, y_test_pred_nbc))
print('F1 Score: %.3f' % f1_score(Y_test, y_test_pred_nbc))
# Out:
# Accuracy score for test data is: 0.7216713881019831
# Recall: 0.811
# Precision: 0.452
# F1 Score: 0.581

# %%
from sklearn.metrics import confusion_matrix
confusion_matrix = pd.DataFrame(confusion_matrix(Y_test, y_test_pred_nbc))
print(confusion_matrix)
# Out:
#       0    1
# 0  1494  659
# 1  127   544

# %% [markdown]
# ###  K Nearest Neighbor

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
accuracy_list = []
def generate():
    for i in range(1,30):
        knn_model_ = KNeighborsClassifier(n_neighbors = i)
        knn_model_.fit(X_train_sc, Y_train)
        pred_i = knn_model_.predict(X_test_sc)
        accuracy_list.append(accuracy_score(Y_test, pred_i))
    
    print("Maximum accuracy and the corresponding value of k is",
          max([(v,i+1) for i,v in enumerate(accuracy_list)]),'respectively.')

generate()
# Out:
# Maximum accuracy and the corresponding value of k is (0.9500708215297451, 2) respectively.

# %%
knn = KNeighborsClassifier(n_neighbors=2, p=2, metric='minkowski')

# %%
knn.fit(X_train_sc, Y_train)
# Out:
# KNeighborsClassifier(n_neighbors=2)

# %%
y_test_pred_knn = knn.predict(X_test_sc)

# %%
from sklearn.metrics import accuracy_score,precision_score, recall_score, f1_score
print('Accuracy score for test data is:', accuracy_score(Y_test,y_test_pred_knn))
print('Recall: %.3f' % recall_score(Y_test, y_test_pred_knn))
print('Precision: %.3f' % precision_score(Y_test, y_test_pred_knn))
print('F1 Score: %.3f' % f1_score(Y_test, y_test_pred_knn))
# Out:
# Accuracy score for test data is: 0.9500708215297451
# Recall: 0.863
# Precision: 0.922
# F1 Score: 0.891

# %%
from sklearn.metrics import confusion_matrix
confusion_matrix = pd.DataFrame(confusion_matrix(Y_test, y_test_pred_knn))
print(confusion_matrix)
# Out:
#       0    1
# 0  2104  49
# 1  92    579

# %% [markdown]
# ### Support Vector Machines

# %%
from sklearn.svm import SVC

# %%
svc=SVC(random_state = 0)
svc.fit(X_train_sc,Y_train)
y_test_pred_svc = svc.predict(X_test_sc)

# %%
from sklearn.metrics import accuracy_score,precision_score, recall_score, f1_score
print('Accuracy score for test data is:', accuracy_score(Y_test,y_test_pred_svc))
print('Recall: %.3f' % recall_score(Y_test, y_test_pred_svc))
print('Precision: %.3f' % precision_score(Y_test, y_test_pred_svc))
print('F1 Score: %.3f' % f1_score(Y_test, y_test_pred_svc))
# Out:
# Accuracy score for test data is: 0.9518413597733711
# Recall: 0.893
# Precision: 0.903
# F1 Score: 0.898

# %%
from sklearn.metrics import confusion_matrix
confusion_matrix = pd.DataFrame(confusion_matrix(Y_test, y_test_pred_svc))
print(confusion_matrix)
# Out:
#       0    1
# 0  2089  64
# 1  72    599

# %% [markdown]
# ### Bagging Classifier

# %%
from sklearn.ensemble import BaggingClassifier

from sklearn.tree import DecisionTreeClassifier
dtc = DecisionTreeClassifier()

model1 = BaggingClassifier(base_estimator=dtc, n_estimators=200, max_samples= 0.60 ,random_state=None) 
model1.fit(X_train_sc, Y_train)
y_test_pred_bc = model1.predict(X_test_sc)

# %%
from sklearn.metrics import accuracy_score,precision_score, recall_score, f1_score
print('Accuracy score for test data is:', accuracy_score(Y_test,y_test_pred_bc))
print('Recall: %.3f' % recall_score(Y_test, y_test_pred_bc))
print('Precision: %.3f' % precision_score(Y_test, y_test_pred_bc))
print('F1 Score: %.3f' % f1_score(Y_test, y_test_pred_bc))
# Out:
# Accuracy score for test data is: 0.9759206798866855
# Recall: 0.920
# Precision: 0.978
# F1 Score: 0.948

# %%
from sklearn.metrics import confusion_matrix
confusion_matrix = pd.DataFrame(confusion_matrix(Y_test, y_test_pred_bc))
print(confusion_matrix)
# Out:
#       0    1
# 0  2139  14
# 1  54    617

# %% [markdown]
# ### Voting Based Ensemble Technique

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.svm import SVC
from sklearn.ensemble import VotingClassifier
from sklearn import model_selection
from sklearn.model_selection import KFold

# %%
kfold = KFold(n_splits=10)

#create the sub models
estimators =[]

model1 = DecisionTreeClassifier()
estimators.append(('cart', model1))

model2 = SVC()
estimators.append(('svm', model2))

# %%
# create the ensemble model
from sklearn import model_selection
from sklearn.model_selection import cross_val_score
from sklearn.metrics import make_scorer, accuracy_score, precision_score, recall_score, f1_score

scoring = {'accuracy' : make_scorer(accuracy_score), 
           'precision' : make_scorer(precision_score),
           'recall' : make_scorer(recall_score), 
           'f1_score' : make_scorer(f1_score)}
ensemble = VotingClassifier(estimators) 

results = model_selection.cross_validate(ensemble, X_s, Y, cv=kfold,scoring=scoring)

# %%
results_df=pd.DataFrame.from_dict(results)
results_df.mean()
# Out:
# fit_time         1.255848
# score_time       0.262893
# test_accuracy    0.954669
# test_precision   0.968236
# test_recall      0.865647
# test_f1_score    0.913186
# dtype: float64

# %% [markdown]
# ### AdaBoost Classifier

# %%
from sklearn.ensemble import AdaBoostClassifier

# %%
abc = AdaBoostClassifier(n_estimators=500)
abc.fit(X_train_sc, Y_train)
y_test_pred_abc = abc.predict(X_test_sc)

# %%
from sklearn.metrics import accuracy_score,precision_score, recall_score, f1_score
print('Accuracy score for test data is:', accuracy_score(Y_test,y_test_pred_abc))
print('Recall: %.3f' % recall_score(Y_test, y_test_pred_abc))
print('Precision: %.3f' % precision_score(Y_test, y_test_pred_abc))
print('F1 Score: %.3f' % f1_score(Y_test, y_test_pred_abc))
# Out:
# Accuracy score for test data is: 0.9387393767705382
# Recall: 0.870
# Precision: 0.872
# F1 Score: 0.871

# %%
from sklearn.metrics import confusion_matrix
confusion_matrix = pd.DataFrame(confusion_matrix(Y_test, y_test_pred_abc))
print(confusion_matrix)
# Out:
#       0    1
# 0  2067  86
# 1  87    584

# %% [markdown]
# ### Gradient Boost Classifier

# %%
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.metrics import make_scorer, accuracy_score, precision_score, recall_score, f1_score

scoring = {'accuracy' : make_scorer(accuracy_score), 
           'precision' : make_scorer(precision_score),
           'recall' : make_scorer(recall_score), 
           'f1_score' : make_scorer(f1_score)}
model_gb = GradientBoostingClassifier(n_estimators=50, random_state=1, learning_rate = 0.10) 

results_gb = model_selection.cross_validate(model_gb, X_s, Y, cv=kfold, scoring=scoring)

# %%
results_gb_df=pd.DataFrame.from_dict(results_gb)
results_gb_df.mean()
# Out:
# fit_time         0.683608
# score_time       0.004052
# test_accuracy    0.960474
# test_precision   0.917168
# test_recall      0.906179
# test_f1_score    0.910682
# dtype: float64

# %% [markdown]
# ### XG Boost Classifier

# %%
from xgboost import XGBClassifier

# %%
XGB = XGBClassifier(n_estimators=100, random_state=1, learning_rate = 0.15)
XGB.fit(X_train_sc,Y_train)
y_test_pred_xgbc = XGB.predict(X_test_sc)
# Out:
# [20:58:51] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.

# %%
from sklearn.metrics import accuracy_score,precision_score, recall_score, f1_score
print('Accuracy score for test data is:', accuracy_score(Y_test,y_test_pred_xgbc))
print('Recall: %.3f' % recall_score(Y_test, y_test_pred_xgbc))
print('Precision: %.3f' % precision_score(Y_test, y_test_pred_xgbc))
print('F1 Score: %.3f' % f1_score(Y_test, y_test_pred_xgbc))
# Out:
# Accuracy score for test data is: 0.9755665722379604
# Recall: 0.925
# Precision: 0.970
# F1 Score: 0.947

# %% [markdown]
# ## Hyper Parameter Tuning

# %% [markdown]
# ### Gridsearch with Decision Tree

# %%
from sklearn.model_selection import GridSearchCV

decision_tree_classifier = DecisionTreeClassifier(random_state = 1)

tree_para = [{'criterion':['gini','entropy'],'max_depth': range(2,60),
                             'max_features': ['sqrt', 'log2', None] }]
                                                 
grid_search_dtc = GridSearchCV(decision_tree_classifier,tree_para, cv=10, refit='AUC')
grid_search_dtc.fit(X_train_sc, Y_train)
# Out:
# GridSearchCV(cv=10, estimator=DecisionTreeClassifier(random_state=1),
#              param_grid=[{'criterion': ['gini', 'entropy'],
#                           'max_depth': range(2, 60),
#                           'max_features': ['sqrt', 'log2', None]}],
#              refit='AUC')

# %%
y_test_pred_gsdtc = grid_search_dtc.predict(X_test_sc)

# %%
from sklearn.metrics import accuracy_score,precision_score, recall_score, f1_score
print('Accuracy score for test data is:', accuracy_score(Y_test,y_test_pred_gsdtc))
print('Recall: %.3f' % recall_score(Y_test, y_test_pred_gsdtc))
print('Precision: %.3f' % precision_score(Y_test, y_test_pred_gsdtc))
print('F1 Score: %.3f' % f1_score(Y_test, y_test_pred_gsdtc))
# Out:
# Accuracy score for test data is: 0.9695467422096318
# Recall: 0.915
# Precision: 0.955
# F1 Score: 0.935

# %%
from sklearn.metrics import confusion_matrix
confusion_matrix = pd.DataFrame(confusion_matrix(Y_test, y_test_pred_gsdtc))
print(confusion_matrix)
# Out:
#       0    1
# 0  2124  29
# 1  57    614

# %% [markdown]
# ### Gridsearch with Bagging Classifier

# %%
from sklearn.ensemble import BaggingClassifier
from sklearn.tree import DecisionTreeClassifier
param_grid = {
    'base_estimator__max_depth' : [1, 2, 3, 4, 5],
    'max_samples' : [0.05, 0.1, 0.2, 0.5]
}
grid_search_bc = GridSearchCV(BaggingClassifier(DecisionTreeClassifier(),
    n_estimators = 200, max_features = 0.5),
  param_grid, scoring = None)
grid_search_bc.fit(X_train_sc, Y_train)
# Out:
# GridSearchCV(estimator=BaggingClassifier(base_estimator=DecisionTreeClassifier(),
#                                          max_features=0.5, n_estimators=200),
#              param_grid={'base_estimator__max_depth': [1, 2, 3, 4, 5],
#                          'max_samples': [0.05, 0.1, 0.2, 0.5]})

# %%
y_test_pred_gsbc = grid_search_bc.predict(X_test_sc)

# %%
from sklearn.metrics import accuracy_score,precision_score, recall_score, f1_score
print('Accuracy score for test data is:', accuracy_score(Y_test,y_test_pred_gsbc))
print('Recall: %.3f' % recall_score(Y_test, y_test_pred_gsbc))
print('Precision: %.3f' % precision_score(Y_test, y_test_pred_gsbc))
print('F1 Score: %.3f' % f1_score(Y_test, y_test_pred_gsbc))
# Out:
# Accuracy score for test data is: 0.9677762039660056
# Recall: 0.885
# Precision: 0.977
# F1 Score: 0.929

# %%
from sklearn.metrics import confusion_matrix
confusion_matrix = pd.DataFrame(confusion_matrix(Y_test, y_test_pred_gsbc))
print(confusion_matrix)
# Out:
#       0    1
# 0  2139  14
# 1  77    594

# %% [markdown]
# ### RandomizedsearchCV with Random Forest

# %%
model_rfcv = RandomForestClassifier(n_estimators=100, max_samples= 0.60 ,random_state=1)

# %%
from sklearn.model_selection import RandomizedSearchCV
from scipy.stats import randint as sp_randint
# parameters for GridSearchCV
# specify parameters and distributions to sample from
param_dist = {"max_depth": range(2,5),
              "min_samples_split": sp_randint(2, 11),
              "min_samples_leaf": sp_randint(1, 11),
              "bootstrap": [True, False],
              "n_estimators": [100, 400, 700, 1000, 1500],
              "criterion" : ["gini", "entropy"],
              'max_features': ['sqrt', 'log2', None]
             }
# run randomized search
n_iter_search = 50
random_search = RandomizedSearchCV(model_rfcv, param_distributions = param_dist,
                                   n_iter = n_iter_search,
                                   n_jobs = -1)

# %%
random_search.fit(X_train_sc, Y_train)
# Out:
# RandomizedSearchCV(estimator=RandomForestClassifier(max_samples=0.6,
#                                                     random_state=1),
#                    n_iter=50, n_jobs=-1,
#                    param_distributions={'bootstrap': [True, False],
#                                         'criterion': ['gini', 'entropy'],
#                                         'max_depth': range(2, 5),
#                                         'max_features': ['sqrt', 'log2', None],
#                                         'min_samples_leaf': <scipy.stats._distn_infrastructure.rv_frozen object at 0x00000229F5A2FE20>,
#                                         'min_samples_split': <scipy.stats._distn_infrastructure.rv_frozen object at 0x00000229F59AF880>,
#                                         'n_estimators': [100, 400, 700, 1000,
#                                                          1500]})

# %%
y_pred_rfc_cv = random_search.predict(X_test_sc)

# %%
from sklearn.metrics import accuracy_score,precision_score, recall_score, f1_score
print('Accuracy score for test data is:', accuracy_score(Y_test,y_pred_rfc_cv))
print('Recall: %.3f' % recall_score(Y_test, y_pred_rfc_cv))
print('Precision: %.3f' % precision_score(Y_test, y_pred_rfc_cv))
print('F1 Score: %.3f' % f1_score(Y_test, y_pred_rfc_cv))
# Out:
# Accuracy score for test data is: 0.9553824362606232
# Recall: 0.909
# Precision: 0.904
# F1 Score: 0.906

# %%
from sklearn.metrics import confusion_matrix
confusion_matrix = pd.DataFrame(confusion_matrix(Y_test, y_pred_rfc_cv))
print(confusion_matrix)
# Out:
#       0    1
# 0  2088  65
# 1  61    610

# %% [markdown]
# ### Support Vector Classifier

# %%
from sklearn.svm import SVC
from sklearn.model_selection import GridSearchCV
Cs = [0.00001,0.0001,0.001,0.01,0.1,1,10]
gammas=[0.0001,0.001,0.01,0.1,1]

param_grid = {'C': Cs,'gamma':gammas}
grid_search = GridSearchCV(SVC(), param_grid, cv=10)
grid_search.fit(X_train_sc,Y_train)
grid_search.best_params_
# Out:
# {'C': 10, 'gamma': 1}

# %%
model=SVC(C=10,gamma=1)

# %%
model.fit(X_train_sc,Y_train)
# Out:
# SVC(C=10, gamma=1)

# %%
y_pred_svc_cv = model.predict(X_test_sc)

# %%
from sklearn.metrics import accuracy_score,precision_score, recall_score, f1_score
print('Accuracy score for test data is:', accuracy_score(Y_test,y_pred_svc_cv))
print('Recall: %.3f' % recall_score(Y_test, y_pred_svc_cv))
print('Precision: %.3f' % precision_score(Y_test, y_pred_svc_cv))
print('F1 Score: %.3f' % f1_score(Y_test, y_pred_svc_cv))
# Out:
# Accuracy score for test data is: 0.9621104815864022
# Recall: 0.882
# Precision: 0.955
# F1 Score: 0.917

# %%
from sklearn.metrics import confusion_matrix
confusion_matrix = pd.DataFrame(confusion_matrix(Y_test, y_pred_svc_cv))
print(confusion_matrix)
# Out:
#       0    1
# 0  2125  28
# 1  79    592

# %% [markdown]
# ## Fit & Tune Models with Cross validation

# %% [markdown]
# ### Logistic Regression

# %%
from sklearn import model_selection
kfold = model_selection.KFold(n_splits=10,shuffle=True,random_state=2)
modelLR = LogisticRegression()
results = model_selection.cross_val_score(modelLR, X_train_sc, Y_train, cv=kfold, scoring='accuracy')
print("10-fold cross validation average Accuracy score for Logistic Regression: %.3f" % (results.mean()))
# Out:
# 10-fold cross validation average Accuracy score for Logistic Regression: 0.795

# %%
results = model_selection.cross_val_score(modelLR, X_test_sc, Y_test, cv=kfold, scoring= 'roc_auc')
print("10-fold cross validation average roc_auc score for Logistic Regression: %.3f" % (results.mean()))
# Out:
# 10-fold cross validation average roc_auc score for Logistic Regression: 0.835

# %% [markdown]
# ### Support Vector Classifier

# %%
from sklearn.model_selection import cross_val_score

svc = SVC(kernel='rbf',random_state = 0)
scores = cross_val_score(svc,X_s, Y, cv=10, scoring='accuracy') 
print(scores.mean())
# Out:
# 0.9483569505484025

# %%
'''kfold = model_selection.KFold(n_splits=10,shuffle=True,random_state=7)

modelCV = RandomForestClassifier()
scoring = 'accuracy'
results = model_selection.cross_val_score(modelCV, X_train, Y_train, cv=kfold, scoring=scoring)
print("10-fold cross validation average roc_auc score for Random Forest Classifier: %.3f" % (results.mean()))'''
# Out:
# 10-fold cross validation average roc_auc score for Random Forest Classifier: 0.977

# %% [markdown]
# ### Bagging Classifier

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import KFold
logreg = LogisticRegression()

kfold = KFold(n_splits=10) # change this during train-test split method
#cart = DecisionTreeClassifier()

model_k1 = BaggingClassifier(base_estimator=logreg, n_estimators=100, random_state=1)

results_k1 = cross_val_score(model_k1, X_s, Y, cv=kfold)

print('test accuracy: ',results_k1.mean())
# Out:
# test accuracy:  0.7471899763694003

# %%
cart = DecisionTreeClassifier()

kfold = KFold(n_splits=10)

model_k2 = BaggingClassifier(base_estimator=cart, n_estimators=100, random_state=1)

results_k2 = cross_val_score(model_k2, X_s, Y, cv=kfold)

print('test accuracy: ',results_k2.mean())
# Out:
# test accuracy:  0.9728000152585011

# %% [markdown]
# ###  Adaboost Classifier

# %%
score = []
for depth in [1,2,10] : 
    reg_ada = AdaBoostClassifier(DecisionTreeClassifier(max_depth=depth))
    scores_ada = cross_val_score(reg_ada, X_s, Y, cv=10)
    score.append(scores_ada.mean())
print(score)
# Out:
# [0.9290145417530813, 0.9628074035853464, 0.9744264510131846]

# %% [markdown]
# ### XGB Classifier

# %%
kfold = KFold(n_splits=10)
XGB_cv = XGBClassifier(n_estimators=100, random_state=1, learning_rate = 0.1)
results_xgb = cross_val_score(XGB_cv, X_s, Y, cv=kfold)

print('test accuracy: ',results_xgb.mean())
# Out:
# [21:02:08] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [21:02:09] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [21:02:09] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [21:02:10] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [21:02:11] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [21:02:11] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [21:02:12] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [21:02:12] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [21:02:13] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [21:02:14] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# test accuracy:  0.9724455562627112

# %% [markdown]
# ## Evaluate and Finalise the Model

# %% [markdown]
# ### Model Comparison

# %% [markdown]
# | Algorithms                                | Accuracy Score   |  Recall    |    Pecision | F1-Score
# | ------------------------------            |:----------------:|------------:|            |              |
# | __Logistic Regression__                   | __79.64%__      |__34.70%__    |__63.00%__  |__44.80%__    |
# | __Decision Tree Classifier__              | __96.10%__      |__92.30%__    |__91.40%__  |__91.80%__    |
# | __Decision Tree with Gridsearch__         | __96.95%__      |__91.50%__    |__95.50%__  |__93.50%__    |
# | __Random Forest__                         | __96.95%__      |__90.00%__    |__97.00%__  |__93.40%__    |
# | __Random Forest with RandomizedsearchCV__ | __95.53%__      |__90.90%__    |__90.4%__   |__90.60%__    |
# | __Naive Bayes Theorem__                   | __72.16%__      |__81.10%__    |__45.20%__  |__58.10%__    |
# | __K Nearest Neighbor__                    | __95.00%__      |__86.30%__    |__92.20%__  |__89.10%__    |
# | __Support Vector Classifier__             | __95.18%__      |__89.30%__    |__90.30%__  |__89.80%__    |
# | __Bagging Classifier__                    | __97.62%__      |__92.10%__    |__97.80%__  |__94.90%__    |
# | __Voting Classifier__                     | __95.40%__      |__86.4%__     |__96.99%__  |__91.34%__    |
# | __Ada Boosting Classifier__               | __93.87%__      |__87.00%__    |__87.20%__  |__87.10%__    |
# | __Gradient Boost Classifier__             | __96.04%__      |__90.61%__    |__91.70%__  |__91.06%__    |
# | __XGB Classifier__                        | __97.55%__      |__92.50%__    |__97.00%__  |__94.70%__    |

# %% [markdown]
# ### Finalizing the Model

# %% [markdown]
# - After building diffirent classification models and on comparing, the following conclusions are made for finalizing the best performing model:
#     - Bagging Classifier and XG Boost give highest accuracy scores
#     - As the data is imbalanced i.e., the proportion of the staus variable "Left" is much less compared to "Employed", the       Recall score in this case is also important to be considered.
#     - XG Boost gives higher Recall score (92.5%) compared to Bagging Classifier (92.10%)
#     - Based on the above considerations, **XG Boost** is chosen as the final model for predicting the Unseen Data

# %% [markdown]
# ## Predicting the Unseen Data

# %% [markdown]
# ### Importing & Preprocessing of Unseen data

# %%
data_unseen = pd.read_csv('https://raw.githubusercontent.com/sruthayanan/INSAID_Capstone2/main/GCD_Capstone_Project_unseen_data.csv')
data_unseen.head()
# Out:
#    avg_monthly_hrs department  filed_complaint  last_evaluation  n_projects  \
# 0  134              D00-IT      nan            0.528841          2
# 1  221              D00-PD      nan            0.784561          2
# 2  156              D00-SS      nan            0.545183          2
# 3  133              D00-PR      nan              nan             4
# 4  135              D00-SS      nan            0.454637          2
#
#    recently_promoted  salary  satisfaction   tenure  employee_id
# 0   nan               low    0.400464      3.000000  119045
# 1   nan               low    0.759513      3.000000  112223
# 2   nan               medium 0.336457      3.000000  103924
# 3   nan               medium 0.832039      2.000000  105922
# 4   nan               low    0.320723      5.000000  103297

# %%
data_unseen.shape
# Out:
# (100, 10)

# %%
data_unseen.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 10 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   avg_monthly_hrs    100 non-null    int64
#  1   department         98 non-null     object
#  2   filed_complaint    15 non-null     float64
#  3   last_evaluation    83 non-null     float64
#  4   n_projects         100 non-null    int64
#  5   recently_promoted  3 non-null      float64
#  6   salary             100 non-null    object
#  7   satisfaction       97 non-null     float64
#  8   tenure             97 non-null     float64
#  9   employee_id        100 non-null    int64
# dtypes: float64(5), int64(3), object(2)
# memory usage: 7.9+ KB

# %%
emp_details.head()
# Out:
#    employee_id  age  gender marital_status
# 0  113558       43   Male    Married
# 1  112256       24   Female  Unmarried
# 2  112586       22   Female  Unmarried
# 3  108071       36   Male    Married
# 4  116915       38   Male    Married

# %%
common1 = np.intersect1d(data_unseen.employee_id,emp_details.employee_id)
common1.shape
# Out:
# (100,)

# %%
data_pred = pd.merge(left=data_unseen,right=emp_details, how='inner',on='employee_id')
data_pred.head()
# Out:
#    avg_monthly_hrs department  filed_complaint  last_evaluation  n_projects  \
# 0  134              D00-IT      nan            0.528841          2
# 1  221              D00-PD      nan            0.784561          2
# 2  156              D00-SS      nan            0.545183          2
# 3  133              D00-PR      nan              nan             4
# 4  135              D00-SS      nan            0.454637          2
#
#    recently_promoted  salary  satisfaction   tenure  employee_id  age gender  \
# 0   nan               low    0.400464      3.000000  119045       27   Male
# 1   nan               low    0.759513      3.000000  112223       23   Male
# 2   nan               medium 0.336457      3.000000  103924       26   Male
# 3   nan               medium 0.832039      2.000000  105922       52   Male
# 4   nan               low    0.320723      5.000000  103297       27   Male
#
#   marital_status
# 0  Unmarried
# 1  Unmarried
# 2  Unmarried
# 3  Married
# 4  Unmarried

# %%
data_pred.shape
# Out:
# (100, 13)

# %%
data_pred.isnull().sum().sort_values(ascending = False)
# Out:
# recently_promoted    97
# filed_complaint      85
# last_evaluation      17
# tenure               3
# satisfaction         3
# department           2
# marital_status       0
# gender               0
# age                  0
# employee_id          0
# salary               0
# n_projects           0
# avg_monthly_hrs      0
# dtype: int64

# %% [markdown]
# ### Missing Value Treatment:

# %%
data_pred.recently_promoted.value_counts()
# Out:
# 1.000000    3
# Name: recently_promoted, dtype: int64

# %% [markdown]
# - we will replace the NAN values with zero

# %%
data_pred.filed_complaint.value_counts()
# Out:
# 1.000000    15
# Name: filed_complaint, dtype: int64

# %% [markdown]
# - we will replace the NAN values with zero

# %%
data_pred[['recently_promoted','filed_complaint']] = data_pred[['recently_promoted','filed_complaint']].replace(np.NaN,0)

# %%
data_pred.tenure.value_counts()
# Out:
# 3.000000     40
# 2.000000     27
# 4.000000     11
# 5.000000     10
# 6.000000     5
# 7.000000     2
# 10.000000    2
# Name: tenure, dtype: int64

# %% [markdown]
# - we will replace the NAN values with 1

# %%
data_pred.department.value_counts()
# Out:
# D00-SS     27
# D00-ENG    17
# D00-SP     13
# D00-IT     9
# D00-MT     7
# D00-PD     7
# D00-FN     6
# D00-MN     5
# D00-TP     3
# -IT        2
# D00-AD     1
# D00-PR     1
# Name: department, dtype: int64

# %%
data_pred.replace({'-IT'},{'D00-IT'},inplace =True)

# %%
data_pred['department'] = data_pred['department'].replace(np.NaN,'D00-UN')

# %%
data_pred['tenure'] = data_pred['tenure'].replace(np.NaN,1)

# %%
data_pred['satisfaction'] = data_pred['satisfaction'].replace(np.NaN,0)

# %%
# Calculating the mean of last_evaluation for each department, 
means = data_pred.groupby('department')['last_evaluation'].mean()
# Convert pandas series to dictionary
dd=means.to_dict()

# %%
# replacing the null values of last_evaluation with mean of that department.
data_pred.last_evaluation = data_pred.last_evaluation.fillna(data_pred.department.map(dd))

# %%
data_pred['last_evaluation'] = data_pred['last_evaluation'].fillna(0)

# %%
null_data2 = pd.DataFrame(data_pred.isnull().sum(), columns = ['Frequency'])
null_data2.transpose()
# Out:
#            avg_monthly_hrs  department  filed_complaint  last_evaluation  \
# Frequency  0                0           0                0
#
#            n_projects  recently_promoted  salary  satisfaction  tenure  \
# Frequency  0           0                  0       0             0
#
#            employee_id  age  gender  marital_status
# Frequency  0            0    0       0

# %%
data_pred.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 100 entries, 0 to 99
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   avg_monthly_hrs    100 non-null    int64
#  1   department         100 non-null    object
#  2   filed_complaint    100 non-null    float64
#  3   last_evaluation    100 non-null    float64
#  4   n_projects         100 non-null    int64
#  5   recently_promoted  100 non-null    float64
#  6   salary             100 non-null    object
#  7   satisfaction       100 non-null    float64
#  8   tenure             100 non-null    float64
#  9   employee_id        100 non-null    int64
#  10  age                100 non-null    int64
#  11  gender             100 non-null    object
#  12  marital_status     100 non-null    object
# dtypes: float64(5), int64(4), object(4)
# memory usage: 10.9+ KB

# %%
data_pred.nunique()
# Out:
# avg_monthly_hrs      80
# department           12
# filed_complaint      2
# last_evaluation      88
# n_projects           7
# recently_promoted    2
# salary               3
# satisfaction         96
# tenure               8
# employee_id          100
# age                  30
# gender               2
# marital_status       2
# dtype: int64

# %% [markdown]
# ### Feature Engineering of Unseen data

# %% [markdown]
# ####  Encoding

# %%
# Label Encoding
from sklearn.preprocessing import LabelEncoder
Label_Encoder = LabelEncoder()
Label_Encoder.fit(data_pred['department'])
data_pred['department'] = Label_Encoder.transform(data_pred['department'])

# %%
#One-Hot Encoding
categorical_feature_oh=['salary','gender','marital_status']
data_pred=pd.get_dummies(data_pred,columns = categorical_feature_oh)

data_pred.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 100 entries, 0 to 99
# Data columns (total 17 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   avg_monthly_hrs           100 non-null    int64
#  1   department                100 non-null    int32
#  2   filed_complaint           100 non-null    float64
#  3   last_evaluation           100 non-null    float64
#  4   n_projects                100 non-null    int64
#  5   recently_promoted         100 non-null    float64
#  6   satisfaction              100 non-null    float64
#  7   tenure                    100 non-null    float64
#  8   employee_id               100 non-null    int64
#  9   age                       100 non-null    int64
#  10  salary_high               100 non-null    uint8
#  11  salary_low                100 non-null    uint8
#  12  salary_medium             100 non-null    uint8
#  13  gender_Female             100 non-null    uint8
#  14  gender_Male               100 non-null    uint8
#  15  marital_status_Married    100 non-null    uint8
#  16  marital_status_Unmarried  100 non-null    uint8
# dtypes: float64(5), int32(1), int64(4), uint8(7)
# memory usage: 8.9 KB

# %%
data_pred.head()
# Out:
#    avg_monthly_hrs  department  filed_complaint  last_evaluation  n_projects  \
# 0  134              3          0.000000         0.528841          2
# 1  221              6          0.000000         0.784561          2
# 2  156              9          0.000000         0.545183          2
# 3  133              7          0.000000         0.000000          4
# 4  135              9          0.000000         0.454637          2
#
#    recently_promoted  satisfaction   tenure  employee_id  age  salary_high  \
# 0 0.000000           0.400464      3.000000  119045       27   0
# 1 0.000000           0.759513      3.000000  112223       23   0
# 2 0.000000           0.336457      3.000000  103924       26   0
# 3 0.000000           0.832039      2.000000  105922       52   0
# 4 0.000000           0.320723      5.000000  103297       27   0
#
#    salary_low  salary_medium  gender_Female  gender_Male  \
# 0  1           0              0              1
# 1  1           0              0              1
# 2  0           1              0              1
# 3  0           1              0              1
# 4  1           0              0              1
#
#    marital_status_Married  marital_status_Unmarried
# 0  0                       1
# 1  0                       1
# 2  0                       1
# 3  1                       0
# 4  0                       1

# %%
X_valid = data_pred.drop(columns = 'employee_id')

# %%
print(X_valid.shape)
# Out:
# (100, 16)

# %%
X_valid_SC = scaler.transform(X_valid)

# %% [markdown]
# ### Model to Predict Unseen Data

# %%
y_pred_unseenData = XGB.predict(X_valid_SC)
y_pred_unseenData_probability = XGB.predict_proba(X_valid_SC)
predictions = y_pred_unseenData_probability[:,1]

# %%
print (y_pred_unseenData.shape, y_pred_unseenData_probability.shape, predictions.shape)
# Out:
# (100,) (100, 2) (100,)

# %%
df_y_preds = pd.DataFrame(y_pred_unseenData, columns=['status'])
df_y_pred_proba = pd.DataFrame(predictions, columns=['Probability to Leave'])

# %%
df_y_preds.head()
# Out:
#    status
# 0  1
# 1  0
# 2  1
# 3  0
# 4  1

# %%
df_y_preds.status.value_counts()
# Out:
# 0    70
# 1    30
# Name: status, dtype: int64

# %%
df_y_pred_proba.head()
# Out:
#    Probability to Leave
# 0 0.995728
# 1 0.070555
# 2 0.967683
# 3 0.000773
# 4 0.570213

# %%
emp_id = data_pred[['employee_id']]
emp_id.shape
# Out:
# (100, 1)

# %%
df_submission = pd.concat([emp_id, df_y_pred_proba], axis=1)

# %%
df_submission
# Out:
#     employee_id  Probability to Leave
# 0   119045      0.995728
# 1   112223      0.070555
# 2   103924      0.967683
# 3   105922      0.000773
# 4   103297      0.570213
# 5   115525      0.005435
# 6   116409      0.020411
# 7   109427      0.005899
# 8   118590      0.005745
# 9   107075      0.001205
# 10  101173      0.001274
# 11  127419      0.988150
# 12  109575      0.978562
# 13  115834      0.003932
# 14  119963      0.007271
# 15  107449      0.000171
# 16  115767      0.991556
# 17  114678      0.000314
# 18  104384      0.002003
# 19  113998      0.001317
# 20  115060      0.971291
# 21  106141      0.988151
# 22  102113      0.027963
# 23  103723      0.005289
# 24  100400      0.844049
# 25  106597      0.005814
# 26  105299      0.001598
# 27  103740      0.008145
# 28  127312      0.998998
# 29  100564      0.001058
# 30  107811      0.004034
# 31  100646      0.002317
# 32  109852      0.002309
# 33  118666      0.000105
# 34  112180      0.007863
# 35  100787      0.035274
# 36  107726      0.034109
# 37  113851      0.984206
# 38  115282      0.002044
# 39  105654      0.011409
# 40  100405      0.998831
# 41  123181      0.946419
# 42  106100      0.002845
# 43  116407      0.026674
# 44  110213      0.001641
# 45  116010      0.008026
# 46  138635      0.988890
# 47  109241      0.000850
# 48  111864      0.002594
# 49  116431      0.076709
# 50  110559      0.000804
# 51  105027      0.007559
# 52  101272      0.043709
# 53  113568      0.000218
# 54  112855      0.048220
# 55  109599      0.005458
# 56  102397      0.003911
# 57  119115      0.014962
# 58  134126      0.002012
# 59  121900      0.999076
# 60  102998      0.074296
# 61  103805      0.961353
# 62  100365      0.960850
# 63  108576      0.056878
# 64  114361      0.994787
# 65  113694      0.972346
# 66  102301      0.003020
# 67  121406      0.984233
# 68  145105      0.000058
# 69  106890      0.986597
# 70  117431      0.022797
# 71  101534      0.001566
# 72  110456      0.002591
# 73  104576      0.073362
# 74  117933      0.935768
# 75  117781      0.662532
# 76  119721      0.015514
# 77  100230      0.004116
# 78  117030      0.066350
# 79  112360      0.000940
# 80  124246      0.951102
# 81  117804      0.953153
# 82  109658      0.073966
# 83  107490      0.985444
# 84  110555      0.003373
# 85  133022      0.004975
# 86  109383      0.000153
# 87  144357      0.007494
# 88  104120      0.119492
# 89  136286      0.007440
# 90  112200      0.943028
# 91  123320      0.974636
# 92  114160      0.461483
# 93  119725      0.991544
# 94  106053      0.671638
# 95  116666      0.001564
# 96  106422      0.000650
# 97  107889      0.000901
# 98  117622      0.005850
# 99  108058      0.189044

# %%
df_submission.to_csv('1004_GCD_Capstone_Project.csv', header=False, index=False)

# %%
test = pd.read_csv('1004_GCD_Capstone_Project.csv',header=None)
test.head()
# Out:
#         0        1
# 0  119045 0.995728
# 1  112223 0.070555
# 2  103924 0.967683
# 3  105922 0.000773
# 4  103297 0.570213

# %%
test.shape
# Out:
# (100, 2)

# %% [markdown]
# - 1004_GCD_Capstone_Project.csv contains the final predicted probability values for submission.

# %% [markdown]
# ## Actionable Insights

# %% [markdown]
# -  **Delay in Promotion** could be the reason for employees to leave the organisation.
# - Satisfaction level of left employees is much below average in comparison to those who are still employed.
# - Employees who left had higher number of average working hours per month
# - Average age of employees who left is younger in comparison to those still employed
# - Average of employees promoted among those left is less compared to those still employed
# - Number of projects worked upon by both who left and still employed remains almost the same,
# - Majority of unmarried females are in the age group 22-25, whereas males are in 22-29.
# - The number of females leaving in this age group is also more compared to males. For females- ~250(Left) vs. ~400(Employed), males- ~120(Left) vs. 450(Employed)
# - 14.46% of employees filed complaints which is quite a high number and this also shows that employees are not happy in the organisation.
#
# "EDA  of the dataset suggests that Employee who left the company can be grouped into 3 types of employees:
#
# 1) High Evaluation rating, but low satisfaction
# 2) High Evaluation rating and high satisfaction
# 3) Medium to low Evaluation rating and medium and low satisfaction
#
# #### Actionable Insight:
#
# - From above observations on 'employees promoted' and 'tenure' of employees, it is envisaged that the company should have a promotion policy in such a way that as soon as the employee is nearing 3 to 4 years of tenure, he/she should get a fair chance for promotion/incentives/hike in salary etc.
#
# - The company should focus on retaining employess in the age group from 22-29
#
#     By introducing career guidance for future growth of younger employees
#
#     Implementing women friendly policies to retain Female workforce as their attrition rate is proportioantely more compare to     male
# - The grievance redressal mechanism needs to be made strong to promptly address the employees complaints/issues.
# - Performance based incentives to be given to improve the employee satisfaction level.
