# %% [markdown]
# # Capstone Project : HR Analytics
#
# <font color='maroon'> Data Analytics and Machine Learning #
#
# <font color='green'>
# ## Group : 1004 ##
# </font>
#
# ![hr.png](attachment:hr.png)

# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#1.-Introduction" data-toc-modified-id="1.-Introduction-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>1. Introduction</a></span></li><li><span><a href="#2.-Problem-Statement" data-toc-modified-id="2.-Problem-Statement-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>2. Problem Statement</a></span></li><li><span><a href="#3.-Data-Description" data-toc-modified-id="3.-Data-Description-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>3. Data Description</a></span><ul class="toc-item"><li><ul class="toc-item"><li><span><a href="#1.-department_data" data-toc-modified-id="1.-department_data-3.0.1"><span class="toc-item-num">3.0.1&nbsp;&nbsp;</span>1. department_data</a></span></li><li><span><a href="#2.employee_details_data" data-toc-modified-id="2.employee_details_data-3.0.2"><span class="toc-item-num">3.0.2&nbsp;&nbsp;</span>2.employee_details_data</a></span></li><li><span><a href="#3.-employee_data" data-toc-modified-id="3.-employee_data-3.0.3"><span class="toc-item-num">3.0.3&nbsp;&nbsp;</span>3. employee_data</a></span><ul class="toc-item"><li><span><a href="#Target-variable" data-toc-modified-id="Target-variable-3.0.3.1"><span class="toc-item-num">3.0.3.1&nbsp;&nbsp;</span>Target variable</a></span></li><li><span><a href="#Administrative-information" data-toc-modified-id="Administrative-information-3.0.3.2"><span class="toc-item-num">3.0.3.2&nbsp;&nbsp;</span>Administrative information</a></span></li><li><span><a href="#Workload-information" data-toc-modified-id="Workload-information-3.0.3.3"><span class="toc-item-num">3.0.3.3&nbsp;&nbsp;</span>Workload information</a></span></li><li><span><a href="#Mutual-evaluation-information" data-toc-modified-id="Mutual-evaluation-information-3.0.3.4"><span class="toc-item-num">3.0.3.4&nbsp;&nbsp;</span>Mutual evaluation information</a></span></li></ul></li></ul></li><li><span><a href="#3.1-Retrieving-Datasets-from-SQL-Server" data-toc-modified-id="3.1-Retrieving-Datasets-from-SQL-Server-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>3.1 Retrieving Datasets from SQL Server</a></span></li><li><span><a href="#3.2-Saving-the-datasets-into-CSV-Files" data-toc-modified-id="3.2-Saving-the-datasets-into-CSV-Files-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>3.2 Saving the datasets into CSV Files</a></span></li><li><span><a href="#3.3-Importing-the-datasets" data-toc-modified-id="3.3-Importing-the-datasets-3.3"><span class="toc-item-num">3.3&nbsp;&nbsp;</span>3.3 Importing the datasets</a></span></li></ul></li><li><span><a href="#4.-Data-Examination" data-toc-modified-id="4.-Data-Examination-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>4. Data Examination</a></span><ul class="toc-item"><li><span><a href="#Observations-of-Department-Data" data-toc-modified-id="Observations-of-Department-Data-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>Observations of Department Data</a></span></li><li><span><a href="#Observations-of-Employee-Details" data-toc-modified-id="Observations-of-Employee-Details-4.2"><span class="toc-item-num">4.2&nbsp;&nbsp;</span>Observations of Employee Details</a></span></li><li><span><a href="#Observations-of-Employee-Data" data-toc-modified-id="Observations-of-Employee-Data-4.3"><span class="toc-item-num">4.3&nbsp;&nbsp;</span>Observations of Employee Data</a></span></li><li><span><a href="#Pre-Processing" data-toc-modified-id="Pre-Processing-4.4"><span class="toc-item-num">4.4&nbsp;&nbsp;</span>Pre Processing</a></span><ul class="toc-item"><li><span><a href="#Merging-Data" data-toc-modified-id="Merging-Data-4.4.1"><span class="toc-item-num">4.4.1&nbsp;&nbsp;</span>Merging Data</a></span></li><li><span><a href="#Missing-Value-Treatment:" data-toc-modified-id="Missing-Value-Treatment:-4.4.2"><span class="toc-item-num">4.4.2&nbsp;&nbsp;</span>Missing Value Treatment:</a></span><ul class="toc-item"><li><span><a href="#Department:" data-toc-modified-id="Department:-4.4.2.1"><span class="toc-item-num">4.4.2.1&nbsp;&nbsp;</span>Department:</a></span></li><li><span><a href="#Filed-Complaint:" data-toc-modified-id="Filed-Complaint:-4.4.2.2"><span class="toc-item-num">4.4.2.2&nbsp;&nbsp;</span>Filed Complaint:</a></span></li><li><span><a href="#Recently-Promoted:" data-toc-modified-id="Recently-Promoted:-4.4.2.3"><span class="toc-item-num">4.4.2.3&nbsp;&nbsp;</span>Recently Promoted:</a></span></li><li><span><a href="#Tenure:" data-toc-modified-id="Tenure:-4.4.2.4"><span class="toc-item-num">4.4.2.4&nbsp;&nbsp;</span>Tenure:</a></span></li><li><span><a href="#Satisfaction" data-toc-modified-id="Satisfaction-4.4.2.5"><span class="toc-item-num">4.4.2.5&nbsp;&nbsp;</span>Satisfaction</a></span></li><li><span><a href="#Last-Evaluation" data-toc-modified-id="Last-Evaluation-4.4.2.6"><span class="toc-item-num">4.4.2.6&nbsp;&nbsp;</span>Last Evaluation</a></span></li></ul></li></ul></li></ul></li><li><span><a href="#5.-Exploratory-Data-Analysis" data-toc-modified-id="5.-Exploratory-Data-Analysis-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>5. Exploratory Data Analysis</a></span><ul class="toc-item"><li><span><a href="#Employee-Status-Analysis" data-toc-modified-id="Employee-Status-Analysis-5.1"><span class="toc-item-num">5.1&nbsp;&nbsp;</span>Employee Status Analysis</a></span></li><li><span><a href="#Gender-wise-data-analysis" data-toc-modified-id="Gender-wise-data-analysis-5.2"><span class="toc-item-num">5.2&nbsp;&nbsp;</span>Gender wise data analysis</a></span></li><li><span><a href="#Age-wise-data-analysis" data-toc-modified-id="Age-wise-data-analysis-5.3"><span class="toc-item-num">5.3&nbsp;&nbsp;</span>Age wise data analysis</a></span></li><li><span><a href="#Department-wise-Analysis" data-toc-modified-id="Department-wise-Analysis-5.4"><span class="toc-item-num">5.4&nbsp;&nbsp;</span>Department wise Analysis</a></span></li><li><span><a href="#Marital-Status" data-toc-modified-id="Marital-Status-5.5"><span class="toc-item-num">5.5&nbsp;&nbsp;</span>Marital Status</a></span></li><li><span><a href="#No.-of-years-working-(Tenure)" data-toc-modified-id="No.-of-years-working-(Tenure)-5.6"><span class="toc-item-num">5.6&nbsp;&nbsp;</span>No. of years working (Tenure)</a></span></li><li><span><a href="#Recently-Promoted" data-toc-modified-id="Recently-Promoted-5.7"><span class="toc-item-num">5.7&nbsp;&nbsp;</span>Recently Promoted</a></span></li><li><span><a href="#Project-Distribution-among-Employees" data-toc-modified-id="Project-Distribution-among-Employees-5.8"><span class="toc-item-num">5.8&nbsp;&nbsp;</span>Project Distribution among Employees</a></span></li><li><span><a href="#Filed-Complaint" data-toc-modified-id="Filed-Complaint-5.9"><span class="toc-item-num">5.9&nbsp;&nbsp;</span>Filed Complaint</a></span></li><li><span><a href="#Monthly-hours-worked-by-the-employee" data-toc-modified-id="Monthly-hours-worked-by-the-employee-5.10"><span class="toc-item-num">5.10&nbsp;&nbsp;</span>Monthly hours worked by the employee</a></span></li><li><span><a href="#Salary-wise-Analysis" data-toc-modified-id="Salary-wise-Analysis-5.11"><span class="toc-item-num">5.11&nbsp;&nbsp;</span>Salary wise Analysis</a></span></li><li><span><a href="#Impact-of-Satisfaction-and-Last-Evaluation" data-toc-modified-id="Impact-of-Satisfaction-and-Last-Evaluation-5.12"><span class="toc-item-num">5.12&nbsp;&nbsp;</span>Impact of Satisfaction and Last Evaluation</a></span></li><li><span><a href="#Final-Dataset-for-Modelling" data-toc-modified-id="Final-Dataset-for-Modelling-5.13"><span class="toc-item-num">5.13&nbsp;&nbsp;</span>Final Dataset for Modelling</a></span></li></ul></li><li><span><a href="#Correlation-b/w-Features" data-toc-modified-id="Correlation-b/w-Features-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Correlation b/w Features</a></span></li><li><span><a href="#Feature-Engineering" data-toc-modified-id="Feature-Engineering-7"><span class="toc-item-num">7&nbsp;&nbsp;</span>Feature Engineering</a></span><ul class="toc-item"><li><span><a href="#Encoding" data-toc-modified-id="Encoding-7.1"><span class="toc-item-num">7.1&nbsp;&nbsp;</span>Encoding</a></span></li><li><span><a href="#Splitting-X-and-y-into-training-datasets" data-toc-modified-id="Splitting-X-and-y-into-training-datasets-7.2"><span class="toc-item-num">7.2&nbsp;&nbsp;</span>Splitting X and y into training datasets</a></span></li><li><span><a href="#Scaling" data-toc-modified-id="Scaling-7.3"><span class="toc-item-num">7.3&nbsp;&nbsp;</span>Scaling</a></span></li></ul></li><li><span><a href="#Modeling" data-toc-modified-id="Modeling-8"><span class="toc-item-num">8&nbsp;&nbsp;</span>Modeling</a></span><ul class="toc-item"><li><span><a href="#Logistic-Regression" data-toc-modified-id="Logistic-Regression-8.1"><span class="toc-item-num">8.1&nbsp;&nbsp;</span>Logistic Regression</a></span></li><li><span><a href="#Decision-Tree-Classifier" data-toc-modified-id="Decision-Tree-Classifier-8.2"><span class="toc-item-num">8.2&nbsp;&nbsp;</span>Decision Tree Classifier</a></span></li><li><span><a href="#Random-Forest-Classifier" data-toc-modified-id="Random-Forest-Classifier-8.3"><span class="toc-item-num">8.3&nbsp;&nbsp;</span>Random Forest Classifier</a></span></li><li><span><a href="#Naive-Bayes" data-toc-modified-id="Naive-Bayes-8.4"><span class="toc-item-num">8.4&nbsp;&nbsp;</span>Naive Bayes</a></span></li><li><span><a href="#K-Nearest-Neighbor" data-toc-modified-id="K-Nearest-Neighbor-8.5"><span class="toc-item-num">8.5&nbsp;&nbsp;</span>K Nearest Neighbor</a></span></li><li><span><a href="#Support-Vector-Machines" data-toc-modified-id="Support-Vector-Machines-8.6"><span class="toc-item-num">8.6&nbsp;&nbsp;</span>Support Vector Machines</a></span></li><li><span><a href="#Bagging-Classifier" data-toc-modified-id="Bagging-Classifier-8.7"><span class="toc-item-num">8.7&nbsp;&nbsp;</span>Bagging Classifier</a></span></li><li><span><a href="#Voting-Based-Ensemble-Technique" data-toc-modified-id="Voting-Based-Ensemble-Technique-8.8"><span class="toc-item-num">8.8&nbsp;&nbsp;</span>Voting Based Ensemble Technique</a></span></li><li><span><a href="#AdaBoost-Classifier" data-toc-modified-id="AdaBoost-Classifier-8.9"><span class="toc-item-num">8.9&nbsp;&nbsp;</span>AdaBoost Classifier</a></span></li><li><span><a href="#Gradient-Boost-Classifier" data-toc-modified-id="Gradient-Boost-Classifier-8.10"><span class="toc-item-num">8.10&nbsp;&nbsp;</span>Gradient Boost Classifier</a></span></li><li><span><a href="#XG-Boost-Classifier" data-toc-modified-id="XG-Boost-Classifier-8.11"><span class="toc-item-num">8.11&nbsp;&nbsp;</span>XG Boost Classifier</a></span></li><li><span><a href="#Hyper-Parameter-Tuning" data-toc-modified-id="Hyper-Parameter-Tuning-8.12"><span class="toc-item-num">8.12&nbsp;&nbsp;</span>Hyper Parameter Tuning</a></span><ul class="toc-item"><li><span><a href="#Decision-Tree-with-Gridsearch" data-toc-modified-id="Decision-Tree-with-Gridsearch-8.12.1"><span class="toc-item-num">8.12.1&nbsp;&nbsp;</span>Decision Tree with Gridsearch</a></span></li><li><span><a href="#Random-Forest-with-RandomizedsearchCV" data-toc-modified-id="Random-Forest-with-RandomizedsearchCV-8.12.2"><span class="toc-item-num">8.12.2&nbsp;&nbsp;</span>Random Forest with RandomizedsearchCV</a></span></li><li><span><a href="#Support-Vector-Classifier" data-toc-modified-id="Support-Vector-Classifier-8.12.3"><span class="toc-item-num">8.12.3&nbsp;&nbsp;</span>Support Vector Classifier</a></span></li></ul></li><li><span><a href="#Fit-&amp;-Tune-Models-with-Cross-validation" data-toc-modified-id="Fit-&amp;-Tune-Models-with-Cross-validation-8.13"><span class="toc-item-num">8.13&nbsp;&nbsp;</span>Fit &amp; Tune Models with Cross validation</a></span><ul class="toc-item"><li><span><a href="#Logistic-Regression" data-toc-modified-id="Logistic-Regression-8.13.1"><span class="toc-item-num">8.13.1&nbsp;&nbsp;</span>Logistic Regression</a></span></li><li><span><a href="#Support-Vector-Classifier" data-toc-modified-id="Support-Vector-Classifier-8.13.2"><span class="toc-item-num">8.13.2&nbsp;&nbsp;</span>Support Vector Classifier</a></span></li><li><span><a href="#Bagging-Classifier" data-toc-modified-id="Bagging-Classifier-8.13.3"><span class="toc-item-num">8.13.3&nbsp;&nbsp;</span>Bagging Classifier</a></span></li><li><span><a href="#Adaboost-Classifier" data-toc-modified-id="Adaboost-Classifier-8.13.4"><span class="toc-item-num">8.13.4&nbsp;&nbsp;</span>Adaboost Classifier</a></span></li><li><span><a href="#XGB-Classifier" data-toc-modified-id="XGB-Classifier-8.13.5"><span class="toc-item-num">8.13.5&nbsp;&nbsp;</span>XGB Classifier</a></span></li></ul></li></ul></li><li><span><a href="#Evaluate-and-Finalise-the-Model" data-toc-modified-id="Evaluate-and-Finalise-the-Model-9"><span class="toc-item-num">9&nbsp;&nbsp;</span>Evaluate and Finalise the Model</a></span><ul class="toc-item"><li><span><a href="#Model-Comparison" data-toc-modified-id="Model-Comparison-9.1"><span class="toc-item-num">9.1&nbsp;&nbsp;</span>Model Comparison</a></span></li><li><span><a href="#Feature-Importance" data-toc-modified-id="Feature-Importance-9.2"><span class="toc-item-num">9.2&nbsp;&nbsp;</span>Feature Importance</a></span></li></ul></li><li><span><a href="#Predicting-the-unkown" data-toc-modified-id="Predicting-the-unkown-10"><span class="toc-item-num">10&nbsp;&nbsp;</span>Predicting the unkown</a></span><ul class="toc-item"><li><span><a href="#Importing-&amp;-Preprocessing-of-Unseen-data" data-toc-modified-id="Importing-&amp;-Preprocessing-of-Unseen-data-10.1"><span class="toc-item-num">10.1&nbsp;&nbsp;</span>Importing &amp; Preprocessing of Unseen data</a></span></li><li><span><a href="#Missing-Value-Treatment:" data-toc-modified-id="Missing-Value-Treatment:-10.2"><span class="toc-item-num">10.2&nbsp;&nbsp;</span>Missing Value Treatment:</a></span></li><li><span><a href="#Feature-Engineering-of-Unseen-data" data-toc-modified-id="Feature-Engineering-of-Unseen-data-10.3"><span class="toc-item-num">10.3&nbsp;&nbsp;</span>Feature Engineering of Unseen data</a></span><ul class="toc-item"><li><span><a href="#Encoding" data-toc-modified-id="Encoding-10.3.1"><span class="toc-item-num">10.3.1&nbsp;&nbsp;</span>Encoding</a></span></li></ul></li><li><span><a href="#Model-to-Predict-Unseen-Data" data-toc-modified-id="Model-to-Predict-Unseen-Data-10.4"><span class="toc-item-num">10.4&nbsp;&nbsp;</span>Model to Predict Unseen Data</a></span></li></ul></li></ul></div>

# %% [markdown]
# ## 1. Introduction

# %% [markdown]
# Employee attrition is one of the great concerns that companies are struggling to address today and this situation shall continue to be there for one simple reason: the companies don’t really understand why their employees are leaving in the first place. Rather than companies jumping to well-intentioned quick fixes, they may take time to investigate the true causes of attrition. If companies make a concerted effort to better understand why employees are leaving and take meaningful action to retain the emplyees, they can gain an edge in the race to attract, develop, and retain the talent.
#
# **Current Practice**
#
# Once an employee leaves, he or she is taken an interview with the name "exit interview" and shares reasons for leaving. The HR Department then tries and learns insights from the interview and makes changes accordingly.
#
# **This suffers from the following problems:**
#
# The above approach is that it's too haphazard. The quality of insight gained from an interview depends heavily on the skill of the interviewer.
# The second problem is these insights can't be aggregated and interlaced across all employees who have left.
# The third is that it is too late by the time the proposed policy changes take effect.

# %% [markdown]
# ## 2. Problem Statement

# %% [markdown]
# Our client for this project is the HR Department at a software company.
#
# The problem statement is described in the following points:-
# - The HR Department wants to try a **new initiative** to retain employees.
# - The idea is to use **data to predict** whether an employee is **likely to leave**.
# - Once these employees are identified, HR can be **more proactive** in reaching out to them before it's too late.
# - They only want to deal with the data that is related to permanent employees.
# - HR Department has given datasets of past employees and their status (still employed or already left).
# - Our task is **to build a classification model to predict whether an employee will stay or leave**.
# - We need to build the best possible model as there is no comparable candidate for this problem.

# %% [markdown]
# ## 3. Data Description

# %% [markdown]
# The Business Intelligence Analysts of the Company provided us three datasets that contain information about past employees and their status (still employed or already left).
#
# #### 1. department_data
#     This dataset contains information about each department. The schema of the dataset is as follows:
#
#     - **dept_id** – Unique Department Code
#     - **dept_name** – Name of the Department
#     - **dept_head** – Name of the Head of the Department
#
# #### 2.employee_details_data
#     This dataset consists of Employee ID, their Age, Gender and Marital Status. The schema of this dataset is as follows:
#
#     - **employee_id** – Unique ID Number for each employee
#     - **age** – Age of the employee
#     - **gender** – Gender of the employee
#     - **marital_status** – Marital Status of the employee
#
# #### 3. employee_data
#     This dataset consists of each employee’s Administrative Information, Workload Information, Mutual Evaluation Information and Status.
#
#    ##### Target variable
#     - status – Current employment status (Employed / Left)
#
#    ##### Administrative information
#     - department – Department to which the employees belong(ed) to
#     - salary – Salary level with respect to rest of their department
#     - tenure – Number of years at the company
#     - recently_promoted – Was the employee promoted in the last 3 years?
#     - employee_id – Unique ID Number for each employee
#
#    ##### Workload information
#     - n_projects – Number of projects employee has worked on
#     - avg_monthly_hrs – Average number of hours worked per month
#
#    ##### Mutual evaluation information
#     - satisfaction – Score for employee’s satisfaction with the company (higher is better)
#     - last_evaluation – Score for most recent evaluation of employee (higher is better)
#     - filed_complaint – Has the employee filed a formal complaint in the last 3 years?

# %% [markdown]
# ### 3.1 Retrieving Datasets from SQL Server

# %%
#!pip install mysql

# %%
#!pip install mysql.connector

# %%
import numpy as np                     
import pandas as pd

pd.set_option('mode.chained_assignment', None)      
pd.set_option('display.max_colwidth', -1)           
pd.options.display.max_columns = 50  
pd.set_option('display.max_rows', None)
pd.set_option('float_format', '{:5f}'.format)

import warnings
warnings.filterwarnings('ignore')                  

import matplotlib.pyplot as plt
# %matplotlib inline

import seaborn as sns
sns.set(style='whitegrid', font_scale=1.3, color_codes=True)
# Out:
# <ipython-input-1-3463aee4df3d>:5: FutureWarning: Passing a negative integer is deprecated in version 1.0 and will not be supported in future version. Instead, use None to not limit the column width.
#   pd.set_option('display.max_colwidth', -1)

# %%
'''import mysql.connector
from mysql.connector import Error
import pandas as pd

try:
    connection = mysql.connector.connect(host='cpanel.insaid.co',
                                         database='Capstone2',
                                         user='student',
                                         password='student')
    
    if connection.is_connected():
        db_Info = connection.get_server_info()
        print("Connected to MySQL Server version ", db_Info)
        cursor = connection.cursor()
        cursor.execute("select database();")
        record = cursor.fetchone()
        print("You're connected to database: ", record)
        print("\n")
        
        cursor.execute("USE Capstone2")
        cursor.execute("SHOW TABLES")
        for (table_name,) in cursor:
            print(table_name)
        print("\n")
        
except Error as e:
    print("Error while connecting to MySQL", e)
finally:
    if (connection.is_connected()):
        cursor.close()
        connection.close()
        print("MySQL connection is closed")'''
# Out:
# 'import mysql.connector\nfrom mysql.connector import Error\nimport pandas as pd\n\ntry:\n    connection = mysql.connector.connect(host=\'cpanel.insaid.co\',\n                                         database=\'Capstone2\',\n                                         user=\'student\',\n                                         password=\'student\')\n    \n    if connection.is_connected():\n        db_Info = connection.get_server_info()\n        print("Connected to MySQL Server version ", db_Info)\n        cursor = connection.cursor()\n        cursor.execute("select database();")\n        record = cursor.fetchone()\n        print("You\'re connected to database: ", record)\n        print("\n")\n        \n        cursor.execute("USE Capstone2")\n        cursor.execute("SHOW TABLES")\n        for (table_name,) in cursor:\n            print(table_name)\n        print("\n")\n        \nexcept Error as e:\n    print("Error while connecting to MySQL", e)\nfinally:\n    if (connection.is_connected
# ...

# %% [markdown]
# ###  3.2 Saving the datasets into CSV Files

# %%
'''try:
    connection = mysql.connector.connect(host='cpanel.insaid.co',
                                         database='Capstone2',
                                         user='student',
                                         password='student')
    
    if connection.is_connected():
        db_Info = connection.get_server_info()
        print("Connected to MySQL Server version ", db_Info)
        cursor = connection.cursor()
        cursor.execute("select database();")
        record = cursor.fetchone()
        print("You're connected to database: ", record)
        print("\n")
        
        cursor.execute("USE Capstone2")
        cursor.execute("SHOW TABLES")
        for (table_name,) in cursor:
            print(table_name)
        print("\n")
        
# export  department_data table in csv format
        sql_select_Query = "select * from department_data"
        results = pd.read_sql_query(sql_select_Query, connection)
        results.to_csv("department_data.csv", index=False)
        print("Sucessfully exported table department_data")
        
# export  employee_data table in csv format
        sql_select_Query = "select * from employee_data"
        results = pd.read_sql_query(sql_select_Query, connection)
        results.to_csv("employee_data.csv", index=False)
        print("Sucessfully exported table employee_data")
        
# export  employee_details_data table in csv format
        sql_select_Query = "select * from employee_details_data"
        results = pd.read_sql_query(sql_select_Query, connection)
        results.to_csv("employee_details_data.csv", index=False)
        print("Sucessfully exported table employee_details_data")

# export  model_evaluation_results table in csv format
        sql_select_Query = "select * from model_evaluation_results"
        results = pd.read_sql_query(sql_select_Query, connection)
        results.to_csv("model_evaluation_results.csv", index=False)
        print("Sucessfully exported table model_evaluation_results")
        
# export  model_evaluation_table in csv format
        sql_select_Query = "select * from model_evaluation_table"
        results = pd.read_sql_query(sql_select_Query, connection)
        results.to_csv("model_evaluation_table.csv", index=False)
        print("Sucessfully exported table model_evaluation_table")
        
        
except Error as e:
    print("Error while connecting to MySQL", e)
finally:
    if (connection.is_connected()):
        cursor.close()
        connection.close()
        print("MySQL connection is closed")'''
# Out:
# 'try:\n    connection = mysql.connector.connect(host=\'cpanel.insaid.co\',\n                                         database=\'Capstone2\',\n                                         user=\'student\',\n                                         password=\'student\')\n    \n    if connection.is_connected():\n        db_Info = connection.get_server_info()\n        print("Connected to MySQL Server version ", db_Info)\n        cursor = connection.cursor()\n        cursor.execute("select database();")\n        record = cursor.fetchone()\n        print("You\'re connected to database: ", record)\n        print("\n")\n        \n        cursor.execute("USE Capstone2")\n        cursor.execute("SHOW TABLES")\n        for (table_name,) in cursor:\n            print(table_name)\n        print("\n")\n        \n# export  department_data table in csv format\n        sql_select_Query = "select * from department_data"\n        results = pd.read_sql_query(sql_select_Query, connection)\n        results.to
# ...

# %% [markdown]
# | Database Name           |  Records  | Features |
# | :--                     |  :--      | :--      |
# | employee_details_data   | 14245     |  4       |
# | employee_data           | 14150     | 11       |
# | department_data         |    11     |  3       |

# %% [markdown]
# ### 3.3 Importing the datasets

# %%
dept_data = pd.read_csv("https://raw.githubusercontent.com/sruthayanan/INSAID_Capstone2/main/department_data.csv")
emp_details = pd.read_csv("https://raw.githubusercontent.com/sruthayanan/INSAID_Capstone2/main/employee_details_data.csv")
emp_data = pd.read_csv("https://raw.githubusercontent.com/sruthayanan/INSAID_Capstone2/main/employee_data.csv")

# %% [markdown]
# ## 4. Data Examination

# %% [markdown]
# ### Observations of Department Data

# %%
dept_data.head()
# Out:
#    dept_id    dept_name              dept_head
# 0  D00-IT   IT           Henry Adey
# 1  D00-SS   Sales        Edward J Bayley
# 2  D00-TP   Temp         Micheal Zachrey
# 3  D00-ENG  Engineering  Sushant Raghunathan K
# 4  D00-SP   Support      Amelia Westray

# %%
dept_data.dept_id.value_counts()
# Out:
# D00-SS     1
# D00-MN     1
# D00-AD     1
# D00-ENG    1
# D00-MT     1
# D00-SP     1
# D00-PD     1
# D00-TP     1
# D00-IT     1
# D00-FN     1
# D00-PR     1
# Name: dept_id, dtype: int64

# %%
dept_data.dept_name.value_counts()
# Out:
# Management     1
# Engineering    1
# Support        1
# Admin          1
# Sales          1
# IT             1
# Temp           1
# Product        1
# Procurement    1
# Marketing      1
# Finance        1
# Name: dept_name, dtype: int64

# %%
dept_data.nunique()
# Out:
# dept_id      11
# dept_name    11
# dept_head    11
# dtype: int64

# %% [markdown]
# - There are **11** Departments present in the dataset

# %% [markdown]
# ### Observations of Employee Details

# %%
emp_details.head()
# Out:
#    employee_id  age  gender marital_status
# 0  113558       43   Male    Married
# 1  112256       24   Female  Unmarried
# 2  112586       22   Female  Unmarried
# 3  108071       36   Male    Married
# 4  116915       38   Male    Married

# %%
emp_details.shape
# Out:
# (14245, 4)

# %%
emp_details.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14245 entries, 0 to 14244
# Data columns (total 4 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   employee_id     14245 non-null  int64
#  1   age             14245 non-null  int64
#  2   gender          14245 non-null  object
#  3   marital_status  14245 non-null  object
# dtypes: int64(2), object(2)
# memory usage: 445.3+ KB

# %%
emp_details.describe(include='all')
# Out:
#          employee_id          age gender marital_status
# count  14245.000000  14245.000000  14245  14245
# unique   nan           nan         2      2
# top      nan           nan         Male   Unmarried
# freq     nan           nan         9382   7283
# mean   112123.050544 32.889926     NaN    NaN
# std    8500.457343   9.970834      NaN    NaN
# min    100101.000000 22.000000     NaN    NaN
# 25%    105775.000000 24.000000     NaN    NaN
# 50%    111298.000000 29.000000     NaN    NaN
# 75%    116658.000000 41.000000     NaN    NaN
# max    148988.000000 57.000000     NaN    NaN

# %%
emp_details.isnull().sum().sort_values(ascending = False)
# Out:
# marital_status    0
# gender            0
# age               0
# employee_id       0
# dtype: int64

# %%
emp_details = emp_details.drop_duplicates()

# %%
emp_details.shape
# Out:
# (14245, 4)

# %% [markdown]
# - Total observations are 14245 and 4 Variables
# - No Missing Values
# - No duplicated rows in the emp_details dataset

# %%
emp_details.nunique()
# Out:
# employee_id       14245
# age               36
# gender            2
# marital_status    2
# dtype: int64

# %% [markdown]
# ### Observations of Employee Data

# %%
emp_data.head()
# Out:
#    avg_monthly_hrs department  filed_complaint  last_evaluation  n_projects  \
# 0 246.000000        NaN         nan            0.866838          6
# 1 134.000000        NaN         nan            0.555718          2
# 2 156.000000        D00-SS    1.000000         0.474082          2
# 3 256.000000        D00-SP      nan            0.961360          6
# 4 146.000000        D00-SS      nan            0.507349          2
#
#    recently_promoted  salary  satisfaction status   tenure  employee_id
# 0   nan               medium 0.134415       Left  4.000000  124467
# 1   nan               low    0.511041       Left  3.000000  112210
# 2   nan               medium 0.405101       Left  3.000000  126150
# 3   nan               low    0.152974       Left  4.000000  125346
# 4   nan               medium 0.434845       Left  3.000000  113707

# %%
emp_data.shape
# Out:
# (14150, 11)

# %%
emp_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14150 entries, 0 to 14149
# Data columns (total 11 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   avg_monthly_hrs    14150 non-null  float64
#  1   department         13443 non-null  object
#  2   filed_complaint    2046 non-null   float64
#  3   last_evaluation    12663 non-null  float64
#  4   n_projects         14150 non-null  int64
#  5   recently_promoted  297 non-null    float64
#  6   salary             14150 non-null  object
#  7   satisfaction       14000 non-null  float64
#  8   status             14150 non-null  object
#  9   tenure             14000 non-null  float64
#  10  employee_id        14150 non-null  int64
# dtypes: float64(6), int64(2), object(3)
# memory usage: 1.2+ MB

# %%
emp_data.describe()
# Out:
#        avg_monthly_hrs  filed_complaint  last_evaluation   n_projects  \
# count 14150.000000     2046.000000      12663.000000     14150.000000
# mean  199.994346       1.000000         0.718399         3.778304
# std   50.833697        0.000000         0.173108         1.250162
# min   49.000000        1.000000         0.316175         1.000000
# 25%   155.000000       1.000000         0.563711         3.000000
# 50%   199.000000       1.000000         0.724731         4.000000
# 75%   245.000000       1.000000         0.871409         5.000000
# max   310.000000       1.000000         1.000000         7.000000
#
#        recently_promoted  satisfaction       tenure   employee_id
# count 297.000000         14000.000000  14000.000000 14150.000000
# mean  1.000000           0.621212      3.499357     112080.750247
# std   0.000000           0.250482      1.462584     8748.202856
# min   1.000000           0.040058      2.000000     0.000000
# ...

# %% [markdown]
# - **employee_id** cannot be Zero.

# %%
emp_data.isnull().sum().sort_values(ascending = False)
# Out:
# recently_promoted    13853
# filed_complaint      12104
# last_evaluation      1487
# department           707
# tenure               150
# satisfaction         150
# employee_id          0
# status               0
# salary               0
# n_projects           0
# avg_monthly_hrs      0
# dtype: int64

# %% [markdown]
# - Total observations are **14150**.
# - Only **297** records having information about **Recently promoted**. Rest **13853** records having null values.
# - Only **2046** records having information about **filed_complaint**. Rest **12104** records having null values.
# - Total **12663** records having information about **last evaluation**. Rest **1487** records having null values.
# - Total **13443** records having information about the **Department**. Rest **707** records having null values.
# - For **Tenure** and **satisfaction** variable, information is available:**14000**. Rest **150** records having null values.

# %%
emp_data.nunique()
# Out:
# avg_monthly_hrs      249
# department           12
# filed_complaint      1
# last_evaluation      12188
# n_projects           7
# recently_promoted    1
# salary               3
# satisfaction         13497
# status               2
# tenure               8
# employee_id          14117
# dtype: int64

# %%
emp_data.employee_id.value_counts()[:5]
# Out:
# 0         5
# 119780    2
# 104360    2
# 116850    2
# 109425    2
# Name: employee_id, dtype: int64

# %%
df_id = emp_data[(emp_data.employee_id == 0)]
df_id
# Out:
#        avg_monthly_hrs department  filed_complaint  last_evaluation  \
# 34    284.000000        D00-SS      nan            0.852702
# 304   264.000000        D00-ENG     nan            0.774554
# 1234  129.000000        D00-SP      nan            0.402660
# 11304 167.000000        NaN         nan            0.880053
# 12304 259.000000        D00-ENG     nan            0.505883
#
#        n_projects  recently_promoted  salary  satisfaction    status   tenure  \
# 34     6            nan               low    0.069168       Left     4.000000
# 304    6            nan               low    0.110974       Left     4.000000
# 1234   2            nan               medium 0.437359       Left     3.000000
# 11304  5            nan               low    0.682140       Employed 3.000000
# 12304  5            nan               low    0.631046       Employed 4.000000
#
#        employee_id
# 34     0
# 304    0
# 1234   0
# 11304  0
# 12304  0

# %% [markdown]
# - 5 Observations has the Employee id as Zero and there is no common variable between the datasets to extract from other datasets, hence these 5 observations needs to be dropped

# %% [markdown]
# ### Pre Processing

# %%
emp_data = emp_data.drop_duplicates()

# %%
emp_data.shape
# Out:
# (14121, 11)

# %% [markdown]
# - emp_data has a size of 14121 after dropping duplicates

# %%
emp_data.nunique()
# Out:
# avg_monthly_hrs      249
# department           12
# filed_complaint      1
# last_evaluation      12188
# n_projects           7
# recently_promoted    1
# salary               3
# satisfaction         13497
# status               2
# tenure               8
# employee_id          14117
# dtype: int64

# %%
emp_data.department.value_counts()
# Out:
# D00-SS     3896
# D00-ENG    2575
# D00-SP     2109
# D00-IT     1359
# D00-PD     853
# D00-MT     812
# D00-FN     722
# D00-MN     590
# D00-AD     175
# D00-PR     173
# D00-TP     150
# Name: department, dtype: int64

# %% [markdown]
# - Replace 207 rows of'-IT' with 'D00-IT' in emp_data

# %%
emp_data.replace({'-IT'},{'D00-IT'},inplace =True)

# %%
emp_data.department.value_counts()
# Out:
# D00-SS     3896
# D00-ENG    2575
# D00-SP     2109
# D00-IT     1359
# D00-PD     853
# D00-MT     812
# D00-FN     722
# D00-MN     590
# D00-AD     175
# D00-PR     173
# D00-TP     150
# Name: department, dtype: int64

# %% [markdown]
# #### Merging Data

# %% [markdown]
# - emp_data with emp_details

# %%
common = np.intersect1d(emp_data.employee_id,emp_details.employee_id)
common.shape
# Out:
# (14116,)

# %%
final_data = pd.merge(left=emp_data,right=emp_details, how='inner',on='employee_id')
final_data.head()
# Out:
#    avg_monthly_hrs department  filed_complaint  last_evaluation  n_projects  \
# 0 246.000000        NaN         nan            0.866838          6
# 1 134.000000        NaN         nan            0.555718          2
# 2 156.000000        D00-SS    1.000000         0.474082          2
# 3 256.000000        D00-SP      nan            0.961360          6
# 4 146.000000        D00-SS      nan            0.507349          2
#
#    recently_promoted  salary  satisfaction status   tenure  employee_id  age  \
# 0   nan               medium 0.134415       Left  4.000000  124467       42
# 1   nan               low    0.511041       Left  3.000000  112210       23
# 2   nan               medium 0.405101       Left  3.000000  126150       24
# 3   nan               low    0.152974       Left  4.000000  125346       51
# 4   nan               medium 0.434845       Left  3.000000  113707       23
#
#    gender marital_status
# 0  Female  Married
# 1  Female  Unmarried
# 2  Female  Unmarried
# ...

# %%
final_data.shape
# Out:
# (14116, 14)

# %%
final_data.nunique()
# Out:
# avg_monthly_hrs      249
# department           11
# filed_complaint      1
# last_evaluation      12184
# n_projects           7
# recently_promoted    1
# salary               3
# satisfaction         13492
# status               2
# tenure               8
# employee_id          14116
# age                  36
# gender               2
# marital_status       2
# dtype: int64

# %%
final_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 14116 entries, 0 to 14115
# Data columns (total 14 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   avg_monthly_hrs    14116 non-null  float64
#  1   department         13410 non-null  object
#  2   filed_complaint    2041 non-null   float64
#  3   last_evaluation    12629 non-null  float64
#  4   n_projects         14116 non-null  int64
#  5   recently_promoted  297 non-null    float64
#  6   salary             14116 non-null  object
#  7   satisfaction       13966 non-null  float64
#  8   status             14116 non-null  object
#  9   tenure             13966 non-null  float64
#  10  employee_id        14116 non-null  int64
#  11  age                14116 non-null  int64
#  12  gender             14116 non-null  object
#  13  marital_status     14116 non-null  object
# dtypes: float64(6), int64(3), object(5)
# memory usage: 1.6+ MB

# %% [markdown]
# #### Missing Value Treatment:

# %%
null_data = pd.DataFrame(final_data.isnull().sum(), columns = ['Frequency'])
null_data.transpose()
# Out:
#            avg_monthly_hrs  department  filed_complaint  last_evaluation  \
# Frequency  0                706         12075            1487
#
#            n_projects  recently_promoted  salary  satisfaction  status  \
# Frequency  0           13819              0       150           0
#
#            tenure  employee_id  age  gender  marital_status
# Frequency  150     0            0    0       0

# %% [markdown]
# ##### Department:
#
#  We can consider null value present in Departmwnt as Unknown Department, will replace the null value with **D00-UN**.

# %%
final_data['department'] = final_data['department'].replace(np.NaN,'D00-UN')

# %%
final_data.department.value_counts()
# Out:
# D00-SS     3895
# D00-ENG    2573
# D00-SP     2108
# D00-IT     1359
# D00-PD     853
# D00-MT     812
# D00-FN     722
# D00-UN     706
# D00-MN     590
# D00-AD     175
# D00-PR     173
# D00-TP     150
# Name: department, dtype: int64

# %% [markdown]
# ##### Filed Complaint:

# %%
final_data.filed_complaint.value_counts()
# Out:
# 1.000000    2041
# Name: filed_complaint, dtype: int64

# %% [markdown]
# - 1 indicates that the employee has given complaint.
# - So the remaining data which means employees have not given complaint.Hence we will replace the NAN values with zero.

# %% [markdown]
# ##### Recently Promoted:

# %%
final_data.recently_promoted.value_counts()
# Out:
# 1.000000    297
# Name: recently_promoted, dtype: int64

# %% [markdown]
# - 1 indicates that the employee was promoted.
# - So the remaining data which indicates employees are not promoted.We will replace the NAN values with zero.

# %% [markdown]
# ##### Tenure:

# %%
final_data.tenure.value_counts()
# Out:
# 3.000000     6006
# 2.000000     3019
# 4.000000     2386
# 5.000000     1363
# 6.000000     659
# 10.000000    198
# 7.000000     180
# 8.000000     155
# Name: tenure, dtype: int64

# %%
final_data['tenure'] = final_data['tenure'].replace(np.NaN,1)

# %%
df_tenure = final_data[(final_data.tenure == 1)]
df_tenure
# Out:
#        avg_monthly_hrs department  filed_complaint  last_evaluation  \
# 43    125.000000        D00-TP      nan              nan
# 244   124.000000        D00-TP      nan              nan
# 250   119.000000        D00-TP      nan              nan
# 412   126.000000        D00-TP      nan              nan
# 466   65.000000         D00-TP      nan              nan
# 727   139.000000        D00-TP      nan              nan
# 777   63.000000         D00-TP      nan              nan
# 911   72.000000         D00-TP      nan              nan
# 928   87.000000         D00-TP      nan              nan
# 991   68.000000         D00-TP    1.000000           nan
# 1329  74.000000         D00-TP      nan              nan
# 1342  67.000000         D00-TP      nan              nan
# 1642  129.000000        D00-TP      nan              nan
# 1837  124.000000        D00-TP    1.000000           nan
# 1847  69.000000         D00-TP      nan              nan
# ...

# %%
df_tenure.filed_complaint.value_counts()
# Out:
# 1.000000    29
# Name: filed_complaint, dtype: int64

# %%
df_tenure.age.value_counts()
# Out:
# 25    27
# 23    27
# 24    25
# 22    19
# 26    16
# 29    14
# 27    14
# 28    7
# 49    1
# Name: age, dtype: int64

# %%
df_tenure.marital_status.value_counts()
# Out:
# Unmarried    149
# Married      1
# Name: marital_status, dtype: int64

# %%
df_tenure.department.value_counts()
# Out:
# D00-TP    150
# Name: department, dtype: int64

# %% [markdown]
# From the above information we can infer that 150 observations of null value in Tenure column are,
#
# - All belong to same department ie.Temporary
# - 149 are Unmarried
# - All are Young age group, henace considered as experiance fo less than a year and filled with 1.

# %%
final_data[['filed_complaint','recently_promoted']] = final_data[['filed_complaint','recently_promoted']].replace(np.NaN,0)

# %% [markdown]
# ##### Satisfaction

# %% [markdown]
# - All 150 Missing vaues are belongs to tenur=1 Category
# - We can replace the missing values with '0' value because this belongs to the newly recruited emplyees.

# %%
final_data['satisfaction'] = final_data['satisfaction'].replace(np.NaN,0)

# %% [markdown]
# ##### Last Evaluation

# %% [markdown]
# - We can replace the missing values with mean values of the respective departments.

# %%
# Calculating the mean of last_evaluation for each department, 
means = final_data.groupby('department')['last_evaluation'].mean()
# Convert pandas series to dictionary
dd=means.to_dict()

# %%
means
# Out:
# department
# D00-AD    0.726187
# D00-ENG   0.722725
# D00-FN    0.724704
# D00-IT    0.719525
# D00-MN    0.729070
# D00-MT    0.714934
# D00-PD    0.719523
# D00-PR    0.699205
# D00-SP    0.723170
# D00-SS    0.710672
# D00-TP      nan
# D00-UN    0.717679
# Name: last_evaluation, dtype: float64

# %%
# replacing the null values of last_evaluation with mean of that department.
final_data.last_evaluation = final_data.last_evaluation.fillna(final_data.department.map(dd))

# %%
final_data.last_evaluation.value_counts().count()
# Out:
# 12195

# %%
# Replacing the NaN value present in D00-TP with Zero(0)
final_data['last_evaluation'] = final_data['last_evaluation'].fillna(0)

# %%
final_data.last_evaluation.value_counts().count()
# Out:
# 12196

# %%
# Cross-checking that there are no null values in each column
null_data1 = pd.DataFrame(final_data.isnull().sum(), columns = ['Frequency'])
null_data1.transpose()
# Out:
#            avg_monthly_hrs  department  filed_complaint  last_evaluation  \
# Frequency  0                0           0                0
#
#            n_projects  recently_promoted  salary  satisfaction  status  \
# Frequency  0           0                  0       0             0
#
#            tenure  employee_id  age  gender  marital_status
# Frequency  0       0            0    0       0

# %%
# Type casting the relevant columns of float to integer
final_data = final_data.astype({'filed_complaint':'int64','recently_promoted':'int64','tenure':'int64','age':'int64' })

# %%
final_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 14116 entries, 0 to 14115
# Data columns (total 14 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   avg_monthly_hrs    14116 non-null  float64
#  1   department         14116 non-null  object
#  2   filed_complaint    14116 non-null  int64
#  3   last_evaluation    14116 non-null  float64
#  4   n_projects         14116 non-null  int64
#  5   recently_promoted  14116 non-null  int64
#  6   salary             14116 non-null  object
#  7   satisfaction       14116 non-null  float64
#  8   status             14116 non-null  object
#  9   tenure             14116 non-null  int64
#  10  employee_id        14116 non-null  int64
#  11  age                14116 non-null  int64
#  12  gender             14116 non-null  object
#  13  marital_status     14116 non-null  object
# dtypes: float64(3), int64(6), object(5)
# memory usage: 1.6+ MB

# %%
final_data.head()
# Out:
#    avg_monthly_hrs department  filed_complaint  last_evaluation  n_projects  \
# 0 246.000000        D00-UN     0               0.866838          6
# 1 134.000000        D00-UN     0               0.555718          2
# 2 156.000000        D00-SS     1               0.474082          2
# 3 256.000000        D00-SP     0               0.961360          6
# 4 146.000000        D00-SS     0               0.507349          2
#
#    recently_promoted  salary  satisfaction status  tenure  employee_id  age  \
# 0  0                  medium 0.134415       Left   4       124467       42
# 1  0                  low    0.511041       Left   3       112210       23
# 2  0                  medium 0.405101       Left   3       126150       24
# 3  0                  low    0.152974       Left   4       125346       51
# 4  0                  medium 0.434845       Left   3       113707       23
#
#    gender marital_status
# 0  Female  Married
# 1  Female  Unmarried
# 2  Female  Unmarried
# ...

# %%
final_data.shape
# Out:
# (14116, 14)

# %% [markdown]
# ## 5. Exploratory Data Analysis

# %% [markdown]
# ### Employee Status Analysis

# %%
print(final_data[['employee_id','status']].groupby('status').nunique())

figure = plt.figure(figsize = [12, 6])
colors_list = ['#FFA15A','#666699']

# Bar Plot
plt.subplot(1, 2, 1)
ax = sns.barplot(final_data['status'].value_counts().index, final_data['status'].value_counts(), palette  = colors_list)
plt.xlabel('Employee Status', size = 14)
plt.ylabel('Frequency', size = 14)
plt.title('Frequency Occurence', y=1.02, size = 14)

# Pie Plot

plt.subplot(1, 2, 2)
final_data['status'].value_counts().plot(kind = 'pie', figsize = [12, 6], autopct = '%1.1f%%', startangle = 90, 
                                     shadow = True, labels = None, pctdistance = 1.2, colors = colors_list)
plt.title('Proportion', y = 1.02, size = 14)
plt.ylabel('')
plt.axis('equal')
plt.legend(labels = final_data['status'].value_counts().index, bbox_to_anchor=(1.25,1.025),loc = 'center right')
plt.suptitle(t = 'Frequency & Proportion of Employee Status', y = 1.05, size = 14)
plt.tight_layout(pad = 1.0)
plt.show()
# Out:
#           employee_id
# status
# Employed  10761
# Left      3355

# %% [markdown]
# - We can see out of 14116 employees 3355 had left the organization and 10761 are currently employed. The no. of employee left is 24% of the total employment.

# %%
emp_status = final_data.groupby('status')
emp_left = emp_status.get_group('Left')
emp_employed = emp_status.get_group('Employed')

# %%
emp_left.mean()
# Out:
# avg_monthly_hrs     206.688227
# filed_complaint     0.045306
# last_evaluation     0.725455
# n_projects          3.837258
# recently_promoted   0.005365
# satisfaction        0.445077
# tenure              3.851863
# employee_id         115522.503428
# age                 31.973770
# dtype: float64

# %%
emp_employed.mean()
# Out:
# avg_monthly_hrs     197.905120
# filed_complaint     0.175541
# last_evaluation     0.706106
# n_projects          3.759223
# recently_promoted   0.025927
# satisfaction        0.667609
# tenure              3.352477
# employee_id         111060.050739
# age                 33.183533
# dtype: float64

# %% [markdown]
# Observations from the above stats:
#
# - Employees who left had higher number of average working hours per month
# - Average age of employees who left is younger in comparison to those still employed
# - Average value of satisfaction of those who left is lower that of those still employed
# - Average of employees promoted among those left is less compared to those still employed
# - Average number of projects worked upon by both who left and still employed remains almost the same,
# - Though those who left had more projects !
# - Employees who left had worked for more number of years than those still employed

# %%
final_data.pivot_table('employee_id', index='age', columns='status',aggfunc='count')
# Out:
# status   Employed       Left
# age
# 22     800.000000 366.000000
# 23     814.000000 382.000000
# 24     935.000000 373.000000
# 25     874.000000 372.000000
# 26     504.000000 122.000000
# 27     522.000000 140.000000
# 28     523.000000 124.000000
# 29     536.000000 124.000000
# 30     224.000000 51.000000
# 31     177.000000 48.000000
# 32     223.000000 54.000000
# 33     220.000000 59.000000
# 34     201.000000 42.000000
# 35     220.000000 41.000000
# 36     218.000000 51.000000
# 37     225.000000 59.000000
# 38     224.000000 45.000000
# 39     223.000000 47.000000
# 40     228.000000 43.000000
# 41     219.000000 50.000000
# 42     253.000000 50.000000
# 43     220.000000 45.000000
# 44     188.000000 62.000000
# 45     212.000000 52.000000
# 46     214.000000 57.000000
# 47     224.000000 54.000000
# 48     221.000000 51.000000
# 49     195.000000 48.000000
# 50     181.000000 52.000000
# 51     175.000000 52.000000
# 52     211.000000 41.000000
# ...

# %%
plt.figure(figsize=(15,5))
sns.countplot(x='age', hue='status', data = final_data)
# Out:
# <AxesSubplot:xlabel='age', ylabel='count'>

# %% [markdown]
# - The details indicate : unmarried, young, male employees leaving the organisation is higher among the total employees Left the Organization.

# %% [markdown]
# ### Gender wise data analysis

# %%
print(final_data.gender.value_counts())
sns.countplot(x='gender',data=final_data)
# Out:
# Male      9287
# Female    4829
# Name: gender, dtype: int64
# <AxesSubplot:xlabel='gender', ylabel='count'>

# %%
pd.crosstab(final_data['status'],final_data['gender'],margins=True).sort_values('All')
# Out:
# gender    Female  Male    All
# status
# Left      1495    1860  3355
# Employed  3334    7427  10761
# All       4829    9287  14116

# %%
sns.countplot(x='gender',data=final_data,hue='status')
# Out:
# <AxesSubplot:xlabel='gender', ylabel='count'>

# %%
pd.crosstab(final_data['age'],final_data['gender'],margins=True).sort_values('All')
# Out:
# gender  Female  Male    All
# age
# 56      0       22    22
# 57      0       34    34
# 55      0       38    38
# 31      70      155   225
# 54      73      153   226
# 51      59      168   227
# 50      53      180   233
# 53      74      161   235
# 49      68      175   243
# 34      77      166   243
# 44      77      173   250
# 52      70      182   252
# 35      74      187   261
# 45      73      191   264
# 43      78      187   265
# 36      80      189   269
# 38      77      192   269
# 41      84      185   269
# 39      65      205   270
# 46      80      191   271
# 40      90      181   271
# 48      80      192   272
# 30      77      198   275
# 32      84      193   277
# 47      89      189   278
# 33      90      189   279
# 37      70      214   284
# 42      95      208   303
# 26      77      549   626
# 28      87      560   647
# 29      80      580   660
# 27      77      585   662
# 22      635     531   1166
# 23      613     583   1196
# ...

# %%
plt.figure(figsize = [12, 6])
sns.countplot(x='age',data=final_data,hue='gender',palette='Set2')
# sns.countplot(x='age',data=final_data,hue=['gender','marital_status'],palette='Set2')
# Out:
# <AxesSubplot:xlabel='age', ylabel='count'>

# %%
as_fig = sns.FacetGrid(final_data,hue='gender',aspect=5)
as_fig.map(sns.kdeplot,'age')
oldest = final_data['age'].max()
as_fig.set(xlim=(0,oldest))
as_fig.add_legend()
plt.title("Gender Vs Age Distribution")
# Out:
# Text(0.5, 1.0, 'Gender Vs Age Distribution')

# %% [markdown]
# - Female Employees are more than Male in the age group of 22 to 25 years.

# %%
pd.crosstab(final_data['marital_status'],final_data['gender'],margins=True).sort_values('All')
# Out:
# gender          Female  Male    All
# marital_status
# Married         2197    4708  6905
# Unmarried       2632    4579  7211
# All             4829    9287  14116

# %%
plt.figure(figsize = [10, 5])
sns.countplot(x='marital_status',data=final_data,hue='gender')
# Out:
# <AxesSubplot:xlabel='marital_status', ylabel='count'>

# %%
pd.crosstab(final_data['department'],final_data['gender'],margins=True).sort_values('All')
# Out:
# gender      Female  Male    All
# department
# D00-TP      44      106   150
# D00-PR      55      118   173
# D00-AD      55      120   175
# D00-MN      196     394   590
# D00-UN      253     453   706
# D00-FN      236     486   722
# D00-MT      271     541   812
# D00-PD      285     568   853
# D00-IT      493     866   1359
# D00-SP      700     1408  2108
# D00-ENG     880     1693  2573
# D00-SS      1361    2534  3895
# All         4829    9287  14116

# %%
plt.figure(figsize = [15, 6])
sns.countplot(x='department',data=final_data,hue='gender',palette='Set1')
# Out:
# <AxesSubplot:xlabel='department', ylabel='count'>

# %%
pd.crosstab(final_data['salary'],final_data['gender'],margins=True).sort_values('All')
# Out:
# gender  Female  Male    All
# salary
# high    360     781   1141
# medium  2059    4027  6086
# low     2410    4479  6889
# All     4829    9287  14116

# %%
plt.figure(figsize = [12, 5])
sns.countplot(x='salary',data=final_data,hue='gender',palette='Set2_r')
# Out:
# <AxesSubplot:xlabel='salary', ylabel='count'>

# %%
print(final_data.pivot_table('employee_id', index='recently_promoted', columns='gender',aggfunc='count'))
# Out:
# gender             Female  Male
# recently_promoted
# 0                  4739    9080
# 1                  90      207

# %%
plt.figure(figsize = [12, 5])
sns.countplot(x='recently_promoted',data=final_data,hue='gender',palette='Set3_r')
# Out:
# <AxesSubplot:xlabel='recently_promoted', ylabel='count'>

# %%
print(final_data.pivot_table('employee_id', index='tenure', columns='gender',aggfunc='count'))
# Out:
# gender  Female  Male
# tenure
# 1       44      106
# 2       941     2078
# 3       2105    3901
# 4       845     1541
# 5       520     843
# 6       233     426
# 7       49      131
# 8       43      112
# 10      49      149

# %%
plt.figure(figsize = [12, 5])
sns.countplot(x='tenure',data=final_data,hue='gender',palette='Set1_r')
# Out:
# <AxesSubplot:xlabel='tenure', ylabel='count'>

# %%
a= final_data.query("gender == 'Male'")
a.groupby('age')['department'].value_counts().unstack().plot(kind='bar',cmap='Set1',
                                                               figsize=(12,8),stacked=True)
# Out:
# <AxesSubplot:xlabel='age'>

# %%
a= final_data.query("gender == 'Female'")
a.groupby('age')['department'].value_counts().unstack().plot(kind='bar',cmap='Set2',
                                                               figsize=(12,8),stacked=True)
# Out:
# <AxesSubplot:xlabel='age'>

# %% [markdown]
# ### Age wise data analysis

# %%
plt.figure(figsize=(15,5))
final_data.groupby('age').employee_id.nunique().sort_values(ascending=False).plot(kind='bar')
plt.title('Distribution of Employees across Age')
plt.xticks(size = 12)
plt.ylabel('# Employees')
plt.legend()

# %%
as_fig = sns.FacetGrid(final_data,hue='department',aspect=5)
as_fig.map(sns.kdeplot,'age')
oldest = final_data['age'].max()
as_fig.set(xlim=(0,oldest))
as_fig.add_legend()
plt.title('Age distribution Across Departments')
# Out:
# Text(0.5, 1.0, 'Age distribution Across Departments')

# %% [markdown]
# - Most of the Employees belongs to the Department **Temporary** are in age group of 20 to 30 Years.

# %% [markdown]
# ###  Department wise Analysis

# %%
#pd.crosstab(final_data['department'],final_data['status'])
pd.crosstab(final_data['department'],final_data['status'],margins=True).sort_values('All')
# Out:
# status      Employed  Left    All
# department
# D00-TP      130       20    150
# D00-PR      157       16    173
# D00-AD      140       35    175
# D00-MN      505       85    590
# D00-UN      501       205   706
# D00-FN      529       193   722
# D00-MT      617       195   812
# D00-PD      666       187   853
# D00-IT      1062      297   1359
# D00-SP      1589      519   2108
# D00-ENG     1919      654   2573
# D00-SS      2946      949   3895
# All         10761     3355  14116

# %%
pd.crosstab(final_data.department,final_data.status).plot(kind='bar',figsize=(10,6))
# Out:
# <AxesSubplot:xlabel='department'>

# %% [markdown]
# - The above table indicatesthet the highest employee attrition belonged to Sales department followed by Engineering and Support departments

# %%
pd.crosstab(final_data['department'],final_data['n_projects'])
# Out:
# n_projects   1    2     3     4    5    6   7
# department
# D00-AD      0   20   50    56    32   12   5
# D00-ENG     0   384  678   742   481  233  55
# D00-FN      0   119  190   206   131  61   15
# D00-IT      0   207  380   376   276  98   22
# D00-MN      0   73   163   192   114  36   12
# D00-MT      0   146  232   237   134  50   13
# D00-PD      0   137  223   249   160  69   15
# D00-PR      0   17   61    42    34   16   3
# D00-SP      0   327  569   613   412  162  25
# D00-SS      0   680  1031  1116  701  303  64
# D00-TP      61  79   10    0     0    0    0
# D00-UN      0   133  201   215   91   53   13

# %%
pd.crosstab(final_data.department,final_data.n_projects).plot(kind='bar',figsize=(15,7))
# Out:
# <AxesSubplot:xlabel='department'>

# %% [markdown]
# - The above table indicates that the highest number of Projects handled by the Sales department followed by Engineering and Support departments same pattern is followed in employee attrition also.

# %% [markdown]
# ### Marital Status

# %%
emp_left['marital_status'].value_counts()
# Out:
# Unmarried    1947
# Married      1408
# Name: marital_status, dtype: int64

# %%
emp_left['gender'].value_counts()
# Out:
# Male      1860
# Female    1495
# Name: gender, dtype: int64

# %%
emp_employed['marital_status'].value_counts()
# Out:
# Married      5497
# Unmarried    5264
# Name: marital_status, dtype: int64

# %%
plt.figure(figsize=(12,6))
sns.countplot(x='marital_status', hue='status', data = final_data,palette="winter")
#sns.countplot(x='marital_status', hue=['status','age'], data = final_data,palette="winter")
# Out:
# <AxesSubplot:xlabel='marital_status', ylabel='count'>

# %% [markdown]
# ### No. of years working (Tenure)

# %%
print(final_data[['employee_id','tenure']].groupby('tenure').nunique())
# Out:
#         employee_id
# tenure
# 1       150
# 2       3019
# 3       6006
# 4       2386
# 5       1363
# 6       659
# 7       180
# 8       155
# 10      198

# %%
plt.figure(figsize=(15,5))
sns.countplot(x='tenure',  data = final_data)
# Out:
# <AxesSubplot:xlabel='tenure', ylabel='count'>

# %%
final_data['tenure'].value_counts().plot(kind='pie',fontsize=14, autopct='%3.1f%%',figsize=(7,7), startangle=135, 
                                         cmap='Accent')
plt.legend(labels = final_data['tenure'].value_counts().index, bbox_to_anchor=(1.25,0.5),loc = 'center right')
plt.title('Pie chart showing the Tenure of Employees')
# Out:
# Text(0.5, 1.0, 'Pie chart showing the Tenure of Employees')

# %%
plt.figure(figsize=(15,5))
sns.countplot(x='status', hue='tenure', data = final_data)
# Out:
# <AxesSubplot:xlabel='status', ylabel='count'>

# %% [markdown]
# - around 80% of employees have experience between 2-4 years.
# - After 3 to 5 years of experience employees are not staying with the organization.

# %% [markdown]
# ### Recently Promoted

# %%
final_data[['employee_id','recently_promoted']].groupby('recently_promoted').nunique()
# Out:
#                    employee_id
# recently_promoted
# 0                  13819
# 1                  297

# %%
sns.countplot(x='recently_promoted',  data = final_data)
# Out:
# <AxesSubplot:xlabel='recently_promoted', ylabel='count'>

# %% [markdown]
# - 297 employees got promoted recently

# %%
emp_left[['employee_id','recently_promoted']].groupby('recently_promoted').nunique()
# Out:
#                    employee_id
# recently_promoted
# 0                  3337
# 1                  18

# %%
final_data['recently_promoted'].value_counts().plot(kind='pie',fontsize=14, autopct='%3.1f%%',figsize=(7,7), startangle=135)
plt.legend(labels = final_data['recently_promoted'].value_counts().index, bbox_to_anchor=(1.25,0.5),loc = 'center right')
plt.title('Pie chart showing the Promotion of Employees Left')
# Out:
# Text(0.5, 1.0, 'Pie chart showing the Promotion of Employees Left')

# %% [markdown]
# Recently Promoted but still left organisation:
#
# - The above stats indicates that the number of employees promoted among those who left the organisation is so small.
# - **Delay in Promotion** could be the reason for them to leave the organisation.

# %% [markdown]
# ### Project Distribution among Employees

# %%
sns.countplot(x='n_projects',data=final_data)
# Out:
# <AxesSubplot:xlabel='n_projects', ylabel='count'>

# %%
print('Average number of projects worked by Employees: ',final_data.n_projects.mean())
# Out:
# Average number of projects worked by Employees:  3.7777699064890906

# %%
sns.countplot(x="n_projects", data=emp_left)
# Out:
# <AxesSubplot:xlabel='n_projects', ylabel='count'>

# %%
print('Average number of projects worked by Employees who Left: ',emp_left.n_projects.mean())
# Out:
# Average number of projects worked by Employees who Left:  3.83725782414307

# %% [markdown]
# ### Filed Complaint

# %%
final_data[['employee_id','filed_complaint']].groupby('filed_complaint').nunique()
# Out:
#                  employee_id
# filed_complaint
# 0                12075
# 1                2041

# %%
plt.figure(figsize=(12,5))
sns.countplot(x='status', hue='filed_complaint', data = final_data)
# Out:
# <AxesSubplot:xlabel='status', ylabel='count'>

# %%
emp_left[['employee_id','filed_complaint']].groupby('filed_complaint').nunique()
# Out:
#                  employee_id
# filed_complaint
# 0                3203
# 1                152

# %% [markdown]
# - Majority of the employees who had left not complaint in the last 3 years

# %%
plt.figure(figsize=(12,6))
sns.countplot(x='filed_complaint', hue='department', data = final_data)
# Out:
# <AxesSubplot:xlabel='filed_complaint', ylabel='count'>

# %% [markdown]
# - More complaints are filed in Sales department followed by Engineering department

# %% [markdown]
# ### Monthly hours worked by the employee

# %%
sns.distplot(final_data.avg_monthly_hrs)
# Out:
# <AxesSubplot:xlabel='avg_monthly_hrs'>

# %%
final_data.avg_monthly_hrs.mean()
# Out:
# 199.9926324737886

# %%
emp_left.avg_monthly_hrs.mean()
# Out:
# 206.68822652757078

# %%
emp_employed.avg_monthly_hrs.mean()
# Out:
# 197.90512034197565

# %% [markdown]
# ### Salary wise Analysis

# %%
final_data[['employee_id','salary']].groupby('salary').nunique()
# Out:
#         employee_id
# salary
# high    1141
# low     6889
# medium  6086

# %%
ax = final_data['salary'].value_counts().plot(kind='bar', figsize=(10,7),fontsize=13);
ax.set_alpha(0.8)
ax.set_title("Distribution Of The Employee Salary", fontsize=12)
ax.set_ylabel("Frequency", fontsize=12);

totals = []

for i in ax.patches:
    totals.append(i.get_height())

total = sum(totals)

for i in ax.patches:
    ax.text(i.get_x()-.03, i.get_height()+.5, \
            str(round((i.get_height()/total)*100, 2))+'%', fontsize=15,
                color='dimgrey')

# %%
final_data.groupby('salary').mean()
# Out:
#         avg_monthly_hrs  filed_complaint  last_evaluation  n_projects  \
# salary
# high   199.342682       0.160386         0.702983         3.750219
# low    200.214980       0.140949         0.713071         3.777181
# medium 199.862800       0.145744         0.709475         3.783602
#
#         recently_promoted  satisfaction   tenure   employee_id       age
# salary
# high   0.059597           0.643101      3.652060 111364.503067 32.818580
# low    0.009435           0.602389      3.412832 112393.724198 32.720424
# medium 0.026947           0.623356      3.503286 111953.325830 33.109267

# %%
emp_left.groupby('salary').mean()
# Out:
#         avg_monthly_hrs  filed_complaint  last_evaluation  n_projects  \
# salary
# high   192.649351       0.000000         0.667971         3.402597
# low    206.274779       0.043180         0.726839         3.825810
# medium 208.239516       0.051613         0.726750         3.883065
#
#         recently_promoted  satisfaction   tenure   employee_id       age
# salary
# high   0.000000           0.438094      3.636364 116705.831169 30.363636
# low    0.006869           0.446490      3.855741 115443.429833 31.791462
# medium 0.003226           0.443189      3.858871 115578.983871 32.373387

# %%
emp_left[['employee_id','salary']].groupby('salary').nunique()
# Out:
#         employee_id
# salary
# high    77
# low     2038
# medium  1240

# %%
emp_employed.groupby('salary').mean()
# Out:
#         avg_monthly_hrs  filed_complaint  last_evaluation  n_projects  \
# salary
# high   199.827068       0.171992         0.705516         3.775376
# low    197.669140       0.182024         0.707286         3.756751
# medium 197.719356       0.169831         0.705055         3.758151
#
#         recently_promoted  satisfaction   tenure   employee_id       age
# salary
# high   0.063910           0.657937      3.653195 110977.959586 32.996241
# low    0.010513           0.667885      3.226757 111112.483199 33.110699
# medium 0.033017           0.669457      3.412299 111025.588320 33.297565

# %% [markdown]
# Observations from the above:
#
# - worked for more hours,
# - more projects,
# - High tenure number of years
# - Paid less and not promoted
# - Satisfaction level is much below average in comparison to those who are still employed.

# %% [markdown]
# ### Impact of Satisfaction and Last Evaluation

# %%
from sklearn.cluster import KMeans
# Filter data
left_emp =  emp_left[['satisfaction', 'last_evaluation']]
# Create groups using K-means clustering.
kmeans = KMeans(n_clusters = 3, random_state = 1).fit(left_emp)

# %%
# Add new column "label" annd assign cluster labels.
left_emp['label'] = kmeans.labels_
# Create scatter plot
plt.scatter(left_emp['satisfaction'], left_emp['last_evaluation'], c=left_emp['label'],cmap='Paired')
plt.xlabel('Satisfaction Level')
plt.ylabel('Last Evaluation Rating')
plt.title('Clusters of employees who left')
plt.show()

# %% [markdown]
# From the above clusters we can find that Employee who left the company can be grouped into 3 types of employees:
#
# - High Evaluation rating, but low satisfaction
# - High rating and high satisfaction
# - Medium to low rating and medium and low satisfaction

# %% [markdown]
# ### Final Dataset for Modelling

# %%
final_data.head()
# Out:
#    avg_monthly_hrs department  filed_complaint  last_evaluation  n_projects  \
# 0 246.000000        D00-UN     0               0.866838          6
# 1 134.000000        D00-UN     0               0.555718          2
# 2 156.000000        D00-SS     1               0.474082          2
# 3 256.000000        D00-SP     0               0.961360          6
# 4 146.000000        D00-SS     0               0.507349          2
#
#    recently_promoted  salary  satisfaction status  tenure  employee_id  age  \
# 0  0                  medium 0.134415       Left   4       124467       42
# 1  0                  low    0.511041       Left   3       112210       23
# 2  0                  medium 0.405101       Left   3       126150       24
# 3  0                  low    0.152974       Left   4       125346       51
# 4  0                  medium 0.434845       Left   3       113707       23
#
#    gender marital_status
# 0  Female  Married
# 1  Female  Unmarried
# 2  Female  Unmarried
# ...

# %%
final_data.nunique()
# Out:
# avg_monthly_hrs      249
# department           12
# filed_complaint      2
# last_evaluation      12196
# n_projects           7
# recently_promoted    2
# salary               3
# satisfaction         13493
# status               2
# tenure               9
# employee_id          14116
# age                  36
# gender               2
# marital_status       2
# dtype: int64

# %%
final_data.shape
# Out:
# (14116, 14)

# %%
final_data.to_csv('final_data.csv',index=False)

# %%
df_employee = final_data.drop('employee_id',1)

# %%
df_employee.shape
# Out:
# (14116, 13)

# %% [markdown]
# ## Correlation b/w Features

# %%
plt.figure(figsize=(12, 8))
sns.heatmap(df_employee.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Feature Engineering

# %% [markdown]
# ### Encoding

# %%
from sklearn.preprocessing import LabelEncoder
Label_Encoder = LabelEncoder()

# %%
for col in df_employee.columns[1:]:
    if df_employee[col].dtype == 'object':
        if len(list(df_employee[col].unique())) <= 12:
            Label_Encoder.fit(df_employee[col])
            df_employee[col] = Label_Encoder.transform(df_employee[col])

# %%
df_employee.head()
# Out:
#    avg_monthly_hrs  department  filed_complaint  last_evaluation  n_projects  \
# 0 246.000000        11          0               0.866838          6
# 1 134.000000        11          0               0.555718          2
# 2 156.000000        9           1               0.474082          2
# 3 256.000000        8           0               0.961360          6
# 4 146.000000        9           0               0.507349          2
#
#    recently_promoted  salary  satisfaction  status  tenure  age  gender  \
# 0  0                  2      0.134415       1       4       42   0
# 1  0                  1      0.511041       1       3       23   0
# 2  0                  2      0.405101       1       3       24   0
# 3  0                  1      0.152974       1       4       51   0
# 4  0                  2      0.434845       1       3       23   0
#
#    marital_status
# 0  0
# 1  1
# 2  1
# 3  0
# 4  1

# %% [markdown]
# ### Splitting X and y into training datasets

# %%
Y = df_employee['status']

X = df_employee.drop(['status'],axis=1)

# %%
print(X.shape)
print(Y.shape)
# Out:
# (14116, 12)
# (14116,)

# %%
from sklearn.model_selection import train_test_split

X_train,X_test,Y_train,Y_test = train_test_split(X,Y,test_size=0.2,random_state=1,stratify=Y)

# %%
print(X_train.shape)
print(Y_train.shape)
# Out:
# (11292, 12)
# (11292,)

# %%
print(X_test.shape)
print(Y_test.shape)
# Out:
# (2824, 12)
# (2824,)

# %% [markdown]
# ### Scaling

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()

X_train_sc = scaler.fit_transform(X_train)
X_test_sc = scaler.transform(X_test)

# %%
X_s = scaler.fit_transform(X)

# %% [markdown]
# ## Modeling

# %% [markdown]
# ### Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression

# %%
lr = LogisticRegression()
lr.fit(X_train_sc,Y_train)
y_test_pred = lr.predict(X_test_sc)

# %%
from sklearn.metrics import accuracy_score
print(accuracy_score(y_test_pred,Y_test))
# Out:
# 0.7808073654390935

# %%
from sklearn.metrics import confusion_matrix
confusion_matrix = pd.DataFrame(confusion_matrix(Y_test, y_test_pred))
print(confusion_matrix)
# Out:
#       0    1
# 0  2017  136
# 1  483   188

# %%
from sklearn import metrics

probs = lr.predict_proba(X_test_sc)
preds = probs[:,1]
fpr, tpr, threshold = metrics.roc_curve(Y_test, preds)
roc_auc = metrics.auc(fpr, tpr)

plt.title('Receiver Operating Characteristic')
plt.plot(fpr, tpr, 'b', label = 'AUC = %0.2f' % roc_auc)
plt.legend(loc = 'lower right')
plt.plot([0, 1], [0, 1],'r--')
plt.xlim([0, 1])
plt.ylim([0, 1])
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
plt.show()

# %% [markdown]
# ### Decision Tree Classifier

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
dtc = DecisionTreeClassifier()
dtc.fit(X_train_sc, Y_train)
y_pred_test = dtc.predict(X_test_sc)

# %%
from sklearn.metrics import accuracy_score
print('Accuracy score for test data is:', accuracy_score(Y_test,y_pred_test))
# Out:
# Accuracy score for test data is: 0.9617563739376771

# %%
from sklearn.metrics import confusion_matrix
confusion_matrix = pd.DataFrame(confusion_matrix(Y_test, y_pred_test))
print(confusion_matrix)
# Out:
#       0    1
# 0  2092  61
# 1  47    624

# %% [markdown]
# ### Random Forest Classifier

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rfc=RandomForestClassifier(n_estimators=10000,max_depth=7,n_jobs=-1)
rfc.fit(X_train_sc,Y_train)
y_test_pred1 = rfc.predict(X_test_sc)

print(accuracy_score(y_test_pred1,Y_test))
# Out:
# 0.9702549575070821

# %% [markdown]
# ### Naive Bayes

# %%
from sklearn.naive_bayes import GaussianNB

# %%
nbc = GaussianNB()
nbc.fit(X_train_sc,Y_train)
y_test_pred3 = nbc.predict(X_test_sc)

print(accuracy_score(y_test_pred3,Y_test))
# Out:
# 0.8055949008498584

# %%
from sklearn.metrics import confusion_matrix
confusion_matrix = pd.DataFrame(confusion_matrix(Y_test, y_test_pred3))
print(confusion_matrix)
# Out:
#       0    1
# 0  1764  389
# 1  160   511

# %% [markdown]
# ###  K Nearest Neighbor

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
accuracy_list = []
def generate():
    for i in range(1,30):
        knn_model_ = KNeighborsClassifier(n_neighbors = i)
        knn_model_.fit(X_train_sc, Y_train)
        pred_i = knn_model_.predict(X_test_sc)
        accuracy_list.append(accuracy_score(Y_test, pred_i))
    
    print("Maximum accuracy and the corresponding value of k is",
          max([(v,i+1) for i,v in enumerate(accuracy_list)]),'respectively.')

generate()
# Out:
# Maximum accuracy and the corresponding value of k is (0.9514872521246459, 2) respectively.

# %%
knn = KNeighborsClassifier(n_neighbors=2, p=2, metric='minkowski')

# %%
knn.fit(X_train_sc, Y_train)
# Out:
# KNeighborsClassifier(n_neighbors=2)

# %%
y_preds = knn.predict(X_test_sc)

# %%
print(accuracy_score(y_preds,Y_test))
# Out:
# 0.9514872521246459

# %%
from sklearn.metrics import confusion_matrix
confusion_matrix = pd.DataFrame(confusion_matrix(Y_test, y_preds))
print(confusion_matrix)
# Out:
#       0    1
# 0  2104  49
# 1  88    583

# %% [markdown]
# ### Support Vector Machines

# %%
from sklearn.svm import SVC

# %%
svc=SVC(random_state = 0)
svc.fit(X_train_sc,Y_train)
y_test_pred4 = svc.predict(X_test_sc)
print(accuracy_score(Y_test,y_test_pred4))
# Out:
# 0.9571529745042493

# %% [markdown]
# ### Bagging Classifier

# %%
from sklearn.ensemble import BaggingClassifier

from sklearn.tree import DecisionTreeClassifier
dtc = DecisionTreeClassifier()

model1 = BaggingClassifier(base_estimator=dtc, n_estimators=500, max_samples= 0.60 ,random_state=1) 
model1.fit(X_train_sc, Y_train)
y_pred_test = model1.predict(X_test_sc)

from sklearn.metrics import accuracy_score
print('Accuracy score for test data is:', accuracy_score(Y_test,y_pred_test))
# Out:
# Accuracy score for test data is: 0.9762747875354107

# %% [markdown]
# ### Voting Based Ensemble Technique

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.svm import SVC
from sklearn.ensemble import VotingClassifier
from sklearn import model_selection
from sklearn.model_selection import KFold

# %%
kfold = KFold(n_splits=10)

#create the sub models
estimators =[]

model1 = LogisticRegression()
estimators.append(('logistic',model1))

model2 = DecisionTreeClassifier()
estimators.append(('cart', model2))

model3 = SVC()
estimators.append(('svm', model3))

# %%
# create the ensemble model
from sklearn import model_selection
from sklearn.model_selection import cross_val_score

ensemble = VotingClassifier(estimators) 

results = cross_val_score(ensemble, X_s, Y, cv=kfold)

print('test accuracy: ',results.mean())
# Out:
# test accuracy:  0.951549741709715

# %% [markdown]
# ### AdaBoost Classifier

# %%
from sklearn.ensemble import AdaBoostClassifier

# %%
abc = AdaBoostClassifier(n_estimators=10000)
abc.fit(X_train_sc, Y_train)
y_test_pred5 = abc.predict(X_test_sc) 
print(accuracy_score(y_test_pred5,Y_test))
# Out:
# 0.9351983002832861

# %% [markdown]
# ### Gradient Boost Classifier

# %%
from sklearn.ensemble import GradientBoostingClassifier

model_gb = GradientBoostingClassifier(n_estimators=100, random_state=1, learning_rate = 0.10) 

results_gb = cross_val_score(model_gb, X_s, Y, cv=kfold)

print('test accuracy: ',results_gb.mean())
# Out:
# test accuracy:  0.9667785790721626

# %% [markdown]
# ### XG Boost Classifier

# %%
from xgboost import XGBClassifier

# %%
XGB = XGBClassifier(n_estimators=100, random_state=1, learning_rate = 0.15)
XGB.fit(X_train_sc,Y_train)
y_test_pred4 = XGB.predict(X_test_sc)
print(accuracy_score(Y_test,y_test_pred4))
# Out:
# [13:23:53] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# 0.9748583569405099

# %% [markdown]
# ### Hyper Parameter Tuning

# %% [markdown]
# #### Decision Tree with Gridsearch

# %%
from sklearn.model_selection import GridSearchCV

decision_tree_classifier = DecisionTreeClassifier(random_state = 1)

tree_para = [{'criterion':['gini','entropy'],'max_depth': range(2,60),
                             'max_features': ['sqrt', 'log2', None] }]
                                                 
grid_search = GridSearchCV(decision_tree_classifier,tree_para, cv=10, refit='AUC')
grid_search.fit(X_train_sc, Y_train)
# Out:
# GridSearchCV(cv=10, estimator=DecisionTreeClassifier(random_state=1),
#              param_grid=[{'criterion': ['gini', 'entropy'],
#                           'max_depth': range(2, 60),
#                           'max_features': ['sqrt', 'log2', None]}],
#              refit='AUC')

# %%
y_pred_test1 = grid_search.predict(X_test_sc)

# %%
print('Accuracy score for test data is:', accuracy_score(Y_test,y_pred_test1))
# Out:
# Accuracy score for test data is: 0.9691926345609065

# %% [markdown]
# #### Random Forest with RandomizedsearchCV

# %%
model_rfcv = RandomForestClassifier(n_estimators=500, max_samples= 0.60 ,random_state=1)

# %%
from sklearn.model_selection import RandomizedSearchCV
from scipy.stats import randint as sp_randint
# parameters for GridSearchCV
# specify parameters and distributions to sample from
param_dist = {"max_depth": range(2,5),
              "min_samples_split": sp_randint(2, 11),
              "min_samples_leaf": sp_randint(1, 11),
              "bootstrap": [True, False],
              "n_estimators": [100, 400, 700, 1000, 1500],
              "criterion" : ["gini", "entropy"],
              'max_features': ['sqrt', 'log2', None]
             }
# run randomized search
n_iter_search = 50
random_search = RandomizedSearchCV(model_rfcv, param_distributions = param_dist,
                                   n_iter = n_iter_search,
                                   n_jobs = -1)

# %%
random_search.fit(X_train_sc, Y_train)
# Out:
# RandomizedSearchCV(estimator=RandomForestClassifier(max_samples=0.6,
#                                                     n_estimators=500,
#                                                     random_state=1),
#                    n_iter=50, n_jobs=-1,
#                    param_distributions={'bootstrap': [True, False],
#                                         'criterion': ['gini', 'entropy'],
#                                         'max_depth': range(2, 5),
#                                         'max_features': ['sqrt', 'log2', None],
#                                         'min_samples_leaf': <scipy.stats._distn_infrastructure.rv_frozen object at 0x00000237C7DE5C10>,
#                                         'min_samples_split': <scipy.stats._distn_infrastructure.rv_frozen object at 0x00000237C7DE5DF0>,
#                                         'n_estimators': [100, 400, 700, 1000,
#                                                          1500]})

# %%
y_pred_test2 = random_search.predict(X_test_sc)

# %%
print('Accuracy score for test data is:', accuracy_score(Y_test,y_pred_test2))
# Out:
# Accuracy score for test data is: 0.9553824362606232

# %% [markdown]
# #### Support Vector Classifier

# %%
from sklearn.svm import SVC
from sklearn.model_selection import GridSearchCV
Cs = [0.00001,0.0001,0.001,0.01,0.1,1,10]
gammas=[0.0001,0.001,0.01,0.1,1]

param_grid = {'C': Cs,'gamma':gammas}
grid_search = GridSearchCV(SVC(), param_grid, cv=10)
grid_search.fit(X_train_sc,Y_train)
grid_search.best_params_
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-186-03ea83b8d717> in <module>
#       6 param_grid = {'C': Cs,'gamma':gammas}
#       7 grid_search = GridSearchCV(SVC(), param_grid, cv=10)
# ----> 8 grid_search.fit(X_train_sc,Y_train)
#       9 grid_search.best_params_
#
# ~\anaconda3\lib\site-packages\sklearn\model_selection\_search.py in fit(self, X, y, groups, **fit_params)
#     889                 return results
#     890
# --> 891             self._run_search(evaluate_candidates)
#     892
#     893             # multimetric is determined here because in the case of a callable
#
# ~\anaconda3\lib\site-packages\sklearn\model_selection\_search.py in _run_search(self, evaluate_candidates)
#    1390     def _run_search(self, evaluate_candidates):
#    1391         """Search all candidates in param_grid"""
# ...

# %%
model=SVC(C=10,gamma=0.1)

# %%
model.fit(X_train_sc,Y_train)

# %%
y_pred = model.predict(X_test_sc)

# %%
from sklearn.metrics import accuracy_score
print('Accuracy Score:',accuracy_score(Y_test,y_pred))

# %%
from sklearn.metrics import confusion_matrix
confusion_matrix = pd.DataFrame(confusion_matrix(Y_test, y_pred))
print(confusion_matrix)

# %% [markdown]
# ### Fit & Tune Models with Cross validation

# %% [markdown]
# #### Logistic Regression

# %%
from sklearn import model_selection
kfold = model_selection.KFold(n_splits=10,shuffle=True,random_state=2)
modelLR = LogisticRegression()
results = model_selection.cross_val_score(modelLR, X_train_sc, Y_train, cv=kfold, scoring='accuracy')
print("10-fold cross validation average Accuracy score for Logistic Legression: %.3f" % (results.mean()))
# Out:
# 10-fold cross validation average Accuracy score for Logistic Legression: 0.783

# %%
results = model_selection.cross_val_score(modelLR, X_test_sc, Y_test, cv=kfold, scoring= 'roc_auc')
print("10-fold cross validation average roc_auc score for Logistic Regression: %.3f" % (results.mean()))
# Out:
# 10-fold cross validation average roc_auc score for Logistic Legression: 0.822

# %% [markdown]
# #### Support Vector Classifier

# %%
from sklearn.model_selection import cross_val_score

svc = SVC(kernel='rbf',random_state = 0)
scores = cross_val_score(svc,X_s, Y, cv=10, scoring='accuracy') 
print(scores.mean())
# Out:
# 0.953245091681507

# %%
'''kfold = model_selection.KFold(n_splits=10,shuffle=True,random_state=7)

modelCV = RandomForestClassifier()
scoring = 'accuracy'
results = model_selection.cross_val_score(modelCV, X_train, Y_train, cv=kfold, scoring=scoring)
print("10-fold cross validation average roc_auc score for Random Forest Classifier: %.3f" % (results.mean()))'''
# Out:
# 10-fold cross validation average roc_auc score for Random Forest Classifier: 0.977

# %% [markdown]
# #### Bagging Classifier

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import KFold
logreg = LogisticRegression()

kfold = KFold(n_splits=10) # change this during train-test split method
#cart = DecisionTreeClassifier()

model_k1 = BaggingClassifier(base_estimator=logreg, n_estimators=100, random_state=1)

results_k1 = cross_val_score(model_k1, X_s, Y, cv=kfold)

print('test accuracy: ',results_k1.mean())
# Out:
# test accuracy:  0.7439320856162527

# %%
cart = DecisionTreeClassifier()

kfold = KFold(n_splits=10)

model_k2 = BaggingClassifier(base_estimator=cart, n_estimators=100, random_state=1)

results_k2 = cross_val_score(model_k2, X_s, Y, cv=kfold)

print('test accuracy: ',results_k2.mean())
# Out:
# test accuracy:  0.9724456064551491

# %% [markdown]
# #### Adaboost Classifier

# %%
score = []
for depth in [1,2,10] : 
    reg_ada = AdaBoostClassifier(DecisionTreeClassifier(max_depth=depth))
    scores_ada = cross_val_score(reg_ada, X_s, Y, cv=10)
    score.append(scores_ada.mean())

print(score)
# Out:
# [0.9288727481162777, 0.9624535468988101, 0.9729391486961008]

# %% [markdown]
# #### XGB Classifier

# %%
kfold = KFold(n_splits=10)
XGB_cv = XGBClassifier(n_estimators=100, random_state=1, learning_rate = 0.15)
results_xgb = cross_val_score(XGB_cv, X_s, Y, cv=kfold)

print('test accuracy: ',results_xgb.mean())

# %% [markdown]
# ## Evaluate and Finalise the Model

# %% [markdown]
# ### Model Comparison

# %% [markdown]
# | Algorithms                                | Accuracy Score   |  ROC_AUC    |
# | ------------------------------            |:----------------:|------------:|
# | __Logistic Regression__                   | __78.08%__      |__78.08%__    |
# | __Decision Tree Classifier__              | __96.28.0%__    |__96.28.0%__  |
# | __Decision Tree with Gridsearch__         | __97.80%__      |__97.80%__    |
# | __Random Forest__                         | __96.99%__      |__96.99%__    |
# | __Random Forest with RandomizedsearchCV__ | __94.90%__      |__94.90%__    |
# | __RFC 10 Fold Cross Validation__          | __97.70%__      |__97.70%__    |
# | __Naive Bayes Theorem__                   | __80.56%__      |__80.56%__    |
# | __K Nearest Neighbor__                    | __794.97%__     |__794.97%__   |
# | __Support Vector Classifier__             | __95.85%__      |__95.85%__    |
# | __Bagging Classifier__                    | __97.91%__      |__97.91%__    |
# | __Voting Classifier__                     | __95.20%__      |__97.47%__    |
# | __Ada Boosting Classifier__               | __97.47%__      |__97.47%__    |
# | __Gradient Boost Classifier__             | __96.67%__      |__97.47%__    |
# | __XGB Classifier__                        | __97.26%__      |__97.47%__    |

# %% [markdown]
# ### Feature Importance

# %%
names=list(X.columns.values)
data={'Feature_Name':names,
        'Feature_Importance': rfc.feature_importances_ }

feature_df=pd.DataFrame(data)
feature_df.sort_values(by=['Feature_Importance'],ascending=False,inplace=True)
fig, ax = plt.subplots(figsize=(20,16))
sns.barplot(data=feature_df,y='Feature_Name',x='Feature_Importance')
# Out:
# <AxesSubplot:xlabel='Feature_Importance', ylabel='Feature_Name'>

# %% [markdown]
# ## Predicting the unkown

# %% [markdown]
# ### Importing & Preprocessing of Unseen data

# %%
data_unseen = pd.read_csv('https://raw.githubusercontent.com/sruthayanan/INSAID_Capstone2/main/GCD_Capstone_Project_unseen_data.csv')
data_unseen.head()
# Out:
#    avg_monthly_hrs department  filed_complaint  last_evaluation  n_projects  \
# 0  134              D00-IT      nan            0.528841          2
# 1  221              D00-PD      nan            0.784561          2
# 2  156              D00-SS      nan            0.545183          2
# 3  133              D00-PR      nan              nan             4
# 4  135              D00-SS      nan            0.454637          2
#
#    recently_promoted  salary  satisfaction   tenure  employee_id
# 0   nan               low    0.400464      3.000000  119045
# 1   nan               low    0.759513      3.000000  112223
# 2   nan               medium 0.336457      3.000000  103924
# 3   nan               medium 0.832039      2.000000  105922
# 4   nan               low    0.320723      5.000000  103297

# %%
data_unseen.shape
# Out:
# (100, 10)

# %%
data_unseen.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 10 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   avg_monthly_hrs    100 non-null    int64
#  1   department         98 non-null     object
#  2   filed_complaint    15 non-null     float64
#  3   last_evaluation    83 non-null     float64
#  4   n_projects         100 non-null    int64
#  5   recently_promoted  3 non-null      float64
#  6   salary             100 non-null    object
#  7   satisfaction       97 non-null     float64
#  8   tenure             97 non-null     float64
#  9   employee_id        100 non-null    int64
# dtypes: float64(5), int64(3), object(2)
# memory usage: 7.9+ KB

# %%
emp_details.head()
# Out:
#    employee_id  age  gender marital_status
# 0  113558       43   Male    Married
# 1  112256       24   Female  Unmarried
# 2  112586       22   Female  Unmarried
# 3  108071       36   Male    Married
# 4  116915       38   Male    Married

# %%
common1 = np.intersect1d(data_unseen.employee_id,emp_details.employee_id)
common1.shape
# Out:
# (100,)

# %%
data_pred = pd.merge(left=data_unseen,right=emp_details, how='inner',on='employee_id')
data_pred.head()
# Out:
#    avg_monthly_hrs department  filed_complaint  last_evaluation  n_projects  \
# 0  134              D00-IT      nan            0.528841          2
# 1  221              D00-PD      nan            0.784561          2
# 2  156              D00-SS      nan            0.545183          2
# 3  133              D00-PR      nan              nan             4
# 4  135              D00-SS      nan            0.454637          2
#
#    recently_promoted  salary  satisfaction   tenure  employee_id  age gender  \
# 0   nan               low    0.400464      3.000000  119045       27   Male
# 1   nan               low    0.759513      3.000000  112223       23   Male
# 2   nan               medium 0.336457      3.000000  103924       26   Male
# 3   nan               medium 0.832039      2.000000  105922       52   Male
# 4   nan               low    0.320723      5.000000  103297       27   Male
#
#   marital_status
# 0  Unmarried
# 1  Unmarried
# 2  Unmarried
# 3  Married
# 4  Unmarried

# %%
data_pred.shape
# Out:
# (100, 13)

# %%
data_pred.isnull().sum().sort_values(ascending = False)
# Out:
# recently_promoted    97
# filed_complaint      85
# last_evaluation      17
# tenure               3
# satisfaction         3
# department           2
# marital_status       0
# gender               0
# age                  0
# employee_id          0
# salary               0
# n_projects           0
# avg_monthly_hrs      0
# dtype: int64

# %% [markdown]
# ### Missing Value Treatment:

# %%
data_pred.recently_promoted.value_counts()
# Out:
# 1.000000    3
# Name: recently_promoted, dtype: int64

# %% [markdown]
# - we will replace the NAN values with zero

# %%
data_pred.filed_complaint.value_counts()
# Out:
# 1.000000    15
# Name: filed_complaint, dtype: int64

# %% [markdown]
# - we will replace the NAN values with zero

# %%
data_pred[['recently_promoted','filed_complaint']] = data_pred[['recently_promoted','filed_complaint']].replace(np.NaN,0)

# %%
data_pred.tenure.value_counts()
# Out:
# 3.000000     40
# 2.000000     27
# 4.000000     11
# 5.000000     10
# 6.000000     5
# 7.000000     2
# 10.000000    2
# Name: tenure, dtype: int64

# %% [markdown]
# - we will replace the NAN values with 1

# %%
data_pred.department.value_counts()
# Out:
# D00-SS     27
# D00-ENG    17
# D00-SP     13
# D00-IT     9
# D00-PD     7
# D00-MT     7
# D00-FN     6
# D00-MN     5
# D00-TP     3
# -IT        2
# D00-AD     1
# D00-PR     1
# Name: department, dtype: int64

# %%
data_pred.replace({'-IT'},{'D00-IT'},inplace =True)

# %%
data_pred['department'] = data_pred['department'].replace(np.NaN,'D00-UN')

# %%
data_pred['tenure'] = data_pred['tenure'].replace(np.NaN,1)

# %%
data_pred['satisfaction'] = data_pred['satisfaction'].replace(np.NaN,0)

# %%
# Calculating the mean of last_evaluation for each department, 
means = data_pred.groupby('department')['last_evaluation'].mean()
# Convert pandas series to dictionary
dd=means.to_dict()

# %%
# replacing the null values of last_evaluation with mean of that department.
data_pred.last_evaluation = data_pred.last_evaluation.fillna(data_pred.department.map(dd))

# %%
data_pred['last_evaluation'] = data_pred['last_evaluation'].fillna(0)

# %%
null_data2 = pd.DataFrame(data_pred.isnull().sum(), columns = ['Frequency'])
null_data2.transpose()
# Out:
#            avg_monthly_hrs  department  filed_complaint  last_evaluation  \
# Frequency  0                0           0                0
#
#            n_projects  recently_promoted  salary  satisfaction  tenure  \
# Frequency  0           0                  0       0             0
#
#            employee_id  age  gender  marital_status
# Frequency  0            0    0       0

# %%
data_pred.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 100 entries, 0 to 99
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   avg_monthly_hrs    100 non-null    int64
#  1   department         100 non-null    object
#  2   filed_complaint    100 non-null    float64
#  3   last_evaluation    100 non-null    float64
#  4   n_projects         100 non-null    int64
#  5   recently_promoted  100 non-null    float64
#  6   salary             100 non-null    object
#  7   satisfaction       100 non-null    float64
#  8   tenure             100 non-null    float64
#  9   employee_id        100 non-null    int64
#  10  age                100 non-null    int64
#  11  gender             100 non-null    object
#  12  marital_status     100 non-null    object
# dtypes: float64(5), int64(4), object(4)
# memory usage: 15.9+ KB

# %%
data_pred.nunique()
# Out:
# avg_monthly_hrs      80
# department           12
# filed_complaint      2
# last_evaluation      88
# n_projects           7
# recently_promoted    2
# salary               3
# satisfaction         96
# tenure               8
# employee_id          100
# age                  30
# gender               2
# marital_status       2
# dtype: int64

# %% [markdown]
# ### Feature Engineering of Unseen data

# %% [markdown]
# ####  Encoding

# %%
from sklearn.preprocessing import LabelEncoder
Label_Encoder = LabelEncoder()
for col in data_pred.columns[1:]:
    if data_pred[col].dtype == 'object':
        if len(list(data_pred[col].unique())) <= 12:
            Label_Encoder.fit(data_pred[col])
            data_pred[col] = Label_Encoder.transform(data_pred[col])

# %%
data_pred.head()
# Out:
#    avg_monthly_hrs  department  filed_complaint  last_evaluation  n_projects  \
# 0  134              3          0.000000         0.528841          2
# 1  221              6          0.000000         0.784561          2
# 2  156              9          0.000000         0.545183          2
# 3  133              7          0.000000         0.000000          4
# 4  135              9          0.000000         0.454637          2
#
#    recently_promoted  salary  satisfaction   tenure  employee_id  age  gender  \
# 0 0.000000            1      0.400464      3.000000  119045       27   1
# 1 0.000000            1      0.759513      3.000000  112223       23   1
# 2 0.000000            2      0.336457      3.000000  103924       26   1
# 3 0.000000            2      0.832039      2.000000  105922       52   1
# 4 0.000000            1      0.320723      5.000000  103297       27   1
#
#    marital_status
# 0  1
# 1  1
# 2  1
# 3  0
# 4  1

# %%
X_valid = data_pred.drop(columns = 'employee_id')

# %%
print(X_valid.shape)
# Out:
# (100, 12)

# %%
X_valid_SC = scaler.transform(X_valid)

# %% [markdown]
# ### Model to Predict Unseen Data

# %%
y_pred_unseenData = XGB.predict(X_valid_SC)
y_pred_unseenData_probability = XGB.predict_proba(X_valid_SC)
predictions = y_pred_unseenData_probability[:,1]

# %%
print (y_pred_unseenData.shape, y_pred_unseenData_probability.shape, predictions.shape)
# Out:
# (100,) (100, 2) (100,)

# %%
df_y_preds = pd.DataFrame(y_pred_unseenData, columns=['status'])
df_y_pred_proba = pd.DataFrame(predictions, columns=['Probability to Leave'])

# %%
df_y_preds.head()
# Out:
#    status
# 0  1
# 1  0
# 2  1
# 3  0
# 4  1

# %%
df_y_preds.status.value_counts()
# Out:
# 0    70
# 1    30
# Name: status, dtype: int64

# %%
df_y_pred_proba.head()
# Out:
#    Probability to Leave
# 0 0.993970
# 1 0.068369
# 2 0.977000
# 3 0.001136
# 4 0.733055

# %%
emp_id = data_pred[['employee_id']]
emp_id.shape
# Out:
# (100, 1)

# %%
df_submission = pd.concat([emp_id, df_y_pred_proba], axis=1)

# %%
df_submission
# Out:
#     employee_id  Probability to Leave
# 0   119045      0.993970
# 1   112223      0.068369
# 2   103924      0.977000
# 3   105922      0.001136
# 4   103297      0.733055
# 5   115525      0.014402
# 6   116409      0.020019
# 7   109427      0.002520
# 8   118590      0.003858
# 9   107075      0.003005
# 10  101173      0.001348
# 11  127419      0.989402
# 12  109575      0.983271
# 13  115834      0.005743
# 14  119963      0.007568
# 15  107449      0.000340
# 16  115767      0.991153
# 17  114678      0.000477
# 18  104384      0.001513
# 19  113998      0.001117
# 20  115060      0.973830
# 21  106141      0.987204
# 22  102113      0.035652
# 23  103723      0.003727
# 24  100400      0.888553
# 25  106597      0.007648
# 26  105299      0.001403
# 27  103740      0.004432
# 28  127312      0.998669
# 29  100564      0.001927
# 30  107811      0.007002
# 31  100646      0.004513
# 32  109852      0.003785
# 33  118666      0.000362
# 34  112180      0.009684
# ...

# %%
df_submission.to_csv('1004_Submission.csv', header=False, index=False)

# %%
test = pd.read_csv('1004_Submission.csv',header=None)
test.head()
# Out:
#         0        1
# 0  119045 0.993970
# 1  112223 0.068369
# 2  103924 0.977000
# 3  105922 0.001136
# 4  103297 0.733055

# %%
test.shape
# Out:
# (100, 2)
